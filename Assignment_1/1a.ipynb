# %%
import pandas as pd, numpy as np, csv 
ds = pd.read_csv('kc_house_data.csv')
training_ds = ds[0:int(0.8*len(ds))]
test_ds = ds[int(0.8*len(ds)):len(ds)]
training_ds
# Out:
#          sqft  floors  bedrooms  bathrooms      price
# 0        5650     1.0         3       1.00   221900.0
# 1        7242     2.0         3       2.25   538000.0
# 2       10000     1.0         2       1.00   180000.0
# 3        5000     1.0         4       3.00   604000.0
# 4        8080     1.0         3       2.00   510000.0
# 5      101930     1.0         4       4.50  1230000.0
# 6        6819     2.0         3       2.25   257500.0
# 7        9711     1.0         3       1.50   291850.0
# 8        7470     1.0         3       1.00   229500.0
# 9        6560     2.0         3       2.50   323000.0
# 10       9796     1.0         3       2.50   662500.0
# 11       6000     1.0         2       1.00   468000.0
# 12      19901     1.5         3       1.00   310000.0
# 13       9680     1.0         3       1.75   400000.0
# 14       4850     1.5         5       2.00   530000.0
# 15       5000     2.0         4       3.00   650000.0
# ...

# %%
test_ds
# Out:
#           sqft  floors  bedrooms  bathrooms      price
# 17290    11500     1.0         4       2.50   380000.0
# 17291    11500     1.0         4       2.50   624900.0
# 17292     1779     2.0         3       2.50   379770.0
# 17293    16200     1.0         3       1.75   340000.0
# 17294     8126     2.0         4       2.75   515500.0
# 17295     7125     1.5         4       2.25   600000.0
# 17296    60984     1.0         1       1.00   400000.0
# 17297    11383     1.5         4       1.00   364000.0
# 17298     7526     2.0         4       2.50   440000.0
# 17299     6240     1.0         2       1.00   285000.0
# 17300     4500     1.5         3       1.00   669000.0
# 17301    13468     1.0         4       2.00   475000.0
# 17302     4000     1.0         2       1.00   747000.0
# 17303     5750     1.0         3       1.50   317000.0
# 17304     8164     1.0         2       1.00   390000.0
# 17305     5000     2.0         4       2.50  1070000.0
# ...
