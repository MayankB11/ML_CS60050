# %%
import numpy as np
dataset = []
with open("Assignment_2_data.txt") as f:
    ct = 0
    for line in f:
        label, line = line.split("\t",1)
        if label == "spam":
            dataset.append([1,line])
        elif label == "ham":
            dataset.append([0,line])
        else:
            print("Error : ",(label, line))

np.random.shuffle(dataset)
dataset
# Out:
# [[0, 'S:)s.nervous  &lt;#&gt; :)\n'],
#  [1, '88800 and 89034 are premium phone services call 08718711108\n'],
#  [0, 'Just curious because my cuz asked what I was up to\n'],
#  [0,
#   'Hi, my love! How goes that day? Fuck, this morning I woke and dropped my cell on the way down the stairs but it seems alright ... *phews* I miss you !\n'],
#  [0, 'Draw va?i dont think so:)\n'],
#  [0, "But i'll b going 2 sch on mon. My sis need 2 take smth.\n"],
#  [0, 'Cps is causing the outages to conserve energy.\n'],
#  [1,
#   'Talk sexy!! Make new friends or fall in love in the worlds most discreet text dating service. Just text VIP to 83110 and see who you could meet.\n'],
#  [0, 'Reverse is cheating. That is not mathematics.\n'],
#  [1,
#   'FreeMsg Hey U, i just got 1 of these video/pic fones, reply WILD to this txt & ill send U my pics, hurry up Im so bored at work xxx (18 150p/rcvd STOP2stop)\n'],
#  [0,
#   "Sorry i now then c ur msg... Yar lor so poor thing... But only 4 one night... Tmr u'll have a brand new room 2 sleep in...\n"],
#  [1,
#   'SMS AUCTION - A BRAND NEW Nokia 7250 is up 4 auction today! Auction is FREE 2 join & take part! Txt NOKIA to 86021 now! HG/Suite342/2Lands Row/W1J6HL\n'],
#  [0,
#   'You give us back my id proof and  &lt;#&gt;  rs. We wont allow you to work. We will come to your home within days\n'],
#  [1,
#   'Buy Space Invaders 4 a chance 2 win orig Arcade Game console. Press 0 for Games Arcade (std WAP charge) See o2.co.uk/games 4 Terms + settings. No purchase\n'],
#  [0, '....photoshop makes my computer shut down.\n'],
#  [0,
#   'A bit of Ur smile is my hppnss, a drop of Ur tear is my sorrow, a part of Ur heart is my life, a heart like mine wil care for U, forevr as my GOODFRIEND\n'],
#  [1,
#   'URGENT This is our 2nd attempt to contact U. Your £900 prize from YESTERDAY is still awaiting collection. To claim CALL NOW 09061702893\n'],
#  [0,
#   "New Theory: Argument wins d SITUATION, but loses the PERSON. So dont argue with ur friends just.. . . . kick them &amp; say, I'm always correct.!\n"],
#  [1,
#   'As a SIM subscriber, you are selected to receive a Bonus! Get it delivered to your door, Txt the word OK to No: 88600 to claim. 150p/msg, EXP. 30Apr\n'],
#  [1,
#   'Dorothy@kiefer.com (Bank of Granite issues Strong-Buy) EXPLOSIVE PICK FOR OUR MEMBERS *****UP OVER 300% *********** Nasdaq Symbol CDGT That is a $5.00 per..\n'],
#  [1,
#   "Loan for any purpose £500 - £75,000. Homeowners + Tenants welcome. Have you been previously refused? We can still help. Call Free 0800 1956669 or text back 'help'\n"],
#  [0, 'Watching ajith film ah?\n'],
#  [0,
#   "Hiya. How was last night? I've been naughty and bought myself clothes and very little ... Ready for more shopping tho! What kind of time do you wanna meet?\n"],
#  [0, 'Thank you princess! You are so sexy...\n'],
#  [0,
#   'Noooooooo please. Last thing I need is stress. For once in your life be fair.\n'],
#  [0, 'We confirm eating at esplanade?\n'],
#  [0,
#   'We walked from my moms. Right on stagwood pass right on winterstone left on victors hill. Address is &lt;#&gt;\n'],
#  [0, 'Oh ok no prob..\n'],
#  [0, "I'm gonna rip out my uterus.\n"],
#  [0, 'You still coming tonight?\n'],
#  [0, "Sorry, I'll call later\n"],
#  [0,
#   '"HEY KATE, HOPE UR OK... WILL GIVE U A BUZ WEDLUNCH. GO OUTSOMEWHERE 4 ADRINK IN TOWN..CUD GO 2WATERSHD 4 A BIT? PPL FROMWRK WILL BTHERE. LOVE PETEXXX."\n'],
#  [0, 'Are you plans with your family set in stone ?\n'],
#  [0, "Hey what's up charles sorry about the late reply.\n"],
#  [0, 'Stop knowing me so well!\n'],
#  [0,
#   'Ha... Then we must walk to everywhere... Cannot take tram. My cousin said can walk to vic market from our hotel \n'],
#  [0, 'they released another Italian one today and it has a cosign option\n'],
#  [0, "Sorry battery died, yeah I'm here\n"],
#  [0,
#   'Hi ....My engagement has been fixd on  &lt;#&gt; th of next month. I know its really shocking bt....hmm njan vilikkam....t ws al of a sudn;-(.\n'],
#  [0, 'I think chennai well settled?\n'],
#  [1,
#   'Your free ringtone is waiting to be collected. Simply text the password "MIX" to 85069 to verify. Get Usher and Britney. FML, PO Box 5249, MK17 92H. 450Ppw 16\n'],
#  [0,
#   'Smile in Pleasure Smile in Pain Smile when trouble pours like Rain Smile when sum1 Hurts U Smile becoz SOMEONE still Loves to see u Smiling!!\n'],
#  [0, 'Yeah probably, I still gotta check out with leo\n'],
#  [0, "I'll meet you in the lobby\n"],
#  [0,
#   '"Hey! do u fancy meetin me at 4 at cha \x96 hav a lil beverage on me. if not txt or ring me and we can meet up l8r. quite tired got in at 3 v.pist ;) love Pete x x x"\n'],
#  [0, "I'm home. Ard wat time will u reach?\n"],
#  [0, 'Hope you are feeling great. Pls fill me in. Abiola\n'],
#  [1,
#   'Hi there, 2nights ur lucky night! Uve been invited 2 XCHAT, the Uks wildest chat! Txt CHAT to 86688 now! 150p/MsgrcvdHG/Suite342/2Lands/Row/W1J6HL LDN 18yrs\n'],
#  [1,
#   "Free entry in 2 a weekly comp for a chance to win an ipod. Txt POD to 80182 to get entry (std txt rate) T&C's apply 08452810073 for details 18+\n"],
#  [0,
#   "Honestly i've just made a lovely cup of tea and promptly dropped my keys in it and then burnt my fingers getting them out!\n"],
#  [0, 'Y de asking like this.\n'],
#  [0, 'Nah man, my car is meant to be crammed full of people\n'],
#  [0, 'Otherwise had part time job na-tuition..\n'],
#  [0, 'K..k..any special today?\n'],
#  [0,
#   'Jus finish my lunch on my way home lor... I tot u dun wan 2 stay in sch today...\n'],
#  [1,
#   'SMS. ac sun0819 posts HELLO:"You seem cool, wanted to say hi. HI!!!" Stop? Send STOP to 62468\n'],
#  [0,
#   'Hi here. have birth at on the  to  at 8lb 7oz. Mother and baby doing brilliantly.\n'],
#  [1,
#   "Rock yr chik. Get 100's of filthy films &XXX pics on yr phone now. rply FILTH to 69669. Saristar Ltd, E14 9YT 08701752560. 450p per 5 days. Stop2 cancel\n"],
#  [0, 'Then she dun believe wat?\n'],
#  [0, 'I will spoil you in bed as well :)\n'],
#  [1, 'You have 1 new voicemail. Please call 08719181513.\n'],
#  [0, 'How? Izzit still raining?\n'],
#  [1,
#   '**FREE MESSAGE**Thanks for using the Auction Subscription Service. 18 . 150p/MSGRCVD 2 Skip an Auction txt OUT. 2 Unsubscribe txt STOP CustomerCare 08718726270\n'],
#  [1,
#   'We know someone who you know that fancies you. Call 09058097218 to find out who. POBox 6, LS15HB 150p\n'],
#  [1,
#   'Wan2 win a Meet+Greet with Westlife 4 U or a m8? They are currently on what tour? 1)Unbreakable, 2)Untamed, 3)Unkempt. Text 1,2 or 3 to 83049. Cost 50p +std text\n'],
#  [0, "I'm stuck in da middle of da row on da right hand side of da lt... \n"],
#  [1,
#   'Get your garden ready for summer with a FREE selection of summer bulbs and seeds worth £33:50 only with The Scotsman this Saturday. To stop go2 notxt.co.uk\n'],
#  [0,
#   'Eh sorry leh... I din c ur msg. Not sad already lar. Me watching tv now. U still in office?\n'],
#  [0, 'You got called a tool?\n'],
#  [0, 'Aiyo u so poor thing... Then u dun wan 2 eat? U bathe already?\n'],
#  [0, 'Finally the match heading towards draw as your prediction.\n'],
#  [0,
#   "As I entered my cabin my PA said, '' Happy B'day Boss !!''. I felt special. She askd me 4 lunch. After lunch she invited me to her apartment. We went there.\n"],
#  [1,
#   'You have WON a guaranteed £1000 cash or a £2000 prize. To claim yr prize call our customer service representative on 08714712394 between 10am-7pm\n'],
#  [0,
#   'Oic cos me n my sis got no lunch today my dad went out... So dunno whether 2 eat in sch or wat...\n'],
#  [0, 'I hav almost reached. Call, i m unable to connect u.\n'],
#  [0,
#   "Nvm... I'm going to wear my sport shoes anyway... I'm going to be late leh.\n"],
#  [0, 'How about clothes, jewelry, and trips?\n'],
#  [0, 'Hey!!! I almost forgot ... Happy B-day babe ! I love ya!!\n'],
#  [0, 'Anything lor but toa payoh got place 2 walk meh...\n'],
#  [0, 'Happy birthday... May all ur dreams come true...\n'],
#  [0,
#   'Especially since i talk about boston all up in my personal statement, lol! I woulda changed that if i had realized it said nyc! It says boston now.\n'],
#  [0, 'Dear got bus directly to calicut\n'],
#  [0,
#   'I bought the test yesterday. Its something that lets you know the exact day u ovulate.when will get 2u in about 2 to 3wks. But pls pls dont fret. I know u r worried. Pls relax. Also is there anything in ur past history u need to tell me?\n'],
#  [0, 'U can call now...\n'],
#  [0,
#   'NEFT Transaction with reference number  &lt;#&gt;  for Rs. &lt;DECIMAL&gt;  has been credited to the beneficiary account on  &lt;#&gt;  at  &lt;TIME&gt; : &lt;#&gt;\n'],
#  [0, 'Please sen :)my kind advice :-)please come here and try:-)\n'],
#  [0, 'Y bishan lei... I tot ü say lavender? \n'],
#  [0, 'At home also.\n'],
#  [0,
#   'awesome, how do I deal with the gate? Charles told me last night but, uh, yeah\n'],
#  [1,
#   'December only! Had your mobile 11mths+? You are entitled to update to the latest colour camera mobile for Free! Call The Mobile Update VCo FREE on 08002986906 \n'],
#  [0, 'I can make lasagna for you... vodka...\n'],
#  [0,
#   'I got like $ &lt;#&gt; , I can get some more later though. Get whatever you feel like\n'],
#  [1,
#   "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's\n"],
#  [0, 'Arun can u transfr me d amt\n'],
#  [0,
#   'Tomorrow i am not going to theatre. . . So i can come wherever u call me. . . Tell me where and when to come tomorrow\n'],
#  [0, "Sorry,  in meeting I'll call you later\n"],
#  [0, 'Tell where you reached\n'],
#  [0, 'Sent me ur email id soon\n'],
#  [0,
#   'Hey mate. Spoke to the mag people. We‘re on.  the is deliver by the end of the month. Deliver on the 24th sept. Talk later. \n'],
#  [0, "You're right I have now that I think about it\n"],
#  [0,
#   "Although i told u dat i'm into baig face watches now but i really like e watch u gave cos it's fr u. Thanx 4 everything dat u've done today, i'm touched...\n"],
#  [1,
#   'Please CALL 08712402779 immediately as there is an urgent message waiting for you\n'],
#  [0,
#   'Do 1 thing! Change that sentence into: "Because i want 2 concentrate in my educational career im leaving here.."\n'],
#  [0,
#   "Tunji, how's the queen? how are you doing. This is just wishing you a great day. Abiola.\n"],
#  [0, "I'm home, my love ... If your still awake ... *loving kiss*\n"],
#  [0, "Let me know when you've got the money so carlos can make the call\n"],
#  [0,
#   'Squeeeeeze!! This is christmas hug.. If u lik my frndshp den hug me back.. If u get 3 u r cute:) 6 u r luvd:* 9 u r so lucky;) None? People hate u:\n'],
#  [0,
#   'In fact when do you leave? I think addie goes back to school tues or wed\n'],
#  [0, 'Whats the staff name who is taking class for us?\n'],
#  [0, 'Dude got a haircut. Now its breezy up there\n'],
#  [0, 'Id onluy matters when getting on from offcampus\n'],
#  [0, 'I guess you could be as good an excuse as any, lol.\n'],
#  [0,
#   'If I get there before you after your ten billion calls and texts so help me god\n'],
#  [0, 'Haha get used to driving to usf man, I know a lot of stoners\n'],
#  [1, 'You have 1 new message. Please call 08712400200.\n'],
#  [0, 'Yup... From what i remb... I think should be can book... \n'],
#  [0, 'Well I might not come then...\n'],
#  [0, 'That seems unnecessarily affectionate\n'],
#  [0,
#   'Happy birthday... May u find ur prince charming soon n dun work too hard...\n'],
#  [1,
#   'Text PASS to 69669 to collect your polyphonic ringtones. Normal gprs charges apply only. Enjoy your tones\n'],
#  [0, 'Yes princess! I want to make you happy...\n'],
#  [1,
#   'PRIVATE! Your 2003 Account Statement for <fone no> shows 800 un-redeemed S. I. M. points. Call 08715203656 Identifier Code: 42049 Expires 26/10/04\n'],
#  [0, 'Please leave this topic..sorry for telling that..\n'],
#  [1,
#   'Your B4U voucher w/c 27/03 is MARSMS. Log onto www.B4Utele.com for discount credit. To opt out reply stop. Customer care call 08717168528\n'],
#  [0,
#   'Then u ask darren go n pick u lor... But i oso sian tmr haf 2 meet lect...\n'],
#  [0, 'Sure! I am driving but will reach my destination soon.\n'],
#  [0,
#   "I'd say that's a good sign but, well, you know my track record at reading women\n"],
#  [0,
#   "no, i *didn't* mean to post it. I wrote it, and like so many other times i've ritten stuff to you, i let it sit there. it WAS what i was feeling at the time. I was angry. Before i left, i hit send, then stop. It wasn't there. I checked on my phone when i got to my car. It wasn't there. You said you didn't sleep, you were bored. So why wouldn't THAT be the time to clean, fold laundry, etc.? At least make the bed?\n"],
#  [0,
#   'Did u turn on the heater? The heater was on and set to &lt;#&gt; degrees.\n'],
#  [1,
#   "FREE NOKIA Or Motorola with upto 12mths 1/2price linerental, 500 FREE x-net mins&100txt/mth FREE B'tooth*. Call Mobileupd8 on 08001950382 or call 2optout/D3WV\n"],
#  [0,
#   'Ups which is 3days also, and the shipping company that takes 2wks. The other way is usps which takes a week but when it gets to lag you may have to bribe nipost to get your stuff.\n'],
#  [1,
#   'Santa calling! Would your little ones like a call from Santa Xmas Eve? Call 09077818151 to book you time. Calls1.50ppm last 3mins 30s T&C www.santacalling.com\n'],
#  [0,
#   'THING R GOOD THANX GOT EXAMS IN MARCH IVE DONE NO REVISION? IS FRAN STILL WITH BOYF? IVE GOTTA INTERVIW 4 EXETER BIT WORRIED!x\n'],
#  [0,
#   "Today i'm not workin but not free oso... Gee... Thgt u workin at ur fren's shop ? \n"],
#  [0,
#   'HI DARLIN I FINISH AT 3 DO U 1 2 PICK ME UP OR MEET ME? TEXT BACK ON THIS NUMBER LUV KATE XXX\n'],
#  [0,
#   'I know you are thinkin malaria. But relax, children cant handle malaria. She would have been worse and its gastroenteritis. If she takes enough to replace her loss her temp will reduce. And if you give her malaria meds now she will just vomit. Its a self limiting illness she has which means in a few days it will completely stop\n'],
#  [0, 'Aldrine, rakhesh ex RTM here.pls call.urgent.\n'],
#  [1,
#   'URGENT This is our 2nd attempt to contact U. Your £900 prize from YESTERDAY is still awaiting collection. To claim CALL NOW 09061702893. ACL03530150PM\n'],
#  [0, 'I dont understand your message.\n'],
#  [1,
#   'FREE RING TONE just text "POLYS" to 87131. Then every week get a new tone. 0870737910216yrs only £1.50/wk.\n'],
#  [0, 'Lol great now im getting hungry.\n'],
#  [0, 'Yes, princess. Toledo.\n'],
#  [0,
#   'No. Its not specialisation. Can work but its slave labor. Will look for it this month sha cos no shakara 4 beggar.\n'],
#  [0,
#   'Thats a bit weird, even ?- where is the do supposed to be happening? But good idea, sure they will be in pub!\n'],
#  [0, 'No did you check? I got his detailed message now\n'],
#  [0, 'HEY MATE! HOWS U HONEY?DID U AVE GOOD HOLIDAY? GIMMI DE GOSS!x\n'],
#  [0,
#   'Open rebtel with firefox. When it loads just put plus sign in the user name place, and it will show you two numbers. The lower number is my number. Once you pick that number the pin will display okay!\n'],
#  [0,
#   'Ah poop. Looks like ill prob have to send in my laptop to get fixed cuz it has a gpu problem\n'],
#  [0,
#   'Hmm...Bad news...Hype park plaza $700 studio taken...Only left 2 bedrm-$900...\n'],
#  [0, 'Ü no home work to do meh... \n'],
#  [0, 'Yay! You better not have told that to 5 other girls either.\n'],
#  [0,
#   'Guess who spent all last night phasing in and out of the fourth dimension\n'],
#  [0,
#   "Congrats. That's great. I wanted to tell you not to tell me your score cos it might make me relax. But its motivating me so thanks for sharing\n"],
#  [0, 'And popping &lt;#&gt; ibuprofens was no help.\n'],
#  [0, 'Try neva mate!!\n'],
#  [0,
#   "Watching tv lor... Y she so funny we bluff her 4 wat. Izzit because she thk it's impossible between us?\n"],
#  [0, 'Orh i tot u say she now still dun believe.\n'],
#  [0, 'Where are you ? You said you would be here when I woke ... :-(\n'],
#  [0, 'Geeeee ... I love you so much I can barely stand it\n'],
#  [0,
#   'Cool breeze... Bright sun... Fresh flower... Twittering birds... All these waiting to wish u: "GOODMORNING &amp; HAVE A NICE DAY" :)\n'],
#  [0,
#   " says that he's quitting at least5times a day so i wudn't take much notice of that. Nah, she didn't mind. Are you gonna see him again? Do you want to come to taunton tonight? U can tell me all about !\n"],
#  [1, 'Adult 18 Content Your video will be with you shortly\n'],
#  [0, 'Same. Wana plan a trip sometme then\n'],
#  [0,
#   "that would be good … I'll phone you tomo lunchtime, shall I, to organise something?\n"],
#  [0,
#   'Happy or sad , one thing about past is- "Its no more" GOOD MORNING :-):-).\n'],
#  [0, ' &lt;#&gt;  mins but i had to stop somewhere first.\n'],
#  [0, 'Oh ho. Is this the first time u use these type of words\n'],
#  [0, 'I think steyn surely get one wicket:)\n'],
#  [0, 'Can u look 4 me in da lib i got stuff havent finish yet.\n'],
#  [0, 'Hai priya are you right. What doctor said pa. Where are you.\n'],
#  [0,
#   'U ned to convince him tht its not possible witot hurting his feeling its the main\n'],
#  [0, 'Not directly behind... Abt 4 rows behind ü...\n'],
#  [0, 'K..k.:)congratulation ..\n'],
#  [0, 'Moji i love you more than words. Have a rich day\n'],
#  [0, 'Lol ... I knew that .... I saw him in the dollar store\n'],
#  [0, 'is your hamster dead? Hey so tmr i meet you at 1pm orchard mrt? \n'],
#  [1,
#   'Update_Now - 12Mths Half Price Orange line rental: 400mins...Call MobileUpd8 on 08000839402 or call2optout=J5Q\n'],
#  [0,
#   "I dun thk i'll quit yet... Hmmm, can go jazz ? Yogasana oso can... We can go meet em after our lessons den... \n"],
#  [0,
#   'How are you with moneY...as in to you...money aint a thing....how are you sha!\n'],
#  [0, 'K..k:)how much does it cost?\n'],
#  [0, "Honey boo I'm missing u.\n"],
#  [0,
#   'Ok lor... Sony ericsson salesman... I ask shuhui then she say quite gd 2 use so i considering...\n'],
#  [0, 'Yes.. now only saw your message..\n'],
#  [0,
#   'Hi juan. Im coming home on fri hey. Of course i expect a welcome party and lots of presents. Ill phone u when i get back. Loads of love nicky x x x x x x x x x\n'],
#  [0,
#   'Nowadays people are notixiquating the laxinorficated opportunity for bambling of entropication.... Have you ever oblisingately opted ur books for the masteriastering amplikater of fidalfication? It is very champlaxigating, i think it is atrocious.. Wotz Ur Opinion???? Junna\n'],
#  [0, 'Then wat r u doing now? Busy wif work?\n'],
#  [0, 'You know there is. I shall speak to you in  &lt;#&gt;  minutes then\n'],
#  [0, 'Some friends want me to drive em someplace, probably take a while\n'],
#  [0,
#   "I can't believe how attached I am to seeing you every day. I know you will do the best you can to get to me babe. I will go to teach my class at your midnight\n"],
#  [0,
#   "How's it going? Got any exciting karaoke type activities planned? I'm debating whether to play football this eve. Feeling lazy though.\n"],
#  [0,
#   "So how are you really. What are you up to. How's the masters. And so on.\n"],
#  [0,
#   'Okay lor... Will they still let us go a not ah? Coz they will not know until later. We drop our cards into the box right?\n'],
#  [0,
#   "Don't necessarily expect it to be done before you get back though because I'm just now headin out\n"],
#  [0,
#   'FRAN I DECIDED 2 GO N E WAY IM COMPLETELY BROKE AN KNACKERED I GOT UP BOUT 3 C U 2MRW LOVE JANX P.S THIS IS MY DADS FONE, -NO CREDIT\n'],
#  [0, 'Ok no prob. Take ur time.\n'],
#  [0, 'Call me when u finish then i come n pick u.\n'],
#  [0, "Prabha..i'm soryda..realy..frm heart i'm sory\n"],
#  [0,
#   'What do you do, my dog ? Must I always wait till the end of your day to have word from you ? Did you run out of time on your cell already?\n'],
#  [0,
#   'Yup i thk they r e teacher said that will make my face look longer. Darren ask me not 2 cut too short.\n'],
#  [0, 'O was not into fps then.\n'],
#  [0, 'i want to grasp your pretty booty :)\n'],
#  [0, 'Wife.how she knew the time of murder exactly\n'],
#  [0, "Sorry, I'll call you  later. I am in meeting sir.\n"],
#  [0,
#   'Ahhhh...just woken up!had a bad dream about u tho,so i dont like u right now :) i didnt know anything about comedy night but i guess im up for it.\n'],
#  [0, 'Stupid.its not possible\n'],
#  [0, "U don't remember that old commercial?\n"],
#  [0, 'Yesterday its with me only . Now am going home.\n'],
#  [0, "I'll be in sch fr 4-6... I dun haf da book in sch... It's at home...\n"],
#  [0, "That's cause your old. I live to be high.\n"],
#  [0, "If you're thinking of lifting me one then no.\n"],
#  [0,
#   "When people see my msgs, They think Iam addicted to msging... They are wrong, Bcoz They don\\'t know that Iam addicted to my sweet Friends..!! BSLVYL\n"],
#  [0,
#   'Jokin only lar... :-) depends on which phone my father can get lor...\n'],
#  [0,
#   "Sorry man, my stash ran dry last night and I can't pick up more until sunday\n"],
#  [0, "U sure u can't take any sick time?\n"],
#  [0,
#   'Wow ... I love you sooo much, you know ? I can barely stand it ! I wonder how your day goes and if you are well, my love ... I think of you and miss you\n'],
#  [0,
#   'Boo what time u get out? U were supposed to take me shopping today. :(\n'],
#  [0,
#   'Kind of. Just missed train cos of asthma attack, nxt one in half hr so driving in. not sure where to park.\n'],
#  [1,
#   "I don't know u and u don't know me. Send CHAT to 86688 now and let's find each other! Only 150p/Msg rcvd. HG/Suite342/2Lands/Row/W1J6HL LDN. 18 years or over.\n"],
#  [0, 'Wat time liao, where still got.\n'],
#  [0, 'My battery is low babe\n'],
#  [0, 'Ok.\n'],
#  [0, 'Nan sonathaya soladha. Why boss?\n'],
#  [1,
#   'Congratulations ur awarded 500 of CD vouchers or 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC to 87066 TnCs www.Ldew.com1win150ppmx3age16\n'],
#  [0,
#   'This single single answers are we fighting? Plus i said am broke and you didnt reply\n'],
#  [0,
#   'Im sorry bout last nite it wasn\x92t ur fault it was me, spouse it was pmt or sumthin! U 4give me? I think u shldxxxx\n'],
#  [0,
#   'Call him and say you not coming today ok and tell them not to fool me like this ok\n'],
#  [0,
#   'Do u konw waht is rael FRIENDSHIP Im gving yuo an exmpel: Jsut ese tihs msg.. Evrey splleing of tihs msg is wrnog.. Bt sitll yuo can raed it wihtuot ayn mitsake.. GOODNIGHT &amp; HAVE A NICE SLEEP..SWEET DREAMS..\n'],
#  [0, 'I will reach before ten morning\n'],
#  [0,
#   "Daddy, shu shu is looking 4 u... U wan me 2 tell him u're not in singapore or wat?\n"],
#  [0, 'Wat time u finish ur lect today?\n'],
#  [0, 'Yes see ya not on the dot\n'],
#  [0,
#   "Sounds like a plan! Cardiff is still here and still cold! I'm sitting on the radiator!\n"],
#  [0, 'Cuz ibored. And don wanna study\n'],
#  [0,
#   'No da:)he is stupid da..always sending like this:)don believe any of those message.pandy is a mental:)\n'],
#  [0, "I can't describe how lucky you are that I'm actually awake by noon\n"],
#  [1,
#   'WOW! The Boys R Back. TAKE THAT 2007 UK Tour. Win VIP Tickets & pre-book with VIP Club. Txt CLUB to 81303. Trackmarque Ltd info@vipclub4u.\n'],
#  [0, "I'll probably be around mu a lot\n"],
#  [0,
#   'I want to send something that can sell fast.  &lt;#&gt; k is not easy money.\n'],
#  [0, 'I want  &lt;#&gt;  rs da:)do you have it?\n'],
#  [0,
#   "Under the sea, there lays a rock. In the rock, there is an envelope. In the envelope, there is a paper. On the paper, there are 3 words... '\n"],
#  [0, 'Why are u up so early?\n'],
#  [0, 'ok....take care.umma to you too...\n'],
#  [0, 'Nope... Juz off from work...\n'],
#  [0,
#   "Miserable. They don't tell u that the side effects of birth control are massive gut wrenching cramps for the first 2 months. I didn't sleep at all last night.\n"],
#  [0, 'Gud gud..k, chikku tke care.. sleep well gud nyt\n'],
#  [0, 'Uhhhhrmm isnt having tb test bad when youre sick\n'],
#  [0, "I'm thinking that chennai forgot to come for auction..\n"],
#  [1,
#   'Your credits have been topped up for http://www.bubbletext.com Your renewal Pin is tgxxrz\n'],
#  [1,
#   "FreeMsg Why haven't you replied to my text? I'm Randy, sexy, female and live local. Luv to hear from u. Netcollex Ltd 08700621170150p per msg reply Stop to end\n"],
#  [1,
#   'FREE MESSAGE Activate your 500 FREE Text Messages by replying to this message with the word FREE For terms & conditions, visit www.07781482378.com\n'],
#  [0, ';-( oh well, c u later\n'],
#  [0, 'get ready to moan and scream :)\n'],
#  [1,
#   'URGENT! Your Mobile number has been awarded a <UKP>2000 prize GUARANTEED. Call 09061790125 from landline. Claim 3030. Valid 12hrs only 150ppm\n'],
#  [0, "I've reached home n i bathe liao... U can call me now...\n"],
#  [0, "What i mean was i left too early to check, cos i'm working a 9-6.\n"],
#  [0, 'Probably a couple hours tops\n'],
#  [0,
#   'You at mu? You should try to figure out how much money everyone has for gas and alcohol, jay and I are trying to figure out our weed budget\n'],
#  [0, "Am I the only one who doesn't stalk profiles?\n"],
#  [0, 'Bugis oso near wat... \n'],
#  [0, 'Yes when is the appt again?\n'],
#  [0, 'Hi its in durban are you still on this number\n'],
#  [0, 'Thinkin about someone is all good. No drugs for that\n'],
#  [0, "Alright. I'm out--have a good night!\n"],
#  [0,
#   "Too late. I said i have the website. I didn't i have or dont have the slippers\n"],
#  [0, 'Come to mahal bus stop.. &lt;DECIMAL&gt;\n'],
#  [0, "Sorry, I'll call later\n"],
#  [0,
#   'The fact that you\'re cleaning shows you know why i\'m upset. Your priority is constantly "what i want to do," not "what i need to do."\n'],
#  [0,
#   'Never blame a day in ur life. Good days give u happiness. Bad days give u experience. Both are essential in life! All are Gods blessings! good morning.:\n'],
#  [0, 'No. Did you multimedia message them or e-mail?\n'],
#  [0,
#   'You do your studies alone without anyones help. If you cant no need to study.\n'],
#  [0, 'Oh ic. I thought you meant mary jane.\n'],
#  [0, 'Have a good evening! Ttyl\n'],
#  [1,
#   'Todays Voda numbers ending 5226 are selected to receive a ?350 award. If you hava a match please call 08712300220 quoting claim code 1131 standard rates app \n'],
#  [0,
#   "I dont have any of your file in my bag..i was in work when you called me.i 'll tell you if i find anything in my room.\n"],
#  [1,
#   "Get a FREE mobile video player FREE movie. To collect text GO to 89105. Its free! Extra films can be ordered t's and c's apply. 18 yrs only\n"],
#  [0, 'I AM AT THE GAS STATION. GO THERE.\n'],
#  [0,
#   'If you want to mapquest it or something look up "usf dogwood drive", that\'s the tiny street where the parking lot is\n'],
#  [0,
#   'Hurt me... Tease me... Make me cry... But in the end of my life when i die plz keep one rose on my grave and say STUPID I MISS U.. HAVE A NICE DAY BSLVYL\n'],
#  [0, 'No calls..messages..missed calls\n'],
#  [0,
#   'Havent planning to buy later. I check already lido only got 530 show in e afternoon. U finish work already?\n'],
#  [0, "Sorry, I'll call later\n"],
#  [0, 'Rofl. Its true to its name\n'],
#  [1,
#   "Oh my god! I've found your number again! I'm so glad, text me back xafter this msgs cst std ntwk chg £1.50\n"],
#  [0, "Awesome, I'll see you in a bit\n"],
#  [0,
#   'Hurt me... Tease me... Make me cry... But in the end of my life when i die plz keep one rose on my grave and say STUPID I MISS U.. HAVE A NICE DAY BSLVYL\n'],
#  [1,
#   'Ur cash-balance is currently 500 pounds - to maximize ur cash-in now send CASH to 86688 only 150p/msg. CC: 08718720201 PO BOX 114/14 TCR/W1\n'],
#  [0, 'Oh k:)after that placement there ah?\n'],
#  [0, 'Got it. Seventeen pounds for seven hundred ml – hope ok.\n'],
#  [0,
#   'Thanks again for your reply today. When is ur visa coming in. And r u still buying the gucci and bags. My sister things are not easy, uncle john also has his own bills so i really need to think about how to make my own money. Later sha.\n'],
#  [0,
#   'God picked up a flower and dippeditinaDEW, lovingly touched itwhichturnedinto u, and the he gifted tomeandsaid,THIS FRIEND IS 4U\n'],
#  [0, 'Ard 530 lor. I ok then message ü lor.\n'],
#  [0, 'Remember on that day..\n'],
#  [0, 'Then ü come n pick me at 530 ar?\n'],
#  [0, "Awesome, lemme know whenever you're around\n"],
#  [0,
#   'Dis is yijue. I jus saw ur mail. In case huiming havent sent u my num. Dis is my num.\n'],
#  [0,
#   'Ok lar i double check wif da hair dresser already he said wun cut v short. He said will cut until i look nice.\n'],
#  [0, 'I havent lei.. Next mon can?\n'],
#  [0,
#   "Sorry. You never hear unless you book it. One was kinda a joke--thet were really looking for skinny white girls. The other was one line--you can only do so much on camera with that. Something like that they're casting on the look.\n"],
#  [0,
#   'I am back. Bit long cos of accident on a30. Had to divert via wadebridge.I had a brilliant weekend thanks. Speak soon. Lots of love\n'],
#  [1,
#   'This is the 2nd time we have tried 2 contact u. U have won the £750 Pound prize. 2 claim is easy, call 087187272008 NOW1! Only 10p per minute. BT-national-rate.\n'],
#  [0, 'Understand. his loss is my gain :) so do you work? School?\n'],
#  [0, 'MMM ... Fuck .... Merry Christmas to me\n'],
#  [0, 'Well i will watch shrek in 3D!!B)\n'],
#  [0, 'Ok enjoy . R u there in home.\n'],
#  [0, 'Alright, see you in a bit\n'],
#  [0,
#   'Now only i reached home. . . I am very tired now. . I will come tomorro\n'],
#  [0,
#   'Hi there. We have now moved in2 our pub . Would be great 2 c u if u cud come up.\n'],
#  [0, "Yo you around? A friend of mine's lookin to pick up later tonight\n"],
#  [0, 'Its just the effect of irritation. Just ignore it\n'],
#  [0, 'Ok try to do week end course in coimbatore.\n'],
#  [0, 'Sorry da. I gone mad so many pending works what to do.\n'],
#  [0, "We'll join the  &lt;#&gt;  bus\n"],
#  [0, 'Mm i had my food da from out\n'],
#  [0,
#   'Sweetheart, hope you are not having that kind of day! Have one with loads of reasons to smile. Biola\n'],
#  [0,
#   "If i not meeting ü all rite then i'll go home lor. If ü dun feel like comin it's ok.\n"],
#  [0,
#   'Busy here. Trying to finish for new year. I am looking forward to finally meeting you...\n'],
#  [1,
#   'Ur cash-balance is currently 500 pounds - to maximize ur cash-in now send GO to 86688 only 150p/msg. CC 08718720201 HG/Suite342/2Lands Row/W1J6HL\n'],
#  [0, 'Ü still got lessons?  Ü in sch?\n'],
#  [1,
#   'Customer Loyalty Offer:The NEW Nokia6650 Mobile from ONLY £10 at TXTAUCTION! Txt word: START to No: 81151 & get yours Now! 4T&Ctxt TC 150p/MTmsg\n'],
#  [0,
#   'Wn u r hurt by d prsn who s close 2 u, do fight wit dem. Coz somtimes dis fight saves a relation bt being quiet leaves nothin in a relation.. Gud eveB-)\n'],
#  [0, 'staff.science.nus.edu.sg/~phyhcmk/teaching/pc1323\n'],
#  [0,
#   "I couldn't say no as he is a dying man and I feel sad for him so I will go and I just wanted you to know I would probably be gone late into your night\n"],
#  [0, 'Try to do something dear. You read something for exams\n'],
#  [0, 'Probably gonna swing by in a wee bit\n'],
#  [0, 'Same as kallis dismissial in 2nd test:-).\n'],
#  [0, 'Dunno lei... I thk mum lazy to go out... I neva ask her yet...\n'],
#  [1,
#   'PRIVATE! Your 2003 Account Statement for 07808247860 shows 800 un-redeemed S. I. M. points. Call 08719899229 Identifier Code: 40411 Expires 06/11/04\n'],
#  [0, 'When i have stuff to sell i.ll tell you\n'],
#  [0, 'Hope you are having a good week. Just checking in\n'],
#  [0, 'My fri ah... Okie lor,goin 4 my drivin den go shoppin after tt...\n'],
#  [0,
#   'How dare you stupid. I wont tell anything to you. Hear after i wont talk to you:-.\n'],
#  [0, "Sorry, I can't text &amp; drive coherently, see you in twenty\n"],
#  [0,
#   'Was actually sleeping and still might when u call back. So a text is gr8. You rock sis. Will send u a text wen i wake.\n'],
#  [0, 'Yeah, probably earlier than that\n'],
#  [0,
#   'I actually did for the first time in a while. I went to bed not too long after i spoke with you. Woke up at 7. How was your night?\n'],
#  [0, 'True. Its easier with her here.\n'],
#  [0, 'When you get free, call me\n'],
#  [0,
#   'Imagine you finally get to sink into that bath after I have put you through your paces, maybe even having you eat me for a while before I left ... But also imagine the feel of that cage on your cock surrounded by the bath water, reminding you always who owns you ... Enjoy, my cuck\n'],
#  [0, 'Ok lor wat time ü finish?\n'],
#  [0, 'I think if he rule tamilnadu..then its very tough for our people.\n'],
#  [0, 'life alle mone,eppolum oru pole allalo\n'],
#  [0,
#   'Every King Was Once A Crying Baby And Every Great Building Was Once A Map.. Not Imprtant Where U r TODAY, BUT Where U Wil Reach TOMORW. Gud ni8\n'],
#  [1,
#   "Refused a loan? Secured or Unsecured? Can't get credit? Call free now 0800 195 6669 or text back 'help' & we will!\n"],
#  [0,
#   "U don't know how stubborn I am. I didn't even want to go to the hospital. I kept telling Mark I'm not a weak sucker. Hospitals are for weak suckers.\n"],
#  [1,
#   "FreeMsg: Hey - I'm Buffy. 25 and love to satisfy men. Home alone feeling randy. Reply 2 C my PIX! QlynnBV Help08700621170150p a msg Send stop to stop txts\n"],
#  [1,
#   'WELL DONE! Your 4* Costa Del Sol Holiday or £5000 await collection. Call 09050090044 Now toClaim. SAE, TCs, POBox334, Stockport, SK38xh, Cost£1.50/pm, Max10mins\n'],
#  [0,
#   'Wat makes some people dearer is not just de happiness dat u feel when u meet them but de pain u feel when u miss dem!!!\n'],
#  [1,
#   'Dear Dave this is your final notice to collect your 4* Tenerife Holiday or #5000 CASH award! Call 09061743806 from landline. TCs SAE Box326 CW25WX 150ppm\n'],
#  [0, "No. To be nosy I guess. Idk am I over reacting if I'm freaked?\n"],
#  [0, 'Er yep sure. Props?\n'],
#  [1,
#   'FreeMSG You have been awarded a FREE mini DIGITAL CAMERA, just reply SNAP to collect your prize! (quizclub Opt out? Stop 80122300p/wk SP:RWM Ph:08704050406)\n'],
#  [0, 'Sounds great! Im going to sleep now. Have a good night!\n'],
#  [1,
#   '500 New Mobiles from 2004, MUST GO! Txt: NOKIA to No: 89545 & collect yours today!From ONLY £1 www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18 TXTAUCTION\n'],
#  [0,
#   "If you hear a loud scream in about &lt;#&gt; minutes its cause my Gyno will be shoving things up me that don't belong :/\n"],
#  [0, 'I cant wait to see you! How were the photos were useful? :)\n'],
#  [0,
#   'And miss vday the parachute and double coins??? U must not know me very well...\n'],
#  [0, 'I dont knw pa, i just drink milk..\n'],
#  [1,
#   'How about getting in touch with folks waiting for company? Just txt back your NAME and AGE to opt in! Enjoy the community (150p/SMS)\n'],
#  [0,
#   'I dont know ask to my brother. Nothing problem some thing that. Just i told .\n'],
#  [0, 'Ok. I.ll do you right later.\n'],
#  [0, 'Now get step 2 outta the way. Congrats again.\n'],
#  [0, 'Am in film ill call you later.\n'],
#  [1,
#   "I don't know u and u don't know me. Send CHAT to 86688 now and let's find each other! Only 150p/Msg rcvd. HG/Suite342/2Lands/Row/W1J6HL LDN. 18 years or over.\n"],
#  [0, 'Ok i also wan 2 watch e 9 pm show...\n'],
#  [0, "I'll text you when I drop x off\n"],
#  [0, 'Do you know when the result.\n'],
#  [0,
#   "The last thing i ever wanted to do was hurt you. And i didn't think it would have. You'd laugh, be embarassed, delete the tag and keep going. But as far as i knew, it wasn't even up. The fact that you even felt like i would do it to hurt you shows you really don't know me at all. It was messy wednesday, but it wasn't bad. The problem i have with it is you HAVE the time to clean it, but you choose not to. You skype, you take pictures, you sleep, you want to go out. I don't mind a few things here and there, but when you don't make the bed, when you throw laundry on top of it, when i can't have a friend in the house because i'm embarassed that there's underwear and bras strewn on the bed, pillows on the floor, that's something else. You used to be good about at least making the bed.\n"],
#  [0, 'Ü got wat to buy tell us then ü no need to come in again.\n'],
#  [0, 'Hey gals...U all wanna meet 4 dinner at nìte? \n'],
#  [1,
#   'TheMob> Check out our newest selection of content, Games, Tones, Gossip, babes and sport, Keep your mobile fit and funky text WAP to 82468\n'],
#  [0,
#   'Hello. They are going to the village pub at 8 so either come here or there accordingly. Ok?\n'],
#  [1,
#   'Thanks for your ringtone order, ref number R836. Your mobile will be charged £4.50. Should your tone not arrive please call customer services on 09065069154\n'],
#  [0, "Still at west coast... Haiz... Ü'll take forever to come back...\n"],
#  [0, "Sorry, I'll call later\n"],
#  [0, 'I have no money 4 steve mate! !\n'],
#  [0,
#   'Hey so this sat are we going for the intro pilates only? Or the kickboxing too? \n'],
#  [0, 'Aaooooright are you at work?\n'],
#  [0,
#   '"HI BABE UAWAKE?FEELLIKW SHIT.JUSTFOUND OUT VIA ALETTER THATMUM GOTMARRIED 4thNOV.BEHIND OURBACKS \x96 FUCKINNICE!SELFISH,DEVIOUSBITCH.ANYWAY,I\x92L CALL U"\n'],
#  [0,
#   "That's good. Lets thank God. Please complete the drug. Have lots of water. And have a beautiful day.\n"],
#  [0, 'Wow v v impressed. Have funs shopping!\n'],
#  [0,
#   'When did i use soc... I use it only at home... Ü dunno how 2 type it in word ar...\n'],
#  [0,
#   "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.\n"],
#  [0,
#   'They said if its gonna snow, it will start around 8 or 9 pm tonite! They are predicting an inch of accumulation.\n'],
#  [1,
#   "500 free text msgs. Just text ok to 80488 and we'll credit your account\n"],
#  [0,
#   "Hi Dear Call me its urgnt. I don't know whats your problem. You don't want to work or if you have any other problem at least tell me. Wating for your reply.\n"],
#  [0, 'Yo my trip got postponed, you still stocked up?\n'],
#  [0,
#   "Keep yourself safe for me because I need you and I miss you already and I envy everyone that see's you in real life\n"],
#  [0,
#   "So your telling me I coulda been your real Valentine and I wasn't? U never pick me for NOTHING!!\n"],
#  [1,
#   '83039 62735=£450 UK Break AccommodationVouchers terms & conditions apply. 2 claim you mustprovide your claim number which is 15541 \n'],
#  [0, 'Its ok, if anybody asks abt me, u tel them..:-P\n'],
#  [0, 'Then any special there?\n'],
#  [0, 'happened here while you were adventuring\n'],
#  [0,
#   "But i'm really really broke oh. No amount is too small even  &lt;#&gt; \n"],
#  [0, 'I am real, baby! I want to bring out your inner tigress...\n'],
#  [0, "Cool, I'll text you when I'm on the way\n"],
#  [0,
#   "Sorry I flaked last night, shit's seriously goin down with my roommate, what you up to tonight?\n"],
#  [0, 'Lets use it next week, princess :)\n'],
#  [0, 'i cant talk to you now.i will call when i can.dont keep calling.\n'],
#  [0, "I only haf msn. It's yijue@hotmail.com\n"],
#  [0, 'So when do you wanna gym harri\n'],
#  [0, 'Hey do you want anything to buy:)\n'],
#  [0, "Thanks, I'll keep that in mind\n"],
#  [0,
#   "Yar i wanted 2 scold u yest but late already... I where got zhong se qing you? If u ask me b4 he ask me then i'll go out w u all lor. N u still can act so real.\n"],
#  [0, "R u sure they'll understand that! Wine * good idea just had a slurp!\n"],
#  [0, 'How much for an eighth?\n'],
#  [0,
#   'Nothing but we jus tot u would ask cos u ba gua... But we went mt faber yest... Yest jus went out already mah so today not going out... Jus call lor...\n'],
#  [1,
#   'SIX chances to win CASH! From 100 to 20,000 pounds txt> CSH11 and send to 87575. Cost 150p/day, 6days, 16+ TsandCs apply Reply HL 4 info\n'],
#  [0, 'O. Guess they both got screwd\n'],
#  [0, 'I place all ur points on e cultures module already.\n'],
#  [0,
#   'First has she gained more than  &lt;#&gt; kg since she took in. Second has she done the blood sugar tests. If she has and its ok and her blood pressure is within normal limits then no worries\n'],
#  [0, 'Sorry da..today i wont come to play..i have driving clas..\n'],
#  [0,
#   "I told her I had a Dr appt next week. She thinks I'm gonna die. I told her its just a check. Nothing to be worried about. But she didn't listen.\n"],
#  [0, 'Hello- thanx for taking that call. I got a job! Starts on monday!\n'],
#  [0,
#   '"Hi missed your Call and my mumHas beendropping red wine all over theplace! what is your adress?"\n'],
#  [0, 'Will ü b going to esplanade fr home?\n'],
#  [0, 'No. I.ll meet you in the library\n'],
#  [0, 'Many times we lose our best ones bcoz we are \n'],
#  [0,
#   'Good afternoon on this glorious anniversary day, my sweet J !! I hope this finds you happy and content, my Prey. I think of you and send a teasing kiss from across the sea coaxing images of fond souveniers ... You Cougar-Pen\n'],
#  [0, 'If you r @ home then come down within 5 min\n'],
#  [0,
#   'Olol i printed out a forum post by a guy with the exact same  prob which was fixed with a gpu replacement. Hopefully they dont ignore that.\n'],
#  [0,
#   "Ugh its been a long day. I'm exhausted. Just want to cuddle up and take a nap\n"],
#  [0, 'Watching tv lor...\n'],
#  [0, "It's ok, at least armand's still around\n"],
#  [1,
#   'Promotion Number: 8714714 - UR awarded a City Break and could WIN a £200 Summer Shopping spree every WK. Txt STORE to 88039 . SkilGme. TsCs087147403231Winawk!Age16 £1.50perWKsub\n'],
#  [0,
#   'Im in inperialmusic listening2the weirdest track ever by\x94leafcutter john\x94-sounds like insects being molested&someone plumbing,remixed by evil men on acid!\n'],
#  [0, 'I donno its in your genes or something\n'],
#  [0,
#   "I wasn't well babe, i have swollen glands at my throat ... What did you end up doing ?\n"],
#  [0,
#   "Oh, the grand is having a bit of a party but it doesn't mention any cover charge so it's probably first come first served\n"],
#  [0, 'Ha ha - had popped down to the loo when you hello-ed me. Hello!\n'],
#  [0,
#   'Argh my 3g is spotty, anyway the only thing I remember from the research we did was that province and sterling were the only problem-free places we looked at\n'],
#  [0,
#   'Hey loverboy! I love you !! I had to tell ... I look at your picture and ache to feel you between my legs ... Fuck I want you ... I need you ... I crave you .\n'],
#  [0,
#   "You are always putting your business out there. You put pictures of your ass on facebook. You are one of the most open people i've ever met. Why would i think a picture of your room would hurt you, make you feel violated.\n"],
#  [0,
#   "Yes I started to send requests to make it but pain came back so I'm back in bed. Double coins at the factory too. I gotta cash in all my nitros.\n"],
#  [0,
#   'Wylie update: my weed dealer carlos went to freedom and had a class with lunsford\n'],
#  [1,
#   'GENT! We are trying to contact you. Last weekends draw shows that you won a £1000 prize GUARANTEED. Call 09064012160. Claim Code K52. Valid 12hrs only. 150ppm \n'],
#  [0,
#   'Jane babes not goin 2 wrk, feel ill after lst nite. Foned in already cover 4 me chuck.:-)\n'],
#  [0, 'This pay is  &lt;DECIMAL&gt;  lakhs:)\n'],
#  [0, 'Waiting for your call.\n'],
#  [0, 'Jesus armand really is trying to tell everybody he can find\n'],
#  [0, "Sorry, I can't help you on this.\n"],
#  [1,
#   "URGENT! Last weekend's draw shows that you have won £1000 cash or a Spanish holiday! CALL NOW 09050000332 to claim. T&C: RSTM, SW7 3SS. 150ppm\n"],
#  [0,
#   'We are at grandmas. Oh dear, u still ill? I felt Shit this morning but i think i am just hungover! Another night then. We leave on sat.\n'],
#  [0, 'Ok.. Ü finishing soon?\n'],
#  [0, "I call you later, don't have network. If urgnt, sms me.\n"],
#  [0, "Am slow in using biola's fne\n"],
#  [0,
#   "Don't worry though, I understand how important it is that I be put in my place with a poorly thought out punishment in the face of the worst thing that has ever happened to me. Brb gonna go kill myself\n"],
#  [0,
#   'Really... I tot ur paper ended long ago... But wat u copied jus now got use? U happy lar... I still haf 2 study :-(\n'],
#  [0,
#   'Sometimes Heart Remembrs someone Very much... Forgets someone soon... Bcoz Heart will not like everyone. But liked ones will be Remembered Everytime... BSLVYL\n'],
#  [0,
#   "You aren't coming home between class, right? I need to work out and shower!\n"],
#  [0, 'Whens your radio show?\n'],
#  [0, "Yeah right! I'll bring my tape measure fri!\n"],
#  [0, "I'm done...\n"],
#  [0,
#   "If you're still up, maybe leave the credit card so I can get gas when I get back like he told me to\n"],
#  [0, 'Free any day but i finish at 6 on mon n thurs...\n'],
#  [0, 'We can go 4 e normal pilates after our intro...  \n'],
#  [0, "That's very rude, you on campus?\n"],
#  [0, 'Is ur lecture over?\n'],
#  [0, 'Small problem in auction:)punj now asking tiwary\n'],
#  [0,
#   "If you can make it any time tonight or whenever you can it's cool, just text me whenever you're around\n"],
#  [0,
#   'Oh and by the way you do have more food in your fridge! Want to go out for a meal tonight? \n'],
#  [0,
#   "She just broke down a list of reasons why nobody's in town and I can't tell if she's being sarcastic or just faggy\n"],
#  [0, 'Shuhui say change 2 suntec steamboat? U noe where? Where r u now?\n'],
#  [0,
#   'Think you sent the text to the home phone. That cant display texts. If you still want to send it his number is\n'],
#  [0, 'Smith waste da.i wanna gayle.\n'],
#  [1,
#   'Hi 07734396839 IBH Customer Loyalty Offer: The NEW NOKIA6600 Mobile from ONLY £10 at TXTAUCTION!Txt word:START to No:81151 & get Yours Now!4T&\n'],
#  [0, 'Oi when you gonna ring\n'],
#  [1,
#   'HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd, PO Box 1327 Croydon CR9 5WB 0870..k\n'],
#  [0, 'Dear are you angry i was busy dear\n'],
#  [0,
#   "How's it feel? Mr. Your not my real Valentine just my yo Valentine even tho u hardly play!!\n"],
#  [0, 'Hi happy birthday. Hi hi hi hi hi hi hi\n'],
#  [1,
#   "Collect your VALENTINE'S weekend to PARIS inc Flight & Hotel + £200 Prize guaranteed! Text: PARIS to No: 69101. www.rtf.sphosting.com\n"],
#  [0, 'No probably  &lt;#&gt; %.\n'],
#  [1,
#   'Block Breaker now comes in deluxe format with new features and great graphics from T-Mobile. Buy for just £5 by replying GET BBDELUXE and take the challenge\n'],
#  [0, 'No no. I will check all rooms befor activities\n'],
#  [0,
#   '"Life is nothing wen v get everything". But "life is everything wen v miss something ". Real value of people wil be realized only in their absence.... gud mrng\n'],
#  [0,
#   "It's cool, let me know before it kicks off around  &lt;#&gt; , I'll be out and about all day\n"],
#  [0, 'India have to take lead:)\n'],
#  [0, 'Sounds like something that someone testing me would sayy\n'],
#  [0,
#   "As I entered my cabin my PA said, '' Happy B'day Boss !!''. I felt special. She askd me 4 lunch. After lunch she invited me to her apartment. We went there.\n"],
#  [0,
#   ', ,  and  picking them up from various points | going 2 yeovil | and they will do the motor project 4 3 hours | and then u take them home. || 12 2 5.30 max. || Very easy\n'],
#  [0, 'Hey u still at the gym?\n'],
#  [0, 'By monday next week. Give me the full gist\n'],
#  [0, "Sorry, I'll call later\n"],
#  [0,
#   'I am thinking of going down to reg for pract lessons.. Flung my advance.. Haha wat time u going?\n'],
#  [0,
#   "K, fyi I'm back in my parents' place in south tampa so I might need to do the deal somewhere else\n"],
#  [0, 'No need for the drug anymore.\n'],
#  [0, 'Left dessert. U wan me 2 go suntec look 4 u?\n'],
#  [0, 'I.ll hand her my phone to chat wit u\n'],
#  [0, 'I am waiting machan. Call me once you free.\n'],
#  [0, 'Prepare to be pleasured :)\n'],
#  [0, 'No no:)this is kallis home ground.amla home town is durban:)\n'],
#  [0, 'Play w computer? Aiyah i tok 2 u lor?\n'],
#  [0, 'Oh oh... Wasted... Den muz chiong on sat n sun liao...\n'],
#  [1,
#   'Hi, this is Mandy Sullivan calling from HOTMIX FM...you are chosen to receive £5000.00 in our Easter Prize draw.....Please telephone 09041940223 to claim before 29/03/05 or your prize will be transferred to someone else....\n'],
#  [0, 'Dear :-/ why you mood off. I cant drive so i brother to drive\n'],
#  [0, 'Headin towards busetop\n'],
#  [0, "I shall book chez jules for half eight, if that's ok with you?\n"],
#  [0,
#   'dont make ne plans for nxt wknd coz she wants us to come down then ok\n'],
#  [0,
#   "FR'NDSHIP is like a needle of a clock. Though V r in d same clock, V r nt able 2 met. Evn if V meet,itz only 4few seconds. Bt V alwys stay conected. Gud 9t;-)\n"],
#  [0, 'ALRITE SAM ITS NIC JUST CHECKIN THAT THIS IS UR NUMBER-SO IS IT?T.B*\n'],
#  [0, 'Oops I did have it,  &lt;#&gt; ?\n'],
#  [0,
# ...
#  [1,
#   'LORD OF THE RINGS:RETURN OF THE KING in store NOW!REPLY LOTR by 2 June 4 Chance 2 WIN LOTR soundtrack CDs StdTxtRate. Reply STOP to end txts\n'],
#  [0, 'Hmmm.still we dont have opener?\n'],
#  [1,
#   'You are now unsubscribed all services. Get tons of sexy babes or hunks straight to your phone! go to http://gotbabes.co.uk. No subscriptions.\n'],
#  [0, 'Are you the cutest girl in the world or what\n'],
#  [0, 'Where do you need to go to get it?\n'],
#  [0, 'O ic lol. Should play 9 doors sometime yo\n'],
#  [0,
#   'Have you bookedthe hut? And also your time off? How are you by the way?\n'],
#  [0,
#   "Lol yes. Our friendship is hanging on a thread cause u won't buy stuff.\n"],
#  [0,
#   "I forgot 2 ask ü all smth.. There's a card on da present lei... How? Ü all want 2 write smth or sign on it?\n"],
#  [0, 'What is the plural of the noun research?\n'],
#  [0, 'No da. . Vijay going to talk in jaya tv\n'],
#  [0, 'Okay, good, no problem, and thanx!\n'],
#  [0, 'Gud mrng dear hav a nice day\n'],
#  [0, "I'm home. Doc gave me pain meds says everything is fine.\n"],
#  [0, "Cool, text me when you're parked\n"],
#  [0, 'When u wana see it then\n'],
#  [0, 'Ü go home liao? Ask dad to pick me up at 6...\n'],
#  [1,
#   'Santa Calling! Would your little ones like a call from Santa Xmas eve? Call 09058094583 to book your time.\n'],
#  [0, 'Stupid.its not possible\n'],
#  [1,
#   'Call Germany for only 1 pence per minute! Call from a fixed line via access number 0844 861 85 85. No prepayment. Direct access!\n'],
#  [0,
#   'Al he does is moan at me if n e thin goes wrong its my fault&al de arguments r my fault&fed up of him of himso y bother? Hav 2go, thanx.xx\n'],
#  [0, 'Haha i think i did too\n'],
#  [0,
#   "Hi. I'm always online on yahoo and would like to chat with you someday\n"],
#  [0, '2 celebrate my b\x92day, y else?\n'],
#  [1,
#   'Had your contract mobile 11 Mnths? Latest Motorola, Nokia etc. all FREE! Double Mins & Text on Orange tariffs. TEXT YES for callback, no to remove from records\n'],
#  [1,
#   "Join the UK's horniest Dogging service and u can have sex 2nite!. Just sign up and follow the instructions. Txt ENTRY to 69888 now! Nyt.EC2A.3LP.msg@150p\n"],
#  [0, 'Haha awesome, omw back now then\n'],
#  [0, 'Since when, which side, any fever, any vomitin.\n'],
#  [0,
#   'You are everywhere dirt, on the floor, the windows, even on my shirt. And sometimes when i open my mouth, you are all that comes flowing out. I dream of my world without you, then half my chores are out too. A time of joy for me, lots of tv shows i.ll see. But i guess like all things you just must exist, like rain, hail and mist, and when my time here is done, you and i become one.\n'],
#  [0, "K I'll call you when I'm close\n"],
#  [0, 'You will be in the place of that man\n'],
#  [0,
#   "naughty little thought: 'its better to flirt, flirt n flirt, rather than loving someone n gettin hurt, hurt n hurt...:-) Gud nyt\n"],
#  [0, 'Hello madam how are you ?\n'],
#  [0, 'Still otside le..u come 2morrow maga..\n'],
#  [0,
#   'My house here e sky quite dark liao... If raining then got excuse not 2 run already rite... Hee...\n'],
#  [1,
#   'FREE for 1st week! No1 Nokia tone 4 ur mobile every week just txt NOKIA to 8077 Get txting and tell ur mates. www.getzed.co.uk POBox 36504 W45WQ 16+ norm150p/tone\n'],
#  [0, 'Sat right? Okay thanks... \n'],
#  [0, "Ok no problem... Yup i'm going to sch at 4 if i rem correctly...\n"],
#  [0, 'Does not operate after  &lt;#&gt;  or what\n'],
#  [0, 'HI BABE IM AT HOME NOW WANNA DO SOMETHING? XX\n'],
#  [0, "I dont. Can you send it to me. Plus how's mode.\n"],
#  [0, 'Goodmorning, Today i am late for  &lt;#&gt; min.\n'],
#  [0,
#   'I wont get concentration dear you know you are my mind and everything :-)\n'],
#  [0, 'Is that what time you want me to come?\n'],
#  [0, 'Your bill at 3 is £33.65 so thats not bad!\n'],
#  [0,
#   'Lol! U drunkard! Just doing my hair at d moment. Yeah still up 4 tonight. Wats the plan? \n'],
#  [0,
#   'Sorry light turned green, I meant another friend wanted  &lt;#&gt;  worth but he may not be around\n'],
#  [0,
#   'Allo! We have braved the buses and taken on the trains and triumphed. I mean we‘re in b‘ham. Have a jolly good rest of week\n'],
#  [0, 'Dare i ask... Any luck with sorting out the car?\n'],
#  [0, 'Fuck babe ... What happened to you ? How come you never came back?\n'],
#  [0, 'Check wid corect speling i.e. Sarcasm\n'],
#  [0,
#   "I miss you so much I'm so desparate I have recorded the message you left for me the other day and listen to it just to hear the sound of your voice. I love you\n"],
#  [0,
#   "What are you doing in langport? Sorry, but I'll probably be in bed by 9pm. It sucks being ill at xmas! When do you and go2sri lanka? \n"],
#  [0,
#   'Howz pain.it will come down today.do as i said ystrday.ice and medicine.\n'],
#  [0, 'What * u wearing?\n'],
#  [0,
#   'Dont hesitate. You know this is the second time she has had weakness like that. So keep i notebook of what she eat and did the day before or if anything changed the day before so that we can be sure its nothing\n'],
#  [1,
#   'U have a secret admirer. REVEAL who thinks U R So special. Call 09065174042. To opt out Reply REVEAL STOP. 1.50 per msg recd. Cust care 07821230901\n'],
#  [0,
#   'Went to pay rent. So i had to go to the bank to authorise the payment.\n'],
#  [0,
#   'Cool, we shall go and see, have to go to tip anyway. Are you at home, got something to drop in later? So lets go to town tonight! Maybe mum can take us in.\n'],
#  [0, 'Yes:)here tv is always available in work place..\n'],
#  [0,
#   "Fuck babe ... I miss you already, you know ? Can't you let me send you some money towards your net ? I need you ... I want you ... I crave you ...\n"],
#  [0, 'There is a first time for everything :)\n'],
#  [1,
#   'Mobile Club: Choose any of the top quality items for your mobile. 7cfca1a\n'],
#  [0,
#   'Yup... Hey then one day on fri we can ask miwa and jiayin take leave go karaoke \n'],
#  [1,
#   'This message is free. Welcome to the new & improved Sex & Dogging club! To unsubscribe from this service reply STOP. msgs@150p 18+only\n'],
#  [1,
#   'URGENT! Your mobile number *************** WON a £2000 Bonus Caller prize on 10/06/03! This is the 2nd attempt to reach you! Call 09066368753 ASAP! Box 97N7QP, 150ppm\n'],
#  [0, 'here is my new address -apples&pairs&all that malarky\n'],
#  [0, 'Thank you. I like you as well...\n'],
#  [0, 'Really good:)dhanush rocks once again:)\n'],
#  [0,
#   "Hmm. Shall i bring a bottle of wine to keep us amused? Just joking! I'll still bring a bottle. Red or white? See you tomorrow\n"],
#  [0,
#   'Lol grr my mom is taking forever with my prescription. Pharmacy is like 2 minutes away. Ugh.\n'],
#  [1,
#   "For ur chance to win a £250 wkly shopping spree TXT: SHOP to 80878. T's&C's www.txt-2-shop.com custcare 08715705022, 1x150p/wk\n"],
#  [0, 'Merry Christmas to you too babe, i love ya *kisses*\n'],
#  [0, 'Pls help me tell Ashley that i cant find her number oh\n'],
#  [0, "I'll let you know when it kicks in\n"],
#  [0, 'Please tell me not all of my car keys are in your purse\n'],
#  [0, 'S...i will take mokka players only:)\n'],
#  [0, 'Also are you bringing galileo or dobby\n'],
#  [0, "How are you. Its been ages. How's abj\n"],
#  [0, 'Ill be at yours in about 3 mins but look out for me\n'],
#  [0, 'U reach orchard already? U wan 2 go buy tickets first?\n'],
#  [0,
#   "How are you doing? Hope you've settled in for the new school year. Just wishin you a gr8 day\n"],
#  [0, 'Long beach lor. Expected... U having dinner now?\n'],
#  [0, "U're welcome... Caught u using broken english again...\n"],
#  [0, 'I am in tirupur.  call you da.\n'],
#  [0, 'So lets make it saturday or monday as per convenience.\n'],
#  [0, "Hi i won't b ard 4 christmas. But do enjoy n merry x'mas.\n"],
#  [1,
#   '<Forwarded from 448712404000>Please CALL 08712404000 immediately as there is an urgent message waiting for you.\n'],
#  [0, 'Text her. If she doesnt reply let me know so i can have her log in\n'],
#  [0, 'I have to take exam with in march 3\n'],
#  [0,
#   'Ok i wont call or disturb any one. I know all are avoiding me. I am a burden for all\n'],
#  [0, 'yes baby! I need to stretch open your pussy!\n'],
#  [0, 'Are you staying in town ?\n'],
#  [0, 'No..jst change tat only..\n'],
#  [0, "I'm going out to buy mum's present ar.\n"],
#  [0,
#   "I'm still looking for a car to buy. And have not gone 4the driving test yet.\n"],
#  [0, 'Whatever, juliana. Do whatever you want.\n'],
#  [0,
#   'It doesnt make sense to take it there unless its free. If you need to know more, wikipedia.com\n'],
#  [0, 'Am going to take bath ill place the key in window:-)\n'],
#  [0, 'Your daily text from me – a favour this time\n'],
#  [0,
#   'I will lick up every drop :) are you ready to use your mouth as well?\n'],
#  [0,
#   'Hi. Hope ur day * good! Back from walk, table booked for half eight. Let me know when ur coming over.\n'],
#  [0, 'If i said anything wrong sorry de:-)\n'],
#  [0, 'i felt so...not any conveying reason.. Ese he... What about me?\n'],
#  [0,
#   '"OH FUCK. JUSWOKE UP IN A BED ON A BOATIN THE DOCKS. SLEPT WID 25 YEAR OLD. SPINOUT! GIV U DA GOSSIP L8R. XXX"\n'],
#  [0, 'Ok... Take ur time n enjoy ur dinner...\n'],
#  [0, 'What about this one then.\n'],
#  [0, 'Why you Dint come with us.\n'],
#  [0, 'Not yet chikku..wat abt u?\n'],
#  [1,
#   "important information 4 orange user 0789xxxxxxx. today is your lucky day!2find out why log onto http://www.urawinner.com THERE'S A FANTASTIC SURPRISE AWAITING YOU!\n"],
#  [0,
#   'Bill, as in: Are there any letters for me. i’m expecting one from orange that isn’t a bill but may still say orange on it.\n'],
#  [0,
#   "Sorry vikky, i'm Watching olave mandara movie kano in trishul theatre wit my frnds..\n"],
#  [0,
#   'Is there any movie theatre i can go to and watch unlimited movies and just pay once?\n'],
#  [0,
#   'Yeah, in fact he just asked if we needed anything like an hour ago. When and how much?\n'],
#  [0,
#   "Ditto. And you won't have to worry about me saying ANYTHING to you anymore. Like i said last night, you do whatever you want and i'll do the same. Peace.\n"],
#  [0, 'Long after I quit. I get on only like 5 minutes a day as it is.\n'],
#  [0, 'Thats cool. i liked your photos. You are very sexy!\n'],
#  [0,
#   "I realise you are a busy guy and i'm trying not to be a bother. I have to get some exams outta the way and then try the cars. Do have a gr8 day\n"],
#  [0, 'Omg how did u know what I ate?\n'],
#  [0,
#   "I take it we didn't have the phone callon Friday. Can we assume we won't have it this year now?\n"],
#  [1,
#   'Guess what! Somebody you know secretly fancies you! Wanna find out who it is? Give us a call on 09065394514 From Landline DATEBox1282EssexCM61XN 150p/min 18\n'],
#  [0, 'As usual..iam fine, happy &amp; doing well..:)\n'],
#  [0, 'Ta-Daaaaa! I am home babe, are you still up ?\n'],
#  [0, "Me i'm not workin. Once i get job...\n"],
#  [0,
#   "You busy or can I come by at some point and figure out what we're doing tomorrow\n"],
#  [0,
#   'I think I‘m waiting for the same bus! Inform me when you get there, if you ever get there.\n'],
#  [0,
#   'K ill drink.pa then what doing. I need srs model pls send it to my mail id pa.\n'],
#  [0, 'Yeah whatever lol\n'],
#  [0,
#   "Doesn't g have class early tomorrow and thus shouldn't be trying to smoke at  &lt;#&gt;\n"],
#  [0, 'So can collect ur laptop?\n'],
#  [0, 'It took Mr owl 3 licks\n'],
#  [1,
#   'Congratulations U can claim 2 VIP row A Tickets 2 C Blu in concert in November or Blu gift guaranteed Call 09061104276 to claim TS&Cs www.smsco.net cost£3.75max \n'],
#  [0,
#   "Mystery solved! Just opened my email and he's sent me another batch! Isn't he a sweetie\n"],
#  [0,
#   'Should i buy him a blackberry bold 2 or torch. Should i buy him new or used. Let me know. Plus are you saying i should buy the  &lt;#&gt; g wifi ipad. And what are you saying about the about the  &lt;#&gt; g?\n'],
#  [0, 'Are you in castor? You need to see something\n'],
#  [0, "I'm done oredi...\n"],
#  [0, "Just come home. I don't want u to be miserable\n"],
#  [0,
#   'Aiyah e rain like quite big leh. If drizzling i can at least run home.\n'],
#  [0, "No chikku nt yet.. Ya i'm free\n"],
#  [0, 'I think your mentor is , but not 100 percent sure.\n'],
#  [0, "K, I'll work something out\n"],
#  [0, 'Got it..mail panren paru..\n'],
#  [0, 'Discussed with your mother ah?\n'],
#  [0, 'Waiting in e car 4 my mum lor. U leh? Reach home already?\n'],
#  [1,
#   'Would you like to see my XXX pics they are so hot they were nearly banned in the uk!\n'],
#  [0, 'Well welp is sort of a semiobscure internet thing\n'],
#  [0, 'Thanx a lot 4 ur help!\n'],
#  [0, 'Its normally hot mail. Com you see!\n'],
#  [0,
#   'Finally it has happened..! Aftr decades..! BEER is now cheaper than PETROL! The goverment expects us to "DRINK". . . But don\'t "DRIVE "\n'],
#  [1,
#   "Xmas & New Years Eve tickets are now on sale from the club, during the day from 10am till 8pm, and on Thurs, Fri & Sat night this week. They're selling fast!\n"],
#  [0,
#   'I know you are thinkin malaria. But relax, children cant handle malaria. She would have been worse and its gastroenteritis. If she takes enough to replace her loss her temp will reduce. And if you give her malaria meds now she will just vomit. Its a self limiting illness she has which means in a few days it will completely stop\n'],
#  [0, 'Good morning princess! How are you?\n'],
#  [0, 'Cramps stopped. Going back to sleep\n'],
#  [0, 'Thats cool! Sometimes slow and gentle. Sonetimes rough and hard :)\n'],
#  [0, 'How abt making some of the pics bigger?\n'],
#  [0, 'Thanx but my birthday is over already.\n'],
#  [0, 'And whenever you and i see we can still hook up too.\n'],
#  [0,
#   'Er, hello, things didn‘t quite go to plan – is limping slowly home followed by aa and with exhaust hanging off\n'],
#  [0, 'Hows the champ just leaving glasgow!\n'],
#  [0, 'In da car park \n'],
#  [0,
#   'Omg you can make a wedding chapel in frontierville? Why do they get all the good stuff?\n'],
#  [0,
#   'Hope this text meets you smiling. If not then let this text give you a reason to smile. Have a beautiful day.\n'],
#  [0,
#   'Hey sexy buns! What of that day? No word from you this morning on YM ... :-( ... I think of you\n'],
#  [1,
#   'A £400 XMAS REWARD IS WAITING FOR YOU! Our computer has randomly picked you from our loyal mobile customers to receive a £400 reward. Just call 09066380611\n'],
#  [1,
#   'As a valued customer, I am pleased to advise you that following recent review of your Mob No. you are awarded with a £1500 Bonus Prize, call 09066364589\n'],
#  [1,
#   'Am new 2 club & dont fink we met yet Will B gr8 2 C U Please leave msg 2day wiv ur area 09099726553 reply promised CARLIE x Calls£1/minMobsmore LKPOBOX177HP51FL\n'],
#  [1,
#   'Had your mobile 10 mths? Update to the latest Camera/Video phones for FREE. KEEP UR SAME NUMBER, Get extra free mins/texts. Text YES for a call\n'],
#  [0, "I didn't get the second half of that message\n"],
#  [0, "I don't think he has spatula hands!\n"],
#  [1,
#   'WIN a £200 Shopping spree every WEEK Starting NOW. 2 play text STORE to 88039. SkilGme. TsCs08714740323 1Winawk! age16 £1.50perweeksub.\n'],
#  [0, 'Hey you can pay. With salary de. Only  &lt;#&gt; .\n'],
#  [1,
#   'You are a winner U have been specially selected 2 receive £1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810810\n'],
#  [1,
#   'Thanks for your subscription to Ringtone UK your mobile will be charged £5/month Please confirm by replying YES or NO. If you reply NO you will not be charged\n'],
#  [0, 'Lol alright i was thinkin that too haha\n'],
#  [0, "It's that time of the week again, ryan\n"],
#  [0,
#   'I was wondering if it would be okay for you to call uncle john and let him know that things are not the same in nigeria as they r here. That  &lt;#&gt;  dollars is 2years sent and that you know its a strain but i plan to pay back every dime he gives. Every dime so for me to expect anything from you is not practical. Something like that.\n'],
#  [0, 'Ok. There may be a free gym about.\n'],
#  [0, 'Mmm so yummy babe ... Nice jolt to the suzy\n'],
#  [0, 'Nope... C ü then...\n'],
#  [0, 'Leave it. U will always be ignorant.\n'],
#  ...]

# %%
import re

pattern = re.compile("[\s\n\r\t.,:;\-_\'\"?!#&()]")

for line in dataset:
    line[1] = [x.strip() for x in pattern.split(line[1]) if x.strip() != '']

dataset
# Out:
# [[0, ['S', 's', 'nervous', 'lt', 'gt']],
#  [1,
#   ['88800',
#    'and',
#    '89034',
#    'are',
#    'premium',
#    'phone',
#    'services',
#    'call',
#    '08718711108']],
#  [0,
#   ['Just',
#    'curious',
#    'because',
#    'my',
#    'cuz',
#    'asked',
#    'what',
#    'I',
#    'was',
#    'up',
#    'to']],
#  [0,
#   ['Hi',
#    'my',
#    'love',
#    'How',
#    'goes',
#    'that',
#    'day',
#    'Fuck',
#    'this',
#    'morning',
#    'I',
#    'woke',
#    'and',
#    'dropped',
#    'my',
#    'cell',
#    'on',
#    'the',
#    'way',
#    'down',
#    'the',
#    'stairs',
#    'but',
#    'it',
#    'seems',
#    'alright',
#    '*phews*',
#    'I',
#    'miss',
#    'you']],
#  [0, ['Draw', 'va', 'i', 'dont', 'think', 'so']],
#  [0,
#   ['But',
#    'i',
#    'll',
#    'b',
#    'going',
#    '2',
#    'sch',
#    'on',
#    'mon',
#    'My',
#    'sis',
#    'need',
#    '2',
#    'take',
#    'smth']],
#  [0, ['Cps', 'is', 'causing', 'the', 'outages', 'to', 'conserve', 'energy']],
#  [1,
#   ['Talk',
#    'sexy',
#    'Make',
#    'new',
#    'friends',
#    'or',
#    'fall',
#    'in',
#    'love',
#    'in',
#    'the',
#    'worlds',
#    'most',
#    'discreet',
#    'text',
#    'dating',
#    'service',
#    'Just',
#    'text',
#    'VIP',
#    'to',
#    '83110',
#    'and',
#    'see',
#    'who',
#    'you',
#    'could',
#    'meet']],
#  [0, ['Reverse', 'is', 'cheating', 'That', 'is', 'not', 'mathematics']],
#  [1,
#   ['FreeMsg',
#    'Hey',
#    'U',
#    'i',
#    'just',
#    'got',
#    '1',
#    'of',
#    'these',
#    'video/pic',
#    'fones',
#    'reply',
#    'WILD',
#    'to',
#    'this',
#    'txt',
#    'ill',
#    'send',
#    'U',
#    'my',
#    'pics',
#    'hurry',
#    'up',
#    'Im',
#    'so',
#    'bored',
#    'at',
#    'work',
#    'xxx',
#    '18',
#    '150p/rcvd',
#    'STOP2stop']],
#  [0,
#   ['Sorry',
#    'i',
#    'now',
#    'then',
#    'c',
#    'ur',
#    'msg',
#    'Yar',
#    'lor',
#    'so',
#    'poor',
#    'thing',
#    'But',
#    'only',
#    '4',
#    'one',
#    'night',
#    'Tmr',
#    'u',
#    'll',
#    'have',
#    'a',
#    'brand',
#    'new',
#    'room',
#    '2',
#    'sleep',
#    'in']],
#  [1,
#   ['SMS',
#    'AUCTION',
#    'A',
#    'BRAND',
#    'NEW',
#    'Nokia',
#    '7250',
#    'is',
#    'up',
#    '4',
#    'auction',
#    'today',
#    'Auction',
#    'is',
#    'FREE',
#    '2',
#    'join',
#    'take',
#    'part',
#    'Txt',
#    'NOKIA',
#    'to',
#    '86021',
#    'now',
#    'HG/Suite342/2Lands',
#    'Row/W1J6HL']],
#  [0,
#   ['You',
#    'give',
#    'us',
#    'back',
#    'my',
#    'id',
#    'proof',
#    'and',
#    'lt',
#    'gt',
#    'rs',
#    'We',
#    'wont',
#    'allow',
#    'you',
#    'to',
#    'work',
#    'We',
#    'will',
#    'come',
#    'to',
#    'your',
#    'home',
#    'within',
#    'days']],
#  [1,
#   ['Buy',
#    'Space',
#    'Invaders',
#    '4',
#    'a',
#    'chance',
#    '2',
#    'win',
#    'orig',
#    'Arcade',
#    'Game',
#    'console',
#    'Press',
#    '0',
#    'for',
#    'Games',
#    'Arcade',
#    'std',
#    'WAP',
#    'charge',
#    'See',
#    'o2',
#    'co',
#    'uk/games',
#    '4',
#    'Terms',
#    '+',
#    'settings',
#    'No',
#    'purchase']],
#  [0, ['photoshop', 'makes', 'my', 'computer', 'shut', 'down']],
#  [0,
#   ['A',
#    'bit',
#    'of',
#    'Ur',
#    'smile',
#    'is',
#    'my',
#    'hppnss',
#    'a',
#    'drop',
#    'of',
#    'Ur',
#    'tear',
#    'is',
#    'my',
#    'sorrow',
#    'a',
#    'part',
#    'of',
#    'Ur',
#    'heart',
#    'is',
#    'my',
#    'life',
#    'a',
#    'heart',
#    'like',
#    'mine',
#    'wil',
#    'care',
#    'for',
#    'U',
#    'forevr',
#    'as',
#    'my',
#    'GOODFRIEND']],
#  [1,
#   ['URGENT',
#    'This',
#    'is',
#    'our',
#    '2nd',
#    'attempt',
#    'to',
#    'contact',
#    'U',
#    'Your',
#    '£900',
#    'prize',
#    'from',
#    'YESTERDAY',
#    'is',
#    'still',
#    'awaiting',
#    'collection',
#    'To',
#    'claim',
#    'CALL',
#    'NOW',
#    '09061702893']],
#  [0,
#   ['New',
#    'Theory',
#    'Argument',
#    'wins',
#    'd',
#    'SITUATION',
#    'but',
#    'loses',
#    'the',
#    'PERSON',
#    'So',
#    'dont',
#    'argue',
#    'with',
#    'ur',
#    'friends',
#    'just',
#    'kick',
#    'them',
#    'amp',
#    'say',
#    'I',
#    'm',
#    'always',
#    'correct']],
#  [1,
#   ['As',
#    'a',
#    'SIM',
#    'subscriber',
#    'you',
#    'are',
#    'selected',
#    'to',
#    'receive',
#    'a',
#    'Bonus',
#    'Get',
#    'it',
#    'delivered',
#    'to',
#    'your',
#    'door',
#    'Txt',
#    'the',
#    'word',
#    'OK',
#    'to',
#    'No',
#    '88600',
#    'to',
#    'claim',
#    '150p/msg',
#    'EXP',
#    '30Apr']],
#  [1,
#   ['Dorothy@kiefer',
#    'com',
#    'Bank',
#    'of',
#    'Granite',
#    'issues',
#    'Strong',
#    'Buy',
#    'EXPLOSIVE',
#    'PICK',
#    'FOR',
#    'OUR',
#    'MEMBERS',
#    '*****UP',
#    'OVER',
#    '300%',
#    '***********',
#    'Nasdaq',
#    'Symbol',
#    'CDGT',
#    'That',
#    'is',
#    'a',
#    '$5',
#    '00',
#    'per']],
#  [1,
#   ['Loan',
#    'for',
#    'any',
#    'purpose',
#    '£500',
#    '£75',
#    '000',
#    'Homeowners',
#    '+',
#    'Tenants',
#    'welcome',
#    'Have',
#    'you',
#    'been',
#    'previously',
#    'refused',
#    'We',
#    'can',
#    'still',
#    'help',
#    'Call',
#    'Free',
#    '0800',
#    '1956669',
#    'or',
#    'text',
#    'back',
#    'help']],
#  [0, ['Watching', 'ajith', 'film', 'ah']],
#  [0,
#   ['Hiya',
#    'How',
#    'was',
#    'last',
#    'night',
#    'I',
#    've',
#    'been',
#    'naughty',
#    'and',
#    'bought',
#    'myself',
#    'clothes',
#    'and',
#    'very',
#    'little',
#    'Ready',
#    'for',
#    'more',
#    'shopping',
#    'tho',
#    'What',
#    'kind',
#    'of',
#    'time',
#    'do',
#    'you',
#    'wanna',
#    'meet']],
#  [0, ['Thank', 'you', 'princess', 'You', 'are', 'so', 'sexy']],
#  [0,
#   ['Noooooooo',
#    'please',
#    'Last',
#    'thing',
#    'I',
#    'need',
#    'is',
#    'stress',
#    'For',
#    'once',
#    'in',
#    'your',
#    'life',
#    'be',
#    'fair']],
#  [0, ['We', 'confirm', 'eating', 'at', 'esplanade']],
#  [0,
#   ['We',
#    'walked',
#    'from',
#    'my',
#    'moms',
#    'Right',
#    'on',
#    'stagwood',
#    'pass',
#    'right',
#    'on',
#    'winterstone',
#    'left',
#    'on',
#    'victors',
#    'hill',
#    'Address',
#    'is',
#    'lt',
#    'gt']],
#  [0, ['Oh', 'ok', 'no', 'prob']],
#  [0, ['I', 'm', 'gonna', 'rip', 'out', 'my', 'uterus']],
#  [0, ['You', 'still', 'coming', 'tonight']],
#  [0, ['Sorry', 'I', 'll', 'call', 'later']],
#  [0,
#   ['HEY',
#    'KATE',
#    'HOPE',
#    'UR',
#    'OK',
#    'WILL',
#    'GIVE',
#    'U',
#    'A',
#    'BUZ',
#    'WEDLUNCH',
#    'GO',
#    'OUTSOMEWHERE',
#    '4',
#    'ADRINK',
#    'IN',
#    'TOWN',
#    'CUD',
#    'GO',
#    '2WATERSHD',
#    '4',
#    'A',
#    'BIT',
#    'PPL',
#    'FROMWRK',
#    'WILL',
#    'BTHERE',
#    'LOVE',
#    'PETEXXX']],
#  [0, ['Are', 'you', 'plans', 'with', 'your', 'family', 'set', 'in', 'stone']],
#  [0,
#   ['Hey',
#    'what',
#    's',
#    'up',
#    'charles',
#    'sorry',
#    'about',
#    'the',
#    'late',
#    'reply']],
#  [0, ['Stop', 'knowing', 'me', 'so', 'well']],
#  [0,
#   ['Ha',
#    'Then',
#    'we',
#    'must',
#    'walk',
#    'to',
#    'everywhere',
#    'Cannot',
#    'take',
#    'tram',
#    'My',
#    'cousin',
#    'said',
#    'can',
#    'walk',
#    'to',
#    'vic',
#    'market',
#    'from',
#    'our',
#    'hotel']],
#  [0,
#   ['they',
#    'released',
#    'another',
#    'Italian',
#    'one',
#    'today',
#    'and',
#    'it',
#    'has',
#    'a',
#    'cosign',
#    'option']],
#  [0, ['Sorry', 'battery', 'died', 'yeah', 'I', 'm', 'here']],
#  [0,
#   ['Hi',
#    'My',
#    'engagement',
#    'has',
#    'been',
#    'fixd',
#    'on',
#    'lt',
#    'gt',
#    'th',
#    'of',
#    'next',
#    'month',
#    'I',
#    'know',
#    'its',
#    'really',
#    'shocking',
#    'bt',
#    'hmm',
#    'njan',
#    'vilikkam',
#    't',
#    'ws',
#    'al',
#    'of',
#    'a',
#    'sudn']],
#  [0, ['I', 'think', 'chennai', 'well', 'settled']],
#  [1,
#   ['Your',
#    'free',
#    'ringtone',
#    'is',
#    'waiting',
#    'to',
#    'be',
#    'collected',
#    'Simply',
#    'text',
#    'the',
#    'password',
#    'MIX',
#    'to',
#    '85069',
#    'to',
#    'verify',
#    'Get',
#    'Usher',
#    'and',
#    'Britney',
#    'FML',
#    'PO',
#    'Box',
#    '5249',
#    'MK17',
#    '92H',
#    '450Ppw',
#    '16']],
#  [0,
#   ['Smile',
#    'in',
#    'Pleasure',
#    'Smile',
#    'in',
#    'Pain',
#    'Smile',
#    'when',
#    'trouble',
#    'pours',
#    'like',
#    'Rain',
#    'Smile',
#    'when',
#    'sum1',
#    'Hurts',
#    'U',
#    'Smile',
#    'becoz',
#    'SOMEONE',
#    'still',
#    'Loves',
#    'to',
#    'see',
#    'u',
#    'Smiling']],
#  [0,
#   ['Yeah', 'probably', 'I', 'still', 'gotta', 'check', 'out', 'with', 'leo']],
#  [0, ['I', 'll', 'meet', 'you', 'in', 'the', 'lobby']],
#  [0,
#   ['Hey',
#    'do',
#    'u',
#    'fancy',
#    'meetin',
#    'me',
#    'at',
#    '4',
#    'at',
#    'cha',
#    '\x96',
#    'hav',
#    'a',
#    'lil',
#    'beverage',
#    'on',
#    'me',
#    'if',
#    'not',
#    'txt',
#    'or',
#    'ring',
#    'me',
#    'and',
#    'we',
#    'can',
#    'meet',
#    'up',
#    'l8r',
#    'quite',
#    'tired',
#    'got',
#    'in',
#    'at',
#    '3',
#    'v',
#    'pist',
#    'love',
#    'Pete',
#    'x',
#    'x',
#    'x']],
#  [0, ['I', 'm', 'home', 'Ard', 'wat', 'time', 'will', 'u', 'reach']],
#  [0,
#   ['Hope',
#    'you',
#    'are',
#    'feeling',
#    'great',
#    'Pls',
#    'fill',
#    'me',
#    'in',
#    'Abiola']],
#  [1,
#   ['Hi',
#    'there',
#    '2nights',
#    'ur',
#    'lucky',
#    'night',
#    'Uve',
#    'been',
#    'invited',
#    '2',
#    'XCHAT',
#    'the',
#    'Uks',
#    'wildest',
#    'chat',
#    'Txt',
#    'CHAT',
#    'to',
#    '86688',
#    'now',
#    '150p/MsgrcvdHG/Suite342/2Lands/Row/W1J6HL',
#    'LDN',
#    '18yrs']],
#  [1,
#   ['Free',
#    'entry',
#    'in',
#    '2',
#    'a',
#    'weekly',
#    'comp',
#    'for',
#    'a',
#    'chance',
#    'to',
#    'win',
#    'an',
#    'ipod',
#    'Txt',
#    'POD',
#    'to',
#    '80182',
#    'to',
#    'get',
#    'entry',
#    'std',
#    'txt',
#    'rate',
#    'T',
#    'C',
#    's',
#    'apply',
#    '08452810073',
#    'for',
#    'details',
#    '18+']],
#  [0,
#   ['Honestly',
#    'i',
#    've',
#    'just',
#    'made',
#    'a',
#    'lovely',
#    'cup',
#    'of',
#    'tea',
#    'and',
#    'promptly',
#    'dropped',
#    'my',
#    'keys',
#    'in',
#    'it',
#    'and',
#    'then',
#    'burnt',
#    'my',
#    'fingers',
#    'getting',
#    'them',
#    'out']],
#  [0, ['Y', 'de', 'asking', 'like', 'this']],
#  [0,
#   ['Nah',
#    'man',
#    'my',
#    'car',
#    'is',
#    'meant',
#    'to',
#    'be',
#    'crammed',
#    'full',
#    'of',
#    'people']],
#  [0, ['Otherwise', 'had', 'part', 'time', 'job', 'na', 'tuition']],
#  [0, ['K', 'k', 'any', 'special', 'today']],
#  [0,
#   ['Jus',
#    'finish',
#    'my',
#    'lunch',
#    'on',
#    'my',
#    'way',
#    'home',
#    'lor',
#    'I',
#    'tot',
#    'u',
#    'dun',
#    'wan',
#    '2',
#    'stay',
#    'in',
#    'sch',
#    'today']],
#  [1,
#   ['SMS',
#    'ac',
#    'sun0819',
#    'posts',
#    'HELLO',
#    'You',
#    'seem',
#    'cool',
#    'wanted',
#    'to',
#    'say',
#    'hi',
#    'HI',
#    'Stop',
#    'Send',
#    'STOP',
#    'to',
#    '62468']],
#  [0,
#   ['Hi',
#    'here',
#    'have',
#    'birth',
#    'at',
#    'on',
#    'the',
#    'to',
#    'at',
#    '8lb',
#    '7oz',
#    'Mother',
#    'and',
#    'baby',
#    'doing',
#    'brilliantly']],
#  [1,
#   ['Rock',
#    'yr',
#    'chik',
#    'Get',
#    '100',
#    's',
#    'of',
#    'filthy',
#    'films',
#    'XXX',
#    'pics',
#    'on',
#    'yr',
#    'phone',
#    'now',
#    'rply',
#    'FILTH',
#    'to',
#    '69669',
#    'Saristar',
#    'Ltd',
#    'E14',
#    '9YT',
#    '08701752560',
#    '450p',
#    'per',
#    '5',
#    'days',
#    'Stop2',
#    'cancel']],
#  [0, ['Then', 'she', 'dun', 'believe', 'wat']],
#  [0, ['I', 'will', 'spoil', 'you', 'in', 'bed', 'as', 'well']],
#  [1,
#   ['You', 'have', '1', 'new', 'voicemail', 'Please', 'call', '08719181513']],
#  [0, ['How', 'Izzit', 'still', 'raining']],
#  [1,
#   ['**FREE',
#    'MESSAGE**Thanks',
#    'for',
#    'using',
#    'the',
#    'Auction',
#    'Subscription',
#    'Service',
#    '18',
#    '150p/MSGRCVD',
#    '2',
#    'Skip',
#    'an',
#    'Auction',
#    'txt',
#    'OUT',
#    '2',
#    'Unsubscribe',
#    'txt',
#    'STOP',
#    'CustomerCare',
#    '08718726270']],
#  [1,
#   ['We',
#    'know',
#    'someone',
#    'who',
#    'you',
#    'know',
#    'that',
#    'fancies',
#    'you',
#    'Call',
#    '09058097218',
#    'to',
#    'find',
#    'out',
#    'who',
#    'POBox',
#    '6',
#    'LS15HB',
#    '150p']],
#  [1,
#   ['Wan2',
#    'win',
#    'a',
#    'Meet+Greet',
#    'with',
#    'Westlife',
#    '4',
#    'U',
#    'or',
#    'a',
#    'm8',
#    'They',
#    'are',
#    'currently',
#    'on',
#    'what',
#    'tour',
#    '1',
#    'Unbreakable',
#    '2',
#    'Untamed',
#    '3',
#    'Unkempt',
#    'Text',
#    '1',
#    '2',
#    'or',
#    '3',
#    'to',
#    '83049',
#    'Cost',
#    '50p',
#    '+std',
#    'text']],
#  [0,
#   ['I',
#    'm',
#    'stuck',
#    'in',
#    'da',
#    'middle',
#    'of',
#    'da',
#    'row',
#    'on',
#    'da',
#    'right',
#    'hand',
#    'side',
#    'of',
#    'da',
#    'lt']],
#  [1,
#   ['Get',
#    'your',
#    'garden',
#    'ready',
#    'for',
#    'summer',
#    'with',
#    'a',
#    'FREE',
#    'selection',
#    'of',
#    'summer',
#    'bulbs',
#    'and',
#    'seeds',
#    'worth',
#    '£33',
#    '50',
#    'only',
#    'with',
#    'The',
#    'Scotsman',
#    'this',
#    'Saturday',
#    'To',
#    'stop',
#    'go2',
#    'notxt',
#    'co',
#    'uk']],
#  [0,
#   ['Eh',
#    'sorry',
#    'leh',
#    'I',
#    'din',
#    'c',
#    'ur',
#    'msg',
#    'Not',
#    'sad',
#    'already',
#    'lar',
#    'Me',
#    'watching',
#    'tv',
#    'now',
#    'U',
#    'still',
#    'in',
#    'office']],
#  [0, ['You', 'got', 'called', 'a', 'tool']],
#  [0,
#   ['Aiyo',
#    'u',
#    'so',
#    'poor',
#    'thing',
#    'Then',
#    'u',
#    'dun',
#    'wan',
#    '2',
#    'eat',
#    'U',
#    'bathe',
#    'already']],
#  [0,
#   ['Finally',
#    'the',
#    'match',
#    'heading',
#    'towards',
#    'draw',
#    'as',
#    'your',
#    'prediction']],
#  [0,
#   ['As',
#    'I',
#    'entered',
#    'my',
#    'cabin',
#    'my',
#    'PA',
#    'said',
#    'Happy',
#    'B',
#    'day',
#    'Boss',
#    'I',
#    'felt',
#    'special',
#    'She',
#    'askd',
#    'me',
#    '4',
#    'lunch',
#    'After',
#    'lunch',
#    'she',
#    'invited',
#    'me',
#    'to',
#    'her',
#    'apartment',
#    'We',
#    'went',
#    'there']],
#  [1,
#   ['You',
#    'have',
#    'WON',
#    'a',
#    'guaranteed',
#    '£1000',
#    'cash',
#    'or',
#    'a',
#    '£2000',
#    'prize',
#    'To',
#    'claim',
#    'yr',
#    'prize',
#    'call',
#    'our',
#    'customer',
#    'service',
#    'representative',
#    'on',
#    '08714712394',
#    'between',
#    '10am',
#    '7pm']],
#  [0,
#   ['Oic',
#    'cos',
#    'me',
#    'n',
#    'my',
#    'sis',
#    'got',
#    'no',
#    'lunch',
#    'today',
#    'my',
#    'dad',
#    'went',
#    'out',
#    'So',
#    'dunno',
#    'whether',
#    '2',
#    'eat',
#    'in',
#    'sch',
#    'or',
#    'wat']],
#  [0,
#   ['I',
#    'hav',
#    'almost',
#    'reached',
#    'Call',
#    'i',
#    'm',
#    'unable',
#    'to',
#    'connect',
#    'u']],
#  [0,
#   ['Nvm',
#    'I',
#    'm',
#    'going',
#    'to',
#    'wear',
#    'my',
#    'sport',
#    'shoes',
#    'anyway',
#    'I',
#    'm',
#    'going',
#    'to',
#    'be',
#    'late',
#    'leh']],
#  [0, ['How', 'about', 'clothes', 'jewelry', 'and', 'trips']],
#  [0,
#   ['Hey',
#    'I',
#    'almost',
#    'forgot',
#    'Happy',
#    'B',
#    'day',
#    'babe',
#    'I',
#    'love',
#    'ya']],
#  [0,
#   ['Anything',
#    'lor',
#    'but',
#    'toa',
#    'payoh',
#    'got',
#    'place',
#    '2',
#    'walk',
#    'meh']],
#  [0, ['Happy', 'birthday', 'May', 'all', 'ur', 'dreams', 'come', 'true']],
#  [0,
#   ['Especially',
#    'since',
#    'i',
#    'talk',
#    'about',
#    'boston',
#    'all',
#    'up',
#    'in',
#    'my',
#    'personal',
#    'statement',
#    'lol',
#    'I',
#    'woulda',
#    'changed',
#    'that',
#    'if',
#    'i',
#    'had',
#    'realized',
#    'it',
#    'said',
#    'nyc',
#    'It',
#    'says',
#    'boston',
#    'now']],
#  [0, ['Dear', 'got', 'bus', 'directly', 'to', 'calicut']],
#  [0,
#   ['I',
#    'bought',
#    'the',
#    'test',
#    'yesterday',
#    'Its',
#    'something',
#    'that',
#    'lets',
#    'you',
#    'know',
#    'the',
#    'exact',
#    'day',
#    'u',
#    'ovulate',
#    'when',
#    'will',
#    'get',
#    '2u',
#    'in',
#    'about',
#    '2',
#    'to',
#    '3wks',
#    'But',
#    'pls',
#    'pls',
#    'dont',
#    'fret',
#    'I',
#    'know',
#    'u',
#    'r',
#    'worried',
#    'Pls',
#    'relax',
#    'Also',
#    'is',
#    'there',
#    'anything',
#    'in',
#    'ur',
#    'past',
#    'history',
#    'u',
#    'need',
#    'to',
#    'tell',
#    'me']],
#  [0, ['U', 'can', 'call', 'now']],
#  [0,
#   ['NEFT',
#    'Transaction',
#    'with',
#    'reference',
#    'number',
#    'lt',
#    'gt',
#    'for',
#    'Rs',
#    'lt',
#    'DECIMAL',
#    'gt',
#    'has',
#    'been',
#    'credited',
#    'to',
#    'the',
#    'beneficiary',
#    'account',
#    'on',
#    'lt',
#    'gt',
#    'at',
#    'lt',
#    'TIME',
#    'gt',
#    'lt',
#    'gt']],
#  [0,
#   ['Please',
#    'sen',
#    'my',
#    'kind',
#    'advice',
#    'please',
#    'come',
#    'here',
#    'and',
#    'try']],
#  [0, ['Y', 'bishan', 'lei', 'I', 'tot', 'ü', 'say', 'lavender']],
#  [0, ['At', 'home', 'also']],
#  [0,
#   ['awesome',
#    'how',
#    'do',
#    'I',
#    'deal',
#    'with',
#    'the',
#    'gate',
#    'Charles',
#    'told',
#    'me',
#    'last',
#    'night',
#    'but',
#    'uh',
#    'yeah']],
#  [1,
#   ['December',
#    'only',
#    'Had',
#    'your',
#    'mobile',
#    '11mths+',
#    'You',
#    'are',
#    'entitled',
#    'to',
#    'update',
#    'to',
#    'the',
#    'latest',
#    'colour',
#    'camera',
#    'mobile',
#    'for',
#    'Free',
#    'Call',
#    'The',
#    'Mobile',
#    'Update',
#    'VCo',
#    'FREE',
#    'on',
#    '08002986906']],
#  [0, ['I', 'can', 'make', 'lasagna', 'for', 'you', 'vodka']],
#  [0,
#   ['I',
#    'got',
#    'like',
#    '$',
#    'lt',
#    'gt',
#    'I',
#    'can',
#    'get',
#    'some',
#    'more',
#    'later',
#    'though',
#    'Get',
#    'whatever',
#    'you',
#    'feel',
#    'like']],
#  [1,
#   ['Free',
#    'entry',
#    'in',
#    '2',
#    'a',
#    'wkly',
#    'comp',
#    'to',
#    'win',
#    'FA',
#    'Cup',
#    'final',
#    'tkts',
#    '21st',
#    'May',
#    '2005',
#    'Text',
#    'FA',
#    'to',
#    '87121',
#    'to',
#    'receive',
#    'entry',
#    'question',
#    'std',
#    'txt',
#    'rate',
#    'T',
#    'C',
#    's',
#    'apply',
#    '08452810075over18',
#    's']],
#  [0, ['Arun', 'can', 'u', 'transfr', 'me', 'd', 'amt']],
#  [0,
#   ['Tomorrow',
#    'i',
#    'am',
#    'not',
#    'going',
#    'to',
#    'theatre',
#    'So',
#    'i',
#    'can',
#    'come',
#    'wherever',
#    'u',
#    'call',
#    'me',
#    'Tell',
#    'me',
#    'where',
#    'and',
#    'when',
#    'to',
#    'come',
#    'tomorrow']],
#  [0, ['Sorry', 'in', 'meeting', 'I', 'll', 'call', 'you', 'later']],
#  [0, ['Tell', 'where', 'you', 'reached']],
#  [0, ['Sent', 'me', 'ur', 'email', 'id', 'soon']],
#  [0,
#   ['Hey',
#    'mate',
#    'Spoke',
#    'to',
#    'the',
#    'mag',
#    'people',
#    'We‘re',
#    'on',
#    'the',
#    'is',
#    'deliver',
#    'by',
#    'the',
#    'end',
#    'of',
#    'the',
#    'month',
#    'Deliver',
#    'on',
#    'the',
#    '24th',
#    'sept',
#    'Talk',
#    'later']],
#  [0,
#   ['You',
#    're',
#    'right',
#    'I',
#    'have',
#    'now',
#    'that',
#    'I',
#    'think',
#    'about',
#    'it']],
#  [0,
#   ['Although',
#    'i',
#    'told',
#    'u',
#    'dat',
#    'i',
#    'm',
#    'into',
#    'baig',
#    'face',
#    'watches',
#    'now',
#    'but',
#    'i',
#    'really',
#    'like',
#    'e',
#    'watch',
#    'u',
#    'gave',
#    'cos',
#    'it',
#    's',
#    'fr',
#    'u',
#    'Thanx',
#    '4',
#    'everything',
#    'dat',
#    'u',
#    've',
#    'done',
#    'today',
#    'i',
#    'm',
#    'touched']],
#  [1,
#   ['Please',
#    'CALL',
#    '08712402779',
#    'immediately',
#    'as',
#    'there',
#    'is',
#    'an',
#    'urgent',
#    'message',
#    'waiting',
#    'for',
#    'you']],
#  [0,
#   ['Do',
#    '1',
#    'thing',
#    'Change',
#    'that',
#    'sentence',
#    'into',
#    'Because',
#    'i',
#    'want',
#    '2',
#    'concentrate',
#    'in',
#    'my',
#    'educational',
#    'career',
#    'im',
#    'leaving',
#    'here']],
#  [0,
#   ['Tunji',
#    'how',
#    's',
#    'the',
#    'queen',
#    'how',
#    'are',
#    'you',
#    'doing',
#    'This',
#    'is',
#    'just',
#    'wishing',
#    'you',
#    'a',
#    'great',
#    'day',
#    'Abiola']],
#  [0,
#   ['I',
#    'm',
#    'home',
#    'my',
#    'love',
#    'If',
#    'your',
#    'still',
#    'awake',
#    '*loving',
#    'kiss*']],
#  [0,
#   ['Let',
#    'me',
#    'know',
#    'when',
#    'you',
#    've',
#    'got',
#    'the',
#    'money',
#    'so',
#    'carlos',
#    'can',
#    'make',
#    'the',
#    'call']],
#  [0,
#   ['Squeeeeeze',
#    'This',
#    'is',
#    'christmas',
#    'hug',
#    'If',
#    'u',
#    'lik',
#    'my',
#    'frndshp',
#    'den',
#    'hug',
#    'me',
#    'back',
#    'If',
#    'u',
#    'get',
#    '3',
#    'u',
#    'r',
#    'cute',
#    '6',
#    'u',
#    'r',
#    'luvd',
#    '*',
#    '9',
#    'u',
#    'r',
#    'so',
#    'lucky',
#    'None',
#    'People',
#    'hate',
#    'u']],
#  [0,
#   ['In',
#    'fact',
#    'when',
#    'do',
#    'you',
#    'leave',
#    'I',
#    'think',
#    'addie',
#    'goes',
#    'back',
#    'to',
#    'school',
#    'tues',
#    'or',
#    'wed']],
#  [0,
#   ['Whats',
#    'the',
#    'staff',
#    'name',
#    'who',
#    'is',
#    'taking',
#    'class',
#    'for',
#    'us']],
#  [0, ['Dude', 'got', 'a', 'haircut', 'Now', 'its', 'breezy', 'up', 'there']],
#  [0, ['Id', 'onluy', 'matters', 'when', 'getting', 'on', 'from', 'offcampus']],
#  [0,
#   ['I',
#    'guess',
#    'you',
#    'could',
#    'be',
#    'as',
#    'good',
#    'an',
#    'excuse',
#    'as',
#    'any',
#    'lol']],
#  [0,
#   ['If',
#    'I',
#    'get',
#    'there',
#    'before',
#    'you',
#    'after',
#    'your',
#    'ten',
#    'billion',
#    'calls',
#    'and',
#    'texts',
#    'so',
#    'help',
#    'me',
#    'god']],
#  [0,
#   ['Haha',
#    'get',
#    'used',
#    'to',
#    'driving',
#    'to',
#    'usf',
#    'man',
#    'I',
#    'know',
#    'a',
#    'lot',
#    'of',
#    'stoners']],
#  [1, ['You', 'have', '1', 'new', 'message', 'Please', 'call', '08712400200']],
#  [0,
#   ['Yup',
#    'From',
#    'what',
#    'i',
#    'remb',
#    'I',
#    'think',
#    'should',
#    'be',
#    'can',
#    'book']],
#  [0, ['Well', 'I', 'might', 'not', 'come', 'then']],
#  [0, ['That', 'seems', 'unnecessarily', 'affectionate']],
#  [0,
#   ['Happy',
#    'birthday',
#    'May',
#    'u',
#    'find',
#    'ur',
#    'prince',
#    'charming',
#    'soon',
#    'n',
#    'dun',
#    'work',
#    'too',
#    'hard']],
#  [1,
#   ['Text',
#    'PASS',
#    'to',
#    '69669',
#    'to',
#    'collect',
#    'your',
#    'polyphonic',
#    'ringtones',
#    'Normal',
#    'gprs',
#    'charges',
#    'apply',
#    'only',
#    'Enjoy',
#    'your',
#    'tones']],
#  [0, ['Yes', 'princess', 'I', 'want', 'to', 'make', 'you', 'happy']],
#  [1,
#   ['PRIVATE',
#    'Your',
#    '2003',
#    'Account',
#    'Statement',
#    'for',
#    '<fone',
#    'no>',
#    'shows',
#    '800',
#    'un',
#    'redeemed',
#    'S',
#    'I',
#    'M',
#    'points',
#    'Call',
#    '08715203656',
#    'Identifier',
#    'Code',
#    '42049',
#    'Expires',
#    '26/10/04']],
#  [0, ['Please', 'leave', 'this', 'topic', 'sorry', 'for', 'telling', 'that']],
#  [1,
#   ['Your',
#    'B4U',
#    'voucher',
#    'w/c',
#    '27/03',
#    'is',
#    'MARSMS',
#    'Log',
#    'onto',
#    'www',
#    'B4Utele',
#    'com',
#    'for',
#    'discount',
#    'credit',
#    'To',
#    'opt',
#    'out',
#    'reply',
#    'stop',
#    'Customer',
#    'care',
#    'call',
#    '08717168528']],
#  [0,
#   ['Then',
#    'u',
#    'ask',
#    'darren',
#    'go',
#    'n',
#    'pick',
#    'u',
#    'lor',
#    'But',
#    'i',
#    'oso',
#    'sian',
#    'tmr',
#    'haf',
#    '2',
#    'meet',
#    'lect']],
#  [0,
#   ['Sure',
#    'I',
#    'am',
#    'driving',
#    'but',
#    'will',
#    'reach',
#    'my',
#    'destination',
#    'soon']],
#  [0,
#   ['I',
#    'd',
#    'say',
#    'that',
#    's',
#    'a',
#    'good',
#    'sign',
#    'but',
#    'well',
#    'you',
#    'know',
#    'my',
#    'track',
#    'record',
#    'at',
#    'reading',
#    'women']],
#  [0,
#   ['no',
#    'i',
#    '*didn',
#    't*',
#    'mean',
#    'to',
#    'post',
#    'it',
#    'I',
#    'wrote',
#    'it',
#    'and',
#    'like',
#    'so',
#    'many',
#    'other',
#    'times',
#    'i',
#    've',
#    'ritten',
#    'stuff',
#    'to',
#    'you',
#    'i',
#    'let',
#    'it',
#    'sit',
#    'there',
#    'it',
#    'WAS',
#    'what',
#    'i',
#    'was',
#    'feeling',
#    'at',
#    'the',
#    'time',
#    'I',
#    'was',
#    'angry',
#    'Before',
#    'i',
#    'left',
#    'i',
#    'hit',
#    'send',
#    'then',
#    'stop',
#    'It',
#    'wasn',
#    't',
#    'there',
#    'I',
#    'checked',
#    'on',
#    'my',
#    'phone',
#    'when',
#    'i',
#    'got',
#    'to',
#    'my',
#    'car',
#    'It',
#    'wasn',
#    't',
#    'there',
#    'You',
#    'said',
#    'you',
#    'didn',
#    't',
#    'sleep',
#    'you',
#    'were',
#    'bored',
#    'So',
#    'why',
#    'wouldn',
#    't',
#    'THAT',
#    'be',
#    'the',
#    'time',
#    'to',
#    'clean',
#    'fold',
#    'laundry',
#    'etc',
#    'At',
#    'least',
#    'make',
#    'the',
#    'bed']],
#  [0,
#   ['Did',
#    'u',
#    'turn',
#    'on',
#    'the',
#    'heater',
#    'The',
#    'heater',
#    'was',
#    'on',
#    'and',
#    'set',
#    'to',
#    'lt',
#    'gt',
#    'degrees']],
#  [1,
#   ['FREE',
#    'NOKIA',
#    'Or',
#    'Motorola',
#    'with',
#    'upto',
#    '12mths',
#    '1/2price',
#    'linerental',
#    '500',
#    'FREE',
#    'x',
#    'net',
#    'mins',
#    '100txt/mth',
#    'FREE',
#    'B',
#    'tooth*',
#    'Call',
#    'Mobileupd8',
#    'on',
#    '08001950382',
#    'or',
#    'call',
#    '2optout/D3WV']],
#  [0,
#   ['Ups',
#    'which',
#    'is',
#    '3days',
#    'also',
#    'and',
#    'the',
#    'shipping',
#    'company',
#    'that',
#    'takes',
#    '2wks',
#    'The',
#    'other',
#    'way',
#    'is',
#    'usps',
#    'which',
#    'takes',
#    'a',
#    'week',
#    'but',
#    'when',
#    'it',
#    'gets',
#    'to',
#    'lag',
#    'you',
#    'may',
#    'have',
#    'to',
#    'bribe',
#    'nipost',
#    'to',
#    'get',
#    'your',
#    'stuff']],
#  [1,
#   ['Santa',
#    'calling',
#    'Would',
#    'your',
#    'little',
#    'ones',
#    'like',
#    'a',
#    'call',
#    'from',
#    'Santa',
#    'Xmas',
#    'Eve',
#    'Call',
#    '09077818151',
#    'to',
#    'book',
#    'you',
#    'time',
#    'Calls1',
#    '50ppm',
#    'last',
#    '3mins',
#    '30s',
#    'T',
#    'C',
#    'www',
#    'santacalling',
#    'com']],
#  [0,
#   ['THING',
#    'R',
#    'GOOD',
#    'THANX',
#    'GOT',
#    'EXAMS',
#    'IN',
#    'MARCH',
#    'IVE',
#    'DONE',
#    'NO',
#    'REVISION',
#    'IS',
#    'FRAN',
#    'STILL',
#    'WITH',
#    'BOYF',
#    'IVE',
#    'GOTTA',
#    'INTERVIW',
#    '4',
#    'EXETER',
#    'BIT',
#    'WORRIED',
#    'x']],
#  [0,
#   ['Today',
#    'i',
#    'm',
#    'not',
#    'workin',
#    'but',
#    'not',
#    'free',
#    'oso',
#    'Gee',
#    'Thgt',
#    'u',
#    'workin',
#    'at',
#    'ur',
#    'fren',
#    's',
#    'shop']],
#  [0,
#   ['HI',
#    'DARLIN',
#    'I',
#    'FINISH',
#    'AT',
#    '3',
#    'DO',
#    'U',
#    '1',
#    '2',
#    'PICK',
#    'ME',
#    'UP',
#    'OR',
#    'MEET',
#    'ME',
#    'TEXT',
#    'BACK',
#    'ON',
#    'THIS',
#    'NUMBER',
#    'LUV',
#    'KATE',
#    'XXX']],
#  [0,
#   ['I',
#    'know',
#    'you',
#    'are',
#    'thinkin',
#    'malaria',
#    'But',
#    'relax',
#    'children',
#    'cant',
#    'handle',
#    'malaria',
#    'She',
#    'would',
#    'have',
#    'been',
#    'worse',
#    'and',
#    'its',
#    'gastroenteritis',
#    'If',
#    'she',
#    'takes',
#    'enough',
#    'to',
#    'replace',
#    'her',
#    'loss',
#    'her',
#    'temp',
#    'will',
#    'reduce',
#    'And',
#    'if',
#    'you',
#    'give',
#    'her',
#    'malaria',
#    'meds',
#    'now',
#    'she',
#    'will',
#    'just',
#    'vomit',
#    'Its',
#    'a',
#    'self',
#    'limiting',
#    'illness',
#    'she',
#    'has',
#    'which',
#    'means',
#    'in',
#    'a',
#    'few',
#    'days',
#    'it',
#    'will',
#    'completely',
#    'stop']],
#  [0, ['Aldrine', 'rakhesh', 'ex', 'RTM', 'here', 'pls', 'call', 'urgent']],
#  [1,
#   ['URGENT',
#    'This',
#    'is',
#    'our',
#    '2nd',
#    'attempt',
#    'to',
#    'contact',
#    'U',
#    'Your',
#    '£900',
#    'prize',
#    'from',
#    'YESTERDAY',
#    'is',
#    'still',
#    'awaiting',
#    'collection',
#    'To',
#    'claim',
#    'CALL',
#    'NOW',
#    '09061702893',
#    'ACL03530150PM']],
#  [0, ['I', 'dont', 'understand', 'your', 'message']],
#  [1,
#   ['FREE',
#    'RING',
#    'TONE',
#    'just',
#    'text',
#    'POLYS',
#    'to',
#    '87131',
#    'Then',
#    'every',
#    'week',
#    'get',
#    'a',
#    'new',
#    'tone',
#    '0870737910216yrs',
#    'only',
#    '£1',
#    '50/wk']],
#  [0, ['Lol', 'great', 'now', 'im', 'getting', 'hungry']],
#  [0, ['Yes', 'princess', 'Toledo']],
#  [0,
#   ['No',
#    'Its',
#    'not',
#    'specialisation',
#    'Can',
#    'work',
#    'but',
#    'its',
#    'slave',
#    'labor',
#    'Will',
#    'look',
#    'for',
#    'it',
#    'this',
#    'month',
#    'sha',
#    'cos',
#    'no',
#    'shakara',
#    '4',
#    'beggar']],
#  [0,
#   ['Thats',
#    'a',
#    'bit',
#    'weird',
#    'even',
#    'where',
#    'is',
#    'the',
#    'do',
#    'supposed',
#    'to',
#    'be',
#    'happening',
#    'But',
#    'good',
#    'idea',
#    'sure',
#    'they',
#    'will',
#    'be',
#    'in',
#    'pub']],
#  [0,
#   ['No',
#    'did',
#    'you',
#    'check',
#    'I',
#    'got',
#    'his',
#    'detailed',
#    'message',
#    'now']],
#  [0,
#   ['HEY',
#    'MATE',
#    'HOWS',
#    'U',
#    'HONEY',
#    'DID',
#    'U',
#    'AVE',
#    'GOOD',
#    'HOLIDAY',
#    'GIMMI',
#    'DE',
#    'GOSS',
#    'x']],
#  [0,
#   ['Open',
#    'rebtel',
#    'with',
#    'firefox',
#    'When',
#    'it',
#    'loads',
#    'just',
#    'put',
#    'plus',
#    'sign',
#    'in',
#    'the',
#    'user',
#    'name',
#    'place',
#    'and',
#    'it',
#    'will',
#    'show',
#    'you',
#    'two',
#    'numbers',
#    'The',
#    'lower',
#    'number',
#    'is',
#    'my',
#    'number',
#    'Once',
#    'you',
#    'pick',
#    'that',
#    'number',
#    'the',
#    'pin',
#    'will',
#    'display',
#    'okay']],
#  [0,
#   ['Ah',
#    'poop',
#    'Looks',
#    'like',
#    'ill',
#    'prob',
#    'have',
#    'to',
#    'send',
#    'in',
#    'my',
#    'laptop',
#    'to',
#    'get',
#    'fixed',
#    'cuz',
#    'it',
#    'has',
#    'a',
#    'gpu',
#    'problem']],
#  [0,
#   ['Hmm',
#    'Bad',
#    'news',
#    'Hype',
#    'park',
#    'plaza',
#    '$700',
#    'studio',
#    'taken',
#    'Only',
#    'left',
#    '2',
#    'bedrm',
#    '$900']],
#  [0, ['Ü', 'no', 'home', 'work', 'to', 'do', 'meh']],
#  [0,
#   ['Yay',
#    'You',
#    'better',
#    'not',
#    'have',
#    'told',
#    'that',
#    'to',
#    '5',
#    'other',
#    'girls',
#    'either']],
#  [0,
#   ['Guess',
#    'who',
#    'spent',
#    'all',
#    'last',
#    'night',
#    'phasing',
#    'in',
#    'and',
#    'out',
#    'of',
#    'the',
#    'fourth',
#    'dimension']],
#  [0,
#   ['Congrats',
#    'That',
#    's',
#    'great',
#    'I',
#    'wanted',
#    'to',
#    'tell',
#    'you',
#    'not',
#    'to',
#    'tell',
#    'me',
#    'your',
#    'score',
#    'cos',
#    'it',
#    'might',
#    'make',
#    'me',
#    'relax',
#    'But',
#    'its',
#    'motivating',
#    'me',
#    'so',
#    'thanks',
#    'for',
#    'sharing']],
#  [0, ['And', 'popping', 'lt', 'gt', 'ibuprofens', 'was', 'no', 'help']],
#  [0, ['Try', 'neva', 'mate']],
#  [0,
#   ['Watching',
#    'tv',
#    'lor',
#    'Y',
#    'she',
#    'so',
#    'funny',
#    'we',
#    'bluff',
#    'her',
#    '4',
#    'wat',
#    'Izzit',
#    'because',
#    'she',
#    'thk',
#    'it',
#    's',
#    'impossible',
#    'between',
#    'us']],
#  [0, ['Orh', 'i', 'tot', 'u', 'say', 'she', 'now', 'still', 'dun', 'believe']],
#  [0,
#   ['Where',
#    'are',
#    'you',
#    'You',
#    'said',
#    'you',
#    'would',
#    'be',
#    'here',
#    'when',
#    'I',
#    'woke']],
#  [0,
#   ['Geeeee',
#    'I',
#    'love',
#    'you',
#    'so',
#    'much',
#    'I',
#    'can',
#    'barely',
#    'stand',
#    'it']],
#  [0,
#   ['Cool',
#    'breeze',
#    'Bright',
#    'sun',
#    'Fresh',
#    'flower',
#    'Twittering',
#    'birds',
#    'All',
#    'these',
#    'waiting',
#    'to',
#    'wish',
#    'u',
#    'GOODMORNING',
#    'amp',
#    'HAVE',
#    'A',
#    'NICE',
#    'DAY']],
#  [0,
#   ['says',
#    'that',
#    'he',
#    's',
#    'quitting',
#    'at',
#    'least5times',
#    'a',
#    'day',
#    'so',
#    'i',
#    'wudn',
#    't',
#    'take',
#    'much',
#    'notice',
#    'of',
#    'that',
#    'Nah',
#    'she',
#    'didn',
#    't',
#    'mind',
#    'Are',
#    'you',
#    'gonna',
#    'see',
#    'him',
#    'again',
#    'Do',
#    'you',
#    'want',
#    'to',
#    'come',
#    'to',
#    'taunton',
#    'tonight',
#    'U',
#    'can',
#    'tell',
#    'me',
#    'all',
#    'about']],
#  [1,
#   ['Adult',
#    '18',
#    'Content',
#    'Your',
#    'video',
#    'will',
#    'be',
#    'with',
#    'you',
#    'shortly']],
#  [0, ['Same', 'Wana', 'plan', 'a', 'trip', 'sometme', 'then']],
#  [0,
#   ['that',
#    'would',
#    'be',
#    'good',
#    '…',
#    'I',
#    'll',
#    'phone',
#    'you',
#    'tomo',
#    'lunchtime',
#    'shall',
#    'I',
#    'to',
#    'organise',
#    'something']],
#  [0,
#   ['Happy',
#    'or',
#    'sad',
#    'one',
#    'thing',
#    'about',
#    'past',
#    'is',
#    'Its',
#    'no',
#    'more',
#    'GOOD',
#    'MORNING']],
#  [0,
#   ['lt', 'gt', 'mins', 'but', 'i', 'had', 'to', 'stop', 'somewhere', 'first']],
#  [0,
#   ['Oh',
#    'ho',
#    'Is',
#    'this',
#    'the',
#    'first',
#    'time',
#    'u',
#    'use',
#    'these',
#    'type',
#    'of',
#    'words']],
#  [0, ['I', 'think', 'steyn', 'surely', 'get', 'one', 'wicket']],
#  [0,
#   ['Can',
#    'u',
#    'look',
#    '4',
#    'me',
#    'in',
#    'da',
#    'lib',
#    'i',
#    'got',
#    'stuff',
#    'havent',
#    'finish',
#    'yet']],
#  [0,
#   ['Hai',
#    'priya',
#    'are',
#    'you',
#    'right',
#    'What',
#    'doctor',
#    'said',
#    'pa',
#    'Where',
#    'are',
#    'you']],
#  [0,
#   ['U',
#    'ned',
#    'to',
#    'convince',
#    'him',
#    'tht',
#    'its',
#    'not',
#    'possible',
#    'witot',
#    'hurting',
#    'his',
#    'feeling',
#    'its',
#    'the',
#    'main']],
#  [0, ['Not', 'directly', 'behind', 'Abt', '4', 'rows', 'behind', 'ü']],
#  [0, ['K', 'k', 'congratulation']],
#  [0,
#   ['Moji',
#    'i',
#    'love',
#    'you',
#    'more',
#    'than',
#    'words',
#    'Have',
#    'a',
#    'rich',
#    'day']],
#  [0,
#   ['Lol',
#    'I',
#    'knew',
#    'that',
#    'I',
#    'saw',
#    'him',
#    'in',
#    'the',
#    'dollar',
#    'store']],
#  [0,
#   ['is',
#    'your',
#    'hamster',
#    'dead',
#    'Hey',
#    'so',
#    'tmr',
#    'i',
#    'meet',
#    'you',
#    'at',
#    '1pm',
#    'orchard',
#    'mrt']],
#  [1,
#   ['Update',
#    'Now',
#    '12Mths',
#    'Half',
#    'Price',
#    'Orange',
#    'line',
#    'rental',
#    '400mins',
#    'Call',
#    'MobileUpd8',
#    'on',
#    '08000839402',
#    'or',
#    'call2optout=J5Q']],
#  [0,
#   ['I',
#    'dun',
#    'thk',
#    'i',
#    'll',
#    'quit',
#    'yet',
#    'Hmmm',
#    'can',
#    'go',
#    'jazz',
#    'Yogasana',
#    'oso',
#    'can',
#    'We',
#    'can',
#    'go',
#    'meet',
#    'em',
#    'after',
#    'our',
#    'lessons',
#    'den']],
#  [0,
#   ['How',
#    'are',
#    'you',
#    'with',
#    'moneY',
#    'as',
#    'in',
#    'to',
#    'you',
#    'money',
#    'aint',
#    'a',
#    'thing',
#    'how',
#    'are',
#    'you',
#    'sha']],
#  [0, ['K', 'k', 'how', 'much', 'does', 'it', 'cost']],
#  [0, ['Honey', 'boo', 'I', 'm', 'missing', 'u']],
#  [0,
#   ['Ok',
#    'lor',
#    'Sony',
#    'ericsson',
#    'salesman',
#    'I',
#    'ask',
#    'shuhui',
#    'then',
#    'she',
#    'say',
#    'quite',
#    'gd',
#    '2',
#    'use',
#    'so',
#    'i',
#    'considering']],
#  [0, ['Yes', 'now', 'only', 'saw', 'your', 'message']],
#  [0,
#   ['Hi',
#    'juan',
#    'Im',
#    'coming',
#    'home',
#    'on',
#    'fri',
#    'hey',
#    'Of',
#    'course',
#    'i',
#    'expect',
#    'a',
#    'welcome',
#    'party',
#    'and',
#    'lots',
#    'of',
#    'presents',
#    'Ill',
#    'phone',
#    'u',
#    'when',
#    'i',
#    'get',
#    'back',
#    'Loads',
#    'of',
#    'love',
#    'nicky',
#    'x',
#    'x',
#    'x',
#    'x',
#    'x',
#    'x',
#    'x',
#    'x',
#    'x']],
#  [0,
#   ['Nowadays',
#    'people',
#    'are',
#    'notixiquating',
#    'the',
#    'laxinorficated',
#    'opportunity',
#    'for',
#    'bambling',
#    'of',
#    'entropication',
#    'Have',
#    'you',
#    'ever',
#    'oblisingately',
#    'opted',
#    'ur',
#    'books',
#    'for',
#    'the',
#    'masteriastering',
#    'amplikater',
#    'of',
#    'fidalfication',
#    'It',
#    'is',
#    'very',
#    'champlaxigating',
#    'i',
#    'think',
#    'it',
#    'is',
#    'atrocious',
#    'Wotz',
#    'Ur',
#    'Opinion',
#    'Junna']],
#  [0, ['Then', 'wat', 'r', 'u', 'doing', 'now', 'Busy', 'wif', 'work']],
#  [0,
#   ['You',
#    'know',
#    'there',
#    'is',
#    'I',
#    'shall',
#    'speak',
#    'to',
#    'you',
#    'in',
#    'lt',
#    'gt',
#    'minutes',
#    'then']],
#  [0,
#   ['Some',
#    'friends',
#    'want',
#    'me',
#    'to',
#    'drive',
#    'em',
#    'someplace',
#    'probably',
#    'take',
#    'a',
#    'while']],
#  [0,
#   ['I',
#    'can',
#    't',
#    'believe',
#    'how',
#    'attached',
#    'I',
#    'am',
#    'to',
#    'seeing',
#    'you',
#    'every',
#    'day',
#    'I',
#    'know',
#    'you',
#    'will',
#    'do',
#    'the',
#    'best',
#    'you',
#    'can',
#    'to',
#    'get',
#    'to',
#    'me',
#    'babe',
#    'I',
#    'will',
#    'go',
#    'to',
#    'teach',
#    'my',
#    'class',
#    'at',
#    'your',
#    'midnight']],
#  [0,
#   ['How',
#    's',
#    'it',
#    'going',
#    'Got',
#    'any',
#    'exciting',
#    'karaoke',
#    'type',
#    'activities',
#    'planned',
#    'I',
#    'm',
#    'debating',
#    'whether',
#    'to',
#    'play',
#    'football',
#    'this',
#    'eve',
#    'Feeling',
#    'lazy',
#    'though']],
#  [0,
#   ['So',
#    'how',
#    'are',
#    'you',
#    'really',
#    'What',
#    'are',
#    'you',
#    'up',
#    'to',
#    'How',
#    's',
#    'the',
#    'masters',
#    'And',
#    'so',
#    'on']],
#  [0,
#   ['Okay',
#    'lor',
#    'Will',
#    'they',
#    'still',
#    'let',
#    'us',
#    'go',
#    'a',
#    'not',
#    'ah',
#    'Coz',
#    'they',
#    'will',
#    'not',
#    'know',
#    'until',
#    'later',
#    'We',
#    'drop',
#    'our',
#    'cards',
#    'into',
#    'the',
#    'box',
#    'right']],
#  [0,
#   ['Don',
#    't',
#    'necessarily',
#    'expect',
#    'it',
#    'to',
#    'be',
#    'done',
#    'before',
#    'you',
#    'get',
#    'back',
#    'though',
#    'because',
#    'I',
#    'm',
#    'just',
#    'now',
#    'headin',
#    'out']],
#  [0,
#   ['FRAN',
#    'I',
#    'DECIDED',
#    '2',
#    'GO',
#    'N',
#    'E',
#    'WAY',
#    'IM',
#    'COMPLETELY',
#    'BROKE',
#    'AN',
#    'KNACKERED',
#    'I',
#    'GOT',
#    'UP',
#    'BOUT',
#    '3',
#    'C',
#    'U',
#    '2MRW',
#    'LOVE',
#    'JANX',
#    'P',
#    'S',
#    'THIS',
#    'IS',
#    'MY',
#    'DADS',
#    'FONE',
#    'NO',
#    'CREDIT']],
#  [0, ['Ok', 'no', 'prob', 'Take', 'ur', 'time']],
#  [0,
#   ['Call',
#    'me',
#    'when',
#    'u',
#    'finish',
#    'then',
#    'i',
#    'come',
#    'n',
#    'pick',
#    'u']],
#  [0,
#   ['Prabha', 'i', 'm', 'soryda', 'realy', 'frm', 'heart', 'i', 'm', 'sory']],
#  [0,
#   ['What',
#    'do',
#    'you',
#    'do',
#    'my',
#    'dog',
#    'Must',
#    'I',
#    'always',
#    'wait',
#    'till',
#    'the',
#    'end',
#    'of',
#    'your',
#    'day',
#    'to',
#    'have',
#    'word',
#    'from',
#    'you',
#    'Did',
#    'you',
#    'run',
#    'out',
#    'of',
#    'time',
#    'on',
#    'your',
#    'cell',
#    'already']],
#  [0,
#   ['Yup',
#    'i',
#    'thk',
#    'they',
#    'r',
#    'e',
#    'teacher',
#    'said',
#    'that',
#    'will',
#    'make',
#    'my',
#    'face',
#    'look',
#    'longer',
#    'Darren',
#    'ask',
#    'me',
#    'not',
#    '2',
#    'cut',
#    'too',
#    'short']],
#  [0, ['O', 'was', 'not', 'into', 'fps', 'then']],
#  [0, ['i', 'want', 'to', 'grasp', 'your', 'pretty', 'booty']],
#  [0, ['Wife', 'how', 'she', 'knew', 'the', 'time', 'of', 'murder', 'exactly']],
#  [0,
#   ['Sorry',
#    'I',
#    'll',
#    'call',
#    'you',
#    'later',
#    'I',
#    'am',
#    'in',
#    'meeting',
#    'sir']],
#  [0,
#   ['Ahhhh',
#    'just',
#    'woken',
#    'up',
#    'had',
#    'a',
#    'bad',
#    'dream',
#    'about',
#    'u',
#    'tho',
#    'so',
#    'i',
#    'dont',
#    'like',
#    'u',
#    'right',
#    'now',
#    'i',
#    'didnt',
#    'know',
#    'anything',
#    'about',
#    'comedy',
#    'night',
#    'but',
#    'i',
#    'guess',
#    'im',
#    'up',
#    'for',
#    'it']],
#  [0, ['Stupid', 'its', 'not', 'possible']],
#  [0, ['U', 'don', 't', 'remember', 'that', 'old', 'commercial']],
#  [0, ['Yesterday', 'its', 'with', 'me', 'only', 'Now', 'am', 'going', 'home']],
#  [0,
#   ['I',
#    'll',
#    'be',
#    'in',
#    'sch',
#    'fr',
#    '4',
#    '6',
#    'I',
#    'dun',
#    'haf',
#    'da',
#    'book',
#    'in',
#    'sch',
#    'It',
#    's',
#    'at',
#    'home']],
#  [0, ['That', 's', 'cause', 'your', 'old', 'I', 'live', 'to', 'be', 'high']],
#  [0,
#   ['If', 'you', 're', 'thinking', 'of', 'lifting', 'me', 'one', 'then', 'no']],
#  [0,
#   ['When',
#    'people',
#    'see',
#    'my',
#    'msgs',
#    'They',
#    'think',
#    'Iam',
#    'addicted',
#    'to',
#    'msging',
#    'They',
#    'are',
#    'wrong',
#    'Bcoz',
#    'They',
#    'don\\',
#    't',
#    'know',
#    'that',
#    'Iam',
#    'addicted',
#    'to',
#    'my',
#    'sweet',
#    'Friends',
#    'BSLVYL']],
#  [0,
#   ['Jokin',
#    'only',
#    'lar',
#    'depends',
#    'on',
#    'which',
#    'phone',
#    'my',
#    'father',
#    'can',
#    'get',
#    'lor']],
#  [0,
#   ['Sorry',
#    'man',
#    'my',
#    'stash',
#    'ran',
#    'dry',
#    'last',
#    'night',
#    'and',
#    'I',
#    'can',
#    't',
#    'pick',
#    'up',
#    'more',
#    'until',
#    'sunday']],
#  [0, ['U', 'sure', 'u', 'can', 't', 'take', 'any', 'sick', 'time']],
#  [0,
#   ['Wow',
#    'I',
#    'love',
#    'you',
#    'sooo',
#    'much',
#    'you',
#    'know',
#    'I',
#    'can',
#    'barely',
#    'stand',
#    'it',
#    'I',
#    'wonder',
#    'how',
#    'your',
#    'day',
#    'goes',
#    'and',
#    'if',
#    'you',
#    'are',
#    'well',
#    'my',
#    'love',
#    'I',
#    'think',
#    'of',
#    'you',
#    'and',
#    'miss',
#    'you']],
#  [0,
#   ['Boo',
#    'what',
#    'time',
#    'u',
#    'get',
#    'out',
#    'U',
#    'were',
#    'supposed',
#    'to',
#    'take',
#    'me',
#    'shopping',
#    'today']],
#  [0,
#   ['Kind',
#    'of',
#    'Just',
#    'missed',
#    'train',
#    'cos',
#    'of',
#    'asthma',
#    'attack',
#    'nxt',
#    'one',
#    'in',
#    'half',
#    'hr',
#    'so',
#    'driving',
#    'in',
#    'not',
#    'sure',
#    'where',
#    'to',
#    'park']],
#  [1,
#   ['I',
#    'don',
#    't',
#    'know',
#    'u',
#    'and',
#    'u',
#    'don',
#    't',
#    'know',
#    'me',
#    'Send',
#    'CHAT',
#    'to',
#    '86688',
#    'now',
#    'and',
#    'let',
#    's',
#    'find',
#    'each',
#    'other',
#    'Only',
#    '150p/Msg',
#    'rcvd',
#    'HG/Suite342/2Lands/Row/W1J6HL',
#    'LDN',
#    '18',
#    'years',
#    'or',
#    'over']],
#  [0, ['Wat', 'time', 'liao', 'where', 'still', 'got']],
#  [0, ['My', 'battery', 'is', 'low', 'babe']],
#  [0, ['Ok']],
#  [0, ['Nan', 'sonathaya', 'soladha', 'Why', 'boss']],
#  [1,
#   ['Congratulations',
#    'ur',
#    'awarded',
#    '500',
#    'of',
#    'CD',
#    'vouchers',
#    'or',
#    '125gift',
#    'guaranteed',
#    'Free',
#    'entry',
#    '2',
#    '100',
#    'wkly',
#    'draw',
#    'txt',
#    'MUSIC',
#    'to',
#    '87066',
#    'TnCs',
#    'www',
#    'Ldew',
#    'com1win150ppmx3age16']],
#  [0,
#   ['This',
#    'single',
#    'single',
#    'answers',
#    'are',
#    'we',
#    'fighting',
#    'Plus',
#    'i',
#    'said',
#    'am',
#    'broke',
#    'and',
#    'you',
#    'didnt',
#    'reply']],
#  [0,
#   ['Im',
#    'sorry',
#    'bout',
#    'last',
#    'nite',
#    'it',
#    'wasn\x92t',
#    'ur',
#    'fault',
#    'it',
#    'was',
#    'me',
#    'spouse',
#    'it',
#    'was',
#    'pmt',
#    'or',
#    'sumthin',
#    'U',
#    '4give',
#    'me',
#    'I',
#    'think',
#    'u',
#    'shldxxxx']],
#  [0,
#   ['Call',
#    'him',
#    'and',
#    'say',
#    'you',
#    'not',
#    'coming',
#    'today',
#    'ok',
#    'and',
#    'tell',
#    'them',
#    'not',
#    'to',
#    'fool',
#    'me',
#    'like',
#    'this',
#    'ok']],
#  [0,
#   ['Do',
#    'u',
#    'konw',
#    'waht',
#    'is',
#    'rael',
#    'FRIENDSHIP',
#    'Im',
#    'gving',
#    'yuo',
#    'an',
#    'exmpel',
#    'Jsut',
#    'ese',
#    'tihs',
#    'msg',
#    'Evrey',
#    'splleing',
#    'of',
#    'tihs',
#    'msg',
#    'is',
#    'wrnog',
#    'Bt',
#    'sitll',
#    'yuo',
#    'can',
#    'raed',
#    'it',
#    'wihtuot',
#    'ayn',
#    'mitsake',
#    'GOODNIGHT',
#    'amp',
#    'HAVE',
#    'A',
#    'NICE',
#    'SLEEP',
#    'SWEET',
#    'DREAMS']],
#  [0, ['I', 'will', 'reach', 'before', 'ten', 'morning']],
#  [0,
#   ['Daddy',
#    'shu',
#    'shu',
#    'is',
#    'looking',
#    '4',
#    'u',
#    'U',
#    'wan',
#    'me',
#    '2',
#    'tell',
#    'him',
#    'u',
#    're',
#    'not',
#    'in',
#    'singapore',
#    'or',
#    'wat']],
#  [0, ['Wat', 'time', 'u', 'finish', 'ur', 'lect', 'today']],
#  [0, ['Yes', 'see', 'ya', 'not', 'on', 'the', 'dot']],
#  [0,
#   ['Sounds',
#    'like',
#    'a',
#    'plan',
#    'Cardiff',
#    'is',
#    'still',
#    'here',
#    'and',
#    'still',
#    'cold',
#    'I',
#    'm',
#    'sitting',
#    'on',
#    'the',
#    'radiator']],
#  [0, ['Cuz', 'ibored', 'And', 'don', 'wanna', 'study']],
#  [0,
#   ['No',
#    'da',
#    'he',
#    'is',
#    'stupid',
#    'da',
#    'always',
#    'sending',
#    'like',
#    'this',
#    'don',
#    'believe',
#    'any',
#    'of',
#    'those',
#    'message',
#    'pandy',
#    'is',
#    'a',
#    'mental']],
#  [0,
#   ['I',
#    'can',
#    't',
#    'describe',
#    'how',
#    'lucky',
#    'you',
#    'are',
#    'that',
#    'I',
#    'm',
#    'actually',
#    'awake',
#    'by',
#    'noon']],
#  [1,
#   ['WOW',
#    'The',
#    'Boys',
#    'R',
#    'Back',
#    'TAKE',
#    'THAT',
#    '2007',
#    'UK',
#    'Tour',
#    'Win',
#    'VIP',
#    'Tickets',
#    'pre',
#    'book',
#    'with',
#    'VIP',
#    'Club',
#    'Txt',
#    'CLUB',
#    'to',
#    '81303',
#    'Trackmarque',
#    'Ltd',
#    'info@vipclub4u']],
#  [0, ['I', 'll', 'probably', 'be', 'around', 'mu', 'a', 'lot']],
#  [0,
#   ['I',
#    'want',
#    'to',
#    'send',
#    'something',
#    'that',
#    'can',
#    'sell',
#    'fast',
#    'lt',
#    'gt',
#    'k',
#    'is',
#    'not',
#    'easy',
#    'money']],
#  [0, ['I', 'want', 'lt', 'gt', 'rs', 'da', 'do', 'you', 'have', 'it']],
#  [0,
#   ['Under',
#    'the',
#    'sea',
#    'there',
#    'lays',
#    'a',
#    'rock',
#    'In',
#    'the',
#    'rock',
#    'there',
#    'is',
#    'an',
#    'envelope',
#    'In',
#    'the',
#    'envelope',
#    'there',
#    'is',
#    'a',
#    'paper',
#    'On',
#    'the',
#    'paper',
#    'there',
#    'are',
#    '3',
#    'words']],
#  [0, ['Why', 'are', 'u', 'up', 'so', 'early']],
#  [0, ['ok', 'take', 'care', 'umma', 'to', 'you', 'too']],
#  [0, ['Nope', 'Juz', 'off', 'from', 'work']],
#  [0,
#   ['Miserable',
#    'They',
#    'don',
#    't',
#    'tell',
#    'u',
#    'that',
#    'the',
#    'side',
#    'effects',
#    'of',
#    'birth',
#    'control',
#    'are',
#    'massive',
#    'gut',
#    'wrenching',
#    'cramps',
#    'for',
#    'the',
#    'first',
#    '2',
#    'months',
#    'I',
#    'didn',
#    't',
#    'sleep',
#    'at',
#    'all',
#    'last',
#    'night']],
#  [0,
#   ['Gud', 'gud', 'k', 'chikku', 'tke', 'care', 'sleep', 'well', 'gud', 'nyt']],
#  [0,
#   ['Uhhhhrmm',
#    'isnt',
#    'having',
#    'tb',
#    'test',
#    'bad',
#    'when',
#    'youre',
#    'sick']],
#  [0,
#   ['I',
#    'm',
#    'thinking',
#    'that',
#    'chennai',
#    'forgot',
#    'to',
#    'come',
#    'for',
#    'auction']],
#  [1,
#   ['Your',
#    'credits',
#    'have',
#    'been',
#    'topped',
#    'up',
#    'for',
#    'http',
#    '//www',
#    'bubbletext',
#    'com',
#    'Your',
#    'renewal',
#    'Pin',
#    'is',
#    'tgxxrz']],
#  [1,
#   ['FreeMsg',
#    'Why',
#    'haven',
#    't',
#    'you',
#    'replied',
#    'to',
#    'my',
#    'text',
#    'I',
#    'm',
#    'Randy',
#    'sexy',
#    'female',
#    'and',
#    'live',
#    'local',
#    'Luv',
#    'to',
#    'hear',
#    'from',
#    'u',
#    'Netcollex',
#    'Ltd',
#    '08700621170150p',
#    'per',
#    'msg',
#    'reply',
#    'Stop',
#    'to',
#    'end']],
#  [1,
#   ['FREE',
#    'MESSAGE',
#    'Activate',
#    'your',
#    '500',
#    'FREE',
#    'Text',
#    'Messages',
#    'by',
#    'replying',
#    'to',
#    'this',
#    'message',
#    'with',
#    'the',
#    'word',
#    'FREE',
#    'For',
#    'terms',
#    'conditions',
#    'visit',
#    'www',
#    '07781482378',
#    'com']],
#  [0, ['oh', 'well', 'c', 'u', 'later']],
#  [0, ['get', 'ready', 'to', 'moan', 'and', 'scream']],
#  [1,
#   ['URGENT',
#    'Your',
#    'Mobile',
#    'number',
#    'has',
#    'been',
#    'awarded',
#    'a',
#    '<UKP>2000',
#    'prize',
#    'GUARANTEED',
#    'Call',
#    '09061790125',
#    'from',
#    'landline',
#    'Claim',
#    '3030',
#    'Valid',
#    '12hrs',
#    'only',
#    '150ppm']],
#  [0,
#   ['I',
#    've',
#    'reached',
#    'home',
#    'n',
#    'i',
#    'bathe',
#    'liao',
#    'U',
#    'can',
#    'call',
#    'me',
#    'now']],
#  [0,
#   ['What',
#    'i',
#    'mean',
#    'was',
#    'i',
#    'left',
#    'too',
#    'early',
#    'to',
#    'check',
#    'cos',
#    'i',
#    'm',
#    'working',
#    'a',
#    '9',
#    '6']],
#  [0, ['Probably', 'a', 'couple', 'hours', 'tops']],
#  [0,
#   ['You',
#    'at',
#    'mu',
#    'You',
#    'should',
#    'try',
#    'to',
#    'figure',
#    'out',
#    'how',
#    'much',
#    'money',
#    'everyone',
#    'has',
#    'for',
#    'gas',
#    'and',
#    'alcohol',
#    'jay',
#    'and',
#    'I',
#    'are',
#    'trying',
#    'to',
#    'figure',
#    'out',
#    'our',
#    'weed',
#    'budget']],
#  [0,
#   ['Am', 'I', 'the', 'only', 'one', 'who', 'doesn', 't', 'stalk', 'profiles']],
#  [0, ['Bugis', 'oso', 'near', 'wat']],
#  [0, ['Yes', 'when', 'is', 'the', 'appt', 'again']],
#  [0,
#   ['Hi',
#    'its',
#    'in',
#    'durban',
#    'are',
#    'you',
#    'still',
#    'on',
#    'this',
#    'number']],
#  [0,
#   ['Thinkin',
#    'about',
#    'someone',
#    'is',
#    'all',
#    'good',
#    'No',
#    'drugs',
#    'for',
#    'that']],
#  [0, ['Alright', 'I', 'm', 'out', 'have', 'a', 'good', 'night']],
#  [0,
#   ['Too',
#    'late',
#    'I',
#    'said',
#    'i',
#    'have',
#    'the',
#    'website',
#    'I',
#    'didn',
#    't',
#    'i',
#    'have',
#    'or',
#    'dont',
#    'have',
#    'the',
#    'slippers']],
#  [0, ['Come', 'to', 'mahal', 'bus', 'stop', 'lt', 'DECIMAL', 'gt']],
#  [0, ['Sorry', 'I', 'll', 'call', 'later']],
#  [0,
#   ['The',
#    'fact',
#    'that',
#    'you',
#    're',
#    'cleaning',
#    'shows',
#    'you',
#    'know',
#    'why',
#    'i',
#    'm',
#    'upset',
#    'Your',
#    'priority',
#    'is',
#    'constantly',
#    'what',
#    'i',
#    'want',
#    'to',
#    'do',
#    'not',
#    'what',
#    'i',
#    'need',
#    'to',
#    'do']],
#  [0,
#   ['Never',
#    'blame',
#    'a',
#    'day',
#    'in',
#    'ur',
#    'life',
#    'Good',
#    'days',
#    'give',
#    'u',
#    'happiness',
#    'Bad',
#    'days',
#    'give',
#    'u',
#    'experience',
#    'Both',
#    'are',
#    'essential',
#    'in',
#    'life',
#    'All',
#    'are',
#    'Gods',
#    'blessings',
#    'good',
#    'morning']],
#  [0, ['No', 'Did', 'you', 'multimedia', 'message', 'them', 'or', 'e', 'mail']],
#  [0,
#   ['You',
#    'do',
#    'your',
#    'studies',
#    'alone',
#    'without',
#    'anyones',
#    'help',
#    'If',
#    'you',
#    'cant',
#    'no',
#    'need',
#    'to',
#    'study']],
#  [0, ['Oh', 'ic', 'I', 'thought', 'you', 'meant', 'mary', 'jane']],
#  [0, ['Have', 'a', 'good', 'evening', 'Ttyl']],
#  [1,
#   ['Todays',
#    'Voda',
#    'numbers',
#    'ending',
#    '5226',
#    'are',
#    'selected',
#    'to',
#    'receive',
#    'a',
#    '350',
#    'award',
#    'If',
#    'you',
#    'hava',
#    'a',
#    'match',
#    'please',
#    'call',
# ...
#  [0,
#   ['How',
#    'are',
#    'you',
#    'doing',
#    'Hope',
#    'you',
#    've',
#    'settled',
#    'in',
#    'for',
#    'the',
#    'new',
#    'school',
#    'year',
#    'Just',
#    'wishin',
#    'you',
#    'a',
#    'gr8',
#    'day']],
#  [0, ['Long', 'beach', 'lor', 'Expected', 'U', 'having', 'dinner', 'now']],
#  [0,
#   ['U',
#    're',
#    'welcome',
#    'Caught',
#    'u',
#    'using',
#    'broken',
#    'english',
#    'again']],
#  [0, ['I', 'am', 'in', 'tirupur', 'call', 'you', 'da']],
#  [0,
#   ['So',
#    'lets',
#    'make',
#    'it',
#    'saturday',
#    'or',
#    'monday',
#    'as',
#    'per',
#    'convenience']],
#  [0,
#   ['Hi',
#    'i',
#    'won',
#    't',
#    'b',
#    'ard',
#    '4',
#    'christmas',
#    'But',
#    'do',
#    'enjoy',
#    'n',
#    'merry',
#    'x',
#    'mas']],
#  [1,
#   ['<Forwarded',
#    'from',
#    '448712404000>Please',
#    'CALL',
#    '08712404000',
#    'immediately',
#    'as',
#    'there',
#    'is',
#    'an',
#    'urgent',
#    'message',
#    'waiting',
#    'for',
#    'you']],
#  [0,
#   ['Text',
#    'her',
#    'If',
#    'she',
#    'doesnt',
#    'reply',
#    'let',
#    'me',
#    'know',
#    'so',
#    'i',
#    'can',
#    'have',
#    'her',
#    'log',
#    'in']],
#  [0, ['I', 'have', 'to', 'take', 'exam', 'with', 'in', 'march', '3']],
#  [0,
#   ['Ok',
#    'i',
#    'wont',
#    'call',
#    'or',
#    'disturb',
#    'any',
#    'one',
#    'I',
#    'know',
#    'all',
#    'are',
#    'avoiding',
#    'me',
#    'I',
#    'am',
#    'a',
#    'burden',
#    'for',
#    'all']],
#  [0, ['yes', 'baby', 'I', 'need', 'to', 'stretch', 'open', 'your', 'pussy']],
#  [0, ['Are', 'you', 'staying', 'in', 'town']],
#  [0, ['No', 'jst', 'change', 'tat', 'only']],
#  [0, ['I', 'm', 'going', 'out', 'to', 'buy', 'mum', 's', 'present', 'ar']],
#  [0,
#   ['I',
#    'm',
#    'still',
#    'looking',
#    'for',
#    'a',
#    'car',
#    'to',
#    'buy',
#    'And',
#    'have',
#    'not',
#    'gone',
#    '4the',
#    'driving',
#    'test',
#    'yet']],
#  [0, ['Whatever', 'juliana', 'Do', 'whatever', 'you', 'want']],
#  [0,
#   ['It',
#    'doesnt',
#    'make',
#    'sense',
#    'to',
#    'take',
#    'it',
#    'there',
#    'unless',
#    'its',
#    'free',
#    'If',
#    'you',
#    'need',
#    'to',
#    'know',
#    'more',
#    'wikipedia',
#    'com']],
#  [0,
#   ['Am',
#    'going',
#    'to',
#    'take',
#    'bath',
#    'ill',
#    'place',
#    'the',
#    'key',
#    'in',
#    'window']],
#  [0,
#   ['Your', 'daily', 'text', 'from', 'me', '–', 'a', 'favour', 'this', 'time']],
#  [0,
#   ['I',
#    'will',
#    'lick',
#    'up',
#    'every',
#    'drop',
#    'are',
#    'you',
#    'ready',
#    'to',
#    'use',
#    'your',
#    'mouth',
#    'as',
#    'well']],
#  [0,
#   ['Hi',
#    'Hope',
#    'ur',
#    'day',
#    '*',
#    'good',
#    'Back',
#    'from',
#    'walk',
#    'table',
#    'booked',
#    'for',
#    'half',
#    'eight',
#    'Let',
#    'me',
#    'know',
#    'when',
#    'ur',
#    'coming',
#    'over']],
#  [0, ['If', 'i', 'said', 'anything', 'wrong', 'sorry', 'de']],
#  [0,
#   ['i',
#    'felt',
#    'so',
#    'not',
#    'any',
#    'conveying',
#    'reason',
#    'Ese',
#    'he',
#    'What',
#    'about',
#    'me']],
#  [0,
#   ['OH',
#    'FUCK',
#    'JUSWOKE',
#    'UP',
#    'IN',
#    'A',
#    'BED',
#    'ON',
#    'A',
#    'BOATIN',
#    'THE',
#    'DOCKS',
#    'SLEPT',
#    'WID',
#    '25',
#    'YEAR',
#    'OLD',
#    'SPINOUT',
#    'GIV',
#    'U',
#    'DA',
#    'GOSSIP',
#    'L8R',
#    'XXX']],
#  [0, ['Ok', 'Take', 'ur', 'time', 'n', 'enjoy', 'ur', 'dinner']],
#  [0, ['What', 'about', 'this', 'one', 'then']],
#  [0, ['Why', 'you', 'Dint', 'come', 'with', 'us']],
#  [0, ['Not', 'yet', 'chikku', 'wat', 'abt', 'u']],
#  [1,
#   ['important',
#    'information',
#    '4',
#    'orange',
#    'user',
#    '0789xxxxxxx',
#    'today',
#    'is',
#    'your',
#    'lucky',
#    'day',
#    '2find',
#    'out',
#    'why',
#    'log',
#    'onto',
#    'http',
#    '//www',
#    'urawinner',
#    'com',
#    'THERE',
#    'S',
#    'A',
#    'FANTASTIC',
#    'SURPRISE',
#    'AWAITING',
#    'YOU']],
#  [0,
#   ['Bill',
#    'as',
#    'in',
#    'Are',
#    'there',
#    'any',
#    'letters',
#    'for',
#    'me',
#    'i’m',
#    'expecting',
#    'one',
#    'from',
#    'orange',
#    'that',
#    'isn’t',
#    'a',
#    'bill',
#    'but',
#    'may',
#    'still',
#    'say',
#    'orange',
#    'on',
#    'it']],
#  [0,
#   ['Sorry',
#    'vikky',
#    'i',
#    'm',
#    'Watching',
#    'olave',
#    'mandara',
#    'movie',
#    'kano',
#    'in',
#    'trishul',
#    'theatre',
#    'wit',
#    'my',
#    'frnds']],
#  [0,
#   ['Is',
#    'there',
#    'any',
#    'movie',
#    'theatre',
#    'i',
#    'can',
#    'go',
#    'to',
#    'and',
#    'watch',
#    'unlimited',
#    'movies',
#    'and',
#    'just',
#    'pay',
#    'once']],
#  [0,
#   ['Yeah',
#    'in',
#    'fact',
#    'he',
#    'just',
#    'asked',
#    'if',
#    'we',
#    'needed',
#    'anything',
#    'like',
#    'an',
#    'hour',
#    'ago',
#    'When',
#    'and',
#    'how',
#    'much']],
#  [0,
#   ['Ditto',
#    'And',
#    'you',
#    'won',
#    't',
#    'have',
#    'to',
#    'worry',
#    'about',
#    'me',
#    'saying',
#    'ANYTHING',
#    'to',
#    'you',
#    'anymore',
#    'Like',
#    'i',
#    'said',
#    'last',
#    'night',
#    'you',
#    'do',
#    'whatever',
#    'you',
#    'want',
#    'and',
#    'i',
#    'll',
#    'do',
#    'the',
#    'same',
#    'Peace']],
#  [0,
#   ['Long',
#    'after',
#    'I',
#    'quit',
#    'I',
#    'get',
#    'on',
#    'only',
#    'like',
#    '5',
#    'minutes',
#    'a',
#    'day',
#    'as',
#    'it',
#    'is']],
#  [0,
#   ['Thats',
#    'cool',
#    'i',
#    'liked',
#    'your',
#    'photos',
#    'You',
#    'are',
#    'very',
#    'sexy']],
#  [0,
#   ['I',
#    'realise',
#    'you',
#    'are',
#    'a',
#    'busy',
#    'guy',
#    'and',
#    'i',
#    'm',
#    'trying',
#    'not',
#    'to',
#    'be',
#    'a',
#    'bother',
#    'I',
#    'have',
#    'to',
#    'get',
#    'some',
#    'exams',
#    'outta',
#    'the',
#    'way',
#    'and',
#    'then',
#    'try',
#    'the',
#    'cars',
#    'Do',
#    'have',
#    'a',
#    'gr8',
#    'day']],
#  [0, ['Omg', 'how', 'did', 'u', 'know', 'what', 'I', 'ate']],
#  [0,
#   ['I',
#    'take',
#    'it',
#    'we',
#    'didn',
#    't',
#    'have',
#    'the',
#    'phone',
#    'callon',
#    'Friday',
#    'Can',
#    'we',
#    'assume',
#    'we',
#    'won',
#    't',
#    'have',
#    'it',
#    'this',
#    'year',
#    'now']],
#  [1,
#   ['Guess',
#    'what',
#    'Somebody',
#    'you',
#    'know',
#    'secretly',
#    'fancies',
#    'you',
#    'Wanna',
#    'find',
#    'out',
#    'who',
#    'it',
#    'is',
#    'Give',
#    'us',
#    'a',
#    'call',
#    'on',
#    '09065394514',
#    'From',
#    'Landline',
#    'DATEBox1282EssexCM61XN',
#    '150p/min',
#    '18']],
#  [0, ['As', 'usual', 'iam', 'fine', 'happy', 'amp', 'doing', 'well']],
#  [0, ['Ta', 'Daaaaa', 'I', 'am', 'home', 'babe', 'are', 'you', 'still', 'up']],
#  [0, ['Me', 'i', 'm', 'not', 'workin', 'Once', 'i', 'get', 'job']],
#  [0,
#   ['You',
#    'busy',
#    'or',
#    'can',
#    'I',
#    'come',
#    'by',
#    'at',
#    'some',
#    'point',
#    'and',
#    'figure',
#    'out',
#    'what',
#    'we',
#    're',
#    'doing',
#    'tomorrow']],
#  [0,
#   ['I',
#    'think',
#    'I‘m',
#    'waiting',
#    'for',
#    'the',
#    'same',
#    'bus',
#    'Inform',
#    'me',
#    'when',
#    'you',
#    'get',
#    'there',
#    'if',
#    'you',
#    'ever',
#    'get',
#    'there']],
#  [0,
#   ['K',
#    'ill',
#    'drink',
#    'pa',
#    'then',
#    'what',
#    'doing',
#    'I',
#    'need',
#    'srs',
#    'model',
#    'pls',
#    'send',
#    'it',
#    'to',
#    'my',
#    'mail',
#    'id',
#    'pa']],
#  [0, ['Yeah', 'whatever', 'lol']],
#  [0,
#   ['Doesn',
#    't',
#    'g',
#    'have',
#    'class',
#    'early',
#    'tomorrow',
#    'and',
#    'thus',
#    'shouldn',
#    't',
#    'be',
#    'trying',
#    'to',
#    'smoke',
#    'at',
#    'lt',
#    'gt']],
#  [0, ['So', 'can', 'collect', 'ur', 'laptop']],
#  [0, ['It', 'took', 'Mr', 'owl', '3', 'licks']],
#  [1,
#   ['Congratulations',
#    'U',
#    'can',
#    'claim',
#    '2',
#    'VIP',
#    'row',
#    'A',
#    'Tickets',
#    '2',
#    'C',
#    'Blu',
#    'in',
#    'concert',
#    'in',
#    'November',
#    'or',
#    'Blu',
#    'gift',
#    'guaranteed',
#    'Call',
#    '09061104276',
#    'to',
#    'claim',
#    'TS',
#    'Cs',
#    'www',
#    'smsco',
#    'net',
#    'cost£3',
#    '75max']],
#  [0,
#   ['Mystery',
#    'solved',
#    'Just',
#    'opened',
#    'my',
#    'email',
#    'and',
#    'he',
#    's',
#    'sent',
#    'me',
#    'another',
#    'batch',
#    'Isn',
#    't',
#    'he',
#    'a',
#    'sweetie']],
#  [0,
#   ['Should',
#    'i',
#    'buy',
#    'him',
#    'a',
#    'blackberry',
#    'bold',
#    '2',
#    'or',
#    'torch',
#    'Should',
#    'i',
#    'buy',
#    'him',
#    'new',
#    'or',
#    'used',
#    'Let',
#    'me',
#    'know',
#    'Plus',
#    'are',
#    'you',
#    'saying',
#    'i',
#    'should',
#    'buy',
#    'the',
#    'lt',
#    'gt',
#    'g',
#    'wifi',
#    'ipad',
#    'And',
#    'what',
#    'are',
#    'you',
#    'saying',
#    'about',
#    'the',
#    'about',
#    'the',
#    'lt',
#    'gt',
#    'g']],
#  [0, ['Are', 'you', 'in', 'castor', 'You', 'need', 'to', 'see', 'something']],
#  [0, ['I', 'm', 'done', 'oredi']],
#  [0,
#   ['Just',
#    'come',
#    'home',
#    'I',
#    'don',
#    't',
#    'want',
#    'u',
#    'to',
#    'be',
#    'miserable']],
#  [0,
#   ['Aiyah',
#    'e',
#    'rain',
#    'like',
#    'quite',
#    'big',
#    'leh',
#    'If',
#    'drizzling',
#    'i',
#    'can',
#    'at',
#    'least',
#    'run',
#    'home']],
#  [0, ['No', 'chikku', 'nt', 'yet', 'Ya', 'i', 'm', 'free']],
#  [0,
#   ['I',
#    'think',
#    'your',
#    'mentor',
#    'is',
#    'but',
#    'not',
#    '100',
#    'percent',
#    'sure']],
#  [0, ['K', 'I', 'll', 'work', 'something', 'out']],
#  [0, ['Got', 'it', 'mail', 'panren', 'paru']],
#  [0, ['Discussed', 'with', 'your', 'mother', 'ah']],
#  [0,
#   ['Waiting',
#    'in',
#    'e',
#    'car',
#    '4',
#    'my',
#    'mum',
#    'lor',
#    'U',
#    'leh',
#    'Reach',
#    'home',
#    'already']],
#  [1,
#   ['Would',
#    'you',
#    'like',
#    'to',
#    'see',
#    'my',
#    'XXX',
#    'pics',
#    'they',
#    'are',
#    'so',
#    'hot',
#    'they',
#    'were',
#    'nearly',
#    'banned',
#    'in',
#    'the',
#    'uk']],
#  [0,
#   ['Well',
#    'welp',
#    'is',
#    'sort',
#    'of',
#    'a',
#    'semiobscure',
#    'internet',
#    'thing']],
#  [0, ['Thanx', 'a', 'lot', '4', 'ur', 'help']],
#  [0, ['Its', 'normally', 'hot', 'mail', 'Com', 'you', 'see']],
#  [0,
#   ['Finally',
#    'it',
#    'has',
#    'happened',
#    'Aftr',
#    'decades',
#    'BEER',
#    'is',
#    'now',
#    'cheaper',
#    'than',
#    'PETROL',
#    'The',
#    'goverment',
#    'expects',
#    'us',
#    'to',
#    'DRINK',
#    'But',
#    'don',
#    't',
#    'DRIVE']],
#  [1,
#   ['Xmas',
#    'New',
#    'Years',
#    'Eve',
#    'tickets',
#    'are',
#    'now',
#    'on',
#    'sale',
#    'from',
#    'the',
#    'club',
#    'during',
#    'the',
#    'day',
#    'from',
#    '10am',
#    'till',
#    '8pm',
#    'and',
#    'on',
#    'Thurs',
#    'Fri',
#    'Sat',
#    'night',
#    'this',
#    'week',
#    'They',
#    're',
#    'selling',
#    'fast']],
#  [0,
#   ['I',
#    'know',
#    'you',
#    'are',
#    'thinkin',
#    'malaria',
#    'But',
#    'relax',
#    'children',
#    'cant',
#    'handle',
#    'malaria',
#    'She',
#    'would',
#    'have',
#    'been',
#    'worse',
#    'and',
#    'its',
#    'gastroenteritis',
#    'If',
#    'she',
#    'takes',
#    'enough',
#    'to',
#    'replace',
#    'her',
#    'loss',
#    'her',
#    'temp',
#    'will',
#    'reduce',
#    'And',
#    'if',
#    'you',
#    'give',
#    'her',
#    'malaria',
#    'meds',
#    'now',
#    'she',
#    'will',
#    'just',
#    'vomit',
#    'Its',
#    'a',
#    'self',
#    'limiting',
#    'illness',
#    'she',
#    'has',
#    'which',
#    'means',
#    'in',
#    'a',
#    'few',
#    'days',
#    'it',
#    'will',
#    'completely',
#    'stop']],
#  [0, ['Good', 'morning', 'princess', 'How', 'are', 'you']],
#  [0, ['Cramps', 'stopped', 'Going', 'back', 'to', 'sleep']],
#  [0,
#   ['Thats',
#    'cool',
#    'Sometimes',
#    'slow',
#    'and',
#    'gentle',
#    'Sonetimes',
#    'rough',
#    'and',
#    'hard']],
#  [0, ['How', 'abt', 'making', 'some', 'of', 'the', 'pics', 'bigger']],
#  [0, ['Thanx', 'but', 'my', 'birthday', 'is', 'over', 'already']],
#  [0,
#   ['And',
#    'whenever',
#    'you',
#    'and',
#    'i',
#    'see',
#    'we',
#    'can',
#    'still',
#    'hook',
#    'up',
#    'too']],
#  [0,
#   ['Er',
#    'hello',
#    'things',
#    'didn‘t',
#    'quite',
#    'go',
#    'to',
#    'plan',
#    '–',
#    'is',
#    'limping',
#    'slowly',
#    'home',
#    'followed',
#    'by',
#    'aa',
#    'and',
#    'with',
#    'exhaust',
#    'hanging',
#    'off']],
#  [0, ['Hows', 'the', 'champ', 'just', 'leaving', 'glasgow']],
#  [0, ['In', 'da', 'car', 'park']],
#  [0,
#   ['Omg',
#    'you',
#    'can',
#    'make',
#    'a',
#    'wedding',
#    'chapel',
#    'in',
#    'frontierville',
#    'Why',
#    'do',
#    'they',
#    'get',
#    'all',
#    'the',
#    'good',
#    'stuff']],
#  [0,
#   ['Hope',
#    'this',
#    'text',
#    'meets',
#    'you',
#    'smiling',
#    'If',
#    'not',
#    'then',
#    'let',
#    'this',
#    'text',
#    'give',
#    'you',
#    'a',
#    'reason',
#    'to',
#    'smile',
#    'Have',
#    'a',
#    'beautiful',
#    'day']],
#  [0,
#   ['Hey',
#    'sexy',
#    'buns',
#    'What',
#    'of',
#    'that',
#    'day',
#    'No',
#    'word',
#    'from',
#    'you',
#    'this',
#    'morning',
#    'on',
#    'YM',
#    'I',
#    'think',
#    'of',
#    'you']],
#  [1,
#   ['A',
#    '£400',
#    'XMAS',
#    'REWARD',
#    'IS',
#    'WAITING',
#    'FOR',
#    'YOU',
#    'Our',
#    'computer',
#    'has',
#    'randomly',
#    'picked',
#    'you',
#    'from',
#    'our',
#    'loyal',
#    'mobile',
#    'customers',
#    'to',
#    'receive',
#    'a',
#    '£400',
#    'reward',
#    'Just',
#    'call',
#    '09066380611']],
#  [1,
#   ['As',
#    'a',
#    'valued',
#    'customer',
#    'I',
#    'am',
#    'pleased',
#    'to',
#    'advise',
#    'you',
#    'that',
#    'following',
#    'recent',
#    'review',
#    'of',
#    'your',
#    'Mob',
#    'No',
#    'you',
#    'are',
#    'awarded',
#    'with',
#    'a',
#    '£1500',
#    'Bonus',
#    'Prize',
#    'call',
#    '09066364589']],
#  [1,
#   ['Am',
#    'new',
#    '2',
#    'club',
#    'dont',
#    'fink',
#    'we',
#    'met',
#    'yet',
#    'Will',
#    'B',
#    'gr8',
#    '2',
#    'C',
#    'U',
#    'Please',
#    'leave',
#    'msg',
#    '2day',
#    'wiv',
#    'ur',
#    'area',
#    '09099726553',
#    'reply',
#    'promised',
#    'CARLIE',
#    'x',
#    'Calls£1/minMobsmore',
#    'LKPOBOX177HP51FL']],
#  [1,
#   ['Had',
#    'your',
#    'mobile',
#    '10',
#    'mths',
#    'Update',
#    'to',
#    'the',
#    'latest',
#    'Camera/Video',
#    'phones',
#    'for',
#    'FREE',
#    'KEEP',
#    'UR',
#    'SAME',
#    'NUMBER',
#    'Get',
#    'extra',
#    'free',
#    'mins/texts',
#    'Text',
#    'YES',
#    'for',
#    'a',
#    'call']],
#  [0,
#   ['I', 'didn', 't', 'get', 'the', 'second', 'half', 'of', 'that', 'message']],
#  [0, ['I', 'don', 't', 'think', 'he', 'has', 'spatula', 'hands']],
#  [1,
#   ['WIN',
#    'a',
#    '£200',
#    'Shopping',
#    'spree',
#    'every',
#    'WEEK',
#    'Starting',
#    'NOW',
#    '2',
#    'play',
#    'text',
#    'STORE',
#    'to',
#    '88039',
#    'SkilGme',
#    'TsCs08714740323',
#    '1Winawk',
#    'age16',
#    '£1',
#    '50perweeksub']],
#  [0, ['Hey', 'you', 'can', 'pay', 'With', 'salary', 'de', 'Only', 'lt', 'gt']],
#  [1,
#   ['You',
#    'are',
#    'a',
#    'winner',
#    'U',
#    'have',
#    'been',
#    'specially',
#    'selected',
#    '2',
#    'receive',
#    '£1000',
#    'cash',
#    'or',
#    'a',
#    '4*',
#    'holiday',
#    'flights',
#    'inc',
#    'speak',
#    'to',
#    'a',
#    'live',
#    'operator',
#    '2',
#    'claim',
#    '0871277810810']],
#  [1,
#   ['Thanks',
#    'for',
#    'your',
#    'subscription',
#    'to',
#    'Ringtone',
#    'UK',
#    'your',
#    'mobile',
#    'will',
#    'be',
#    'charged',
#    '£5/month',
#    'Please',
#    'confirm',
#    'by',
#    'replying',
#    'YES',
#    'or',
#    'NO',
#    'If',
#    'you',
#    'reply',
#    'NO',
#    'you',
#    'will',
#    'not',
#    'be',
#    'charged']],
#  [0, ['Lol', 'alright', 'i', 'was', 'thinkin', 'that', 'too', 'haha']],
#  [0, ['It', 's', 'that', 'time', 'of', 'the', 'week', 'again', 'ryan']],
#  [0,
#   ['I',
#    'was',
#    'wondering',
#    'if',
#    'it',
#    'would',
#    'be',
#    'okay',
#    'for',
#    'you',
#    'to',
#    'call',
#    'uncle',
#    'john',
#    'and',
#    'let',
#    'him',
#    'know',
#    'that',
#    'things',
#    'are',
#    'not',
#    'the',
#    'same',
#    'in',
#    'nigeria',
#    'as',
#    'they',
#    'r',
#    'here',
#    'That',
#    'lt',
#    'gt',
#    'dollars',
#    'is',
#    '2years',
#    'sent',
#    'and',
#    'that',
#    'you',
#    'know',
#    'its',
#    'a',
#    'strain',
#    'but',
#    'i',
#    'plan',
#    'to',
#    'pay',
#    'back',
#    'every',
#    'dime',
#    'he',
#    'gives',
#    'Every',
#    'dime',
#    'so',
#    'for',
#    'me',
#    'to',
#    'expect',
#    'anything',
#    'from',
#    'you',
#    'is',
#    'not',
#    'practical',
#    'Something',
#    'like',
#    'that']],
#  [0, ['Ok', 'There', 'may', 'be', 'a', 'free', 'gym', 'about']],
#  [0, ['Mmm', 'so', 'yummy', 'babe', 'Nice', 'jolt', 'to', 'the', 'suzy']],
#  [0, ['Nope', 'C', 'ü', 'then']],
#  [0, ['Leave', 'it', 'U', 'will', 'always', 'be', 'ignorant']],
#  ...]

# %%
def get_vocab_length(dataset):
    vocab = set()
    for line in dataset:
        for token in line[1]:
            vocab.add(token)
    return len(vocab)

print(get_vocab_length(dataset))
# Out:
# 11212

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

for line in dataset:
    line[1] = [x.lower() for x in line[1] if x not in stop_words]

print(get_vocab_length(dataset))
# Out:
# [nltk_data] Downloading package stopwords to /home/mayank/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 9026

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()
for line in dataset:
    line[1] = [stemmer.stem(x) for x in line[1]]
    
print(get_vocab_length(dataset))
# Out:
# 7680

# %%
from collections import defaultdict

def get_top_vocab_words(data,topK =  2000):
    vocab = defaultdict(int)
    for line in data:
        for token in line[1]:
            vocab[token]+=1
            
    sorted_vocab = sorted(vocab.items(),key=lambda x: x[1],reverse=True)
    return sorted_vocab[:topK]

def make_indexed_map(data):
    ans = {}
    i = 0
    for line in data:
        ans[line[0]] = i
        i+=1
    return ans

max_vector_sz = 2000
myvocab = make_indexed_map(get_top_vocab_words(dataset, max_vector_sz))
myvocab
# Out:
# {'littl': 387,
#  'sound': 400,
#  'ti': 1513,
#  'half': 292,
#  'slave': 1176,
#  'cd': 748,
#  '£200': 1073,
#  '80488': 1567,
#  'date': 271,
#  'yeah': 123,
#  'princess': 361,
#  'direct': 850,
#  'mark': 1054,
#  'live': 200,
#  'gener': 1930,
#  'hun': 1677,
#  'better': 263,
#  'will': 216,
#  'wit': 695,
#  'chanc': 278,
#  'ip4': 1145,
#  'social': 1584,
#  'phone': 55,
#  'tyler': 1350,
#  'haha': 225,
#  'men': 971,
#  'msg': 102,
#  'rang': 1617,
#  'bed': 372,
#  'bitch': 1431,
#  '150p': 506,
#  'textpod': 1979,
#  'insur': 1196,
#  'green': 1483,
#  'w45wq': 1389,
#  '£3': 865,
#  'includ': 903,
#  'not': 157,
#  'orchard': 866,
#  'text': 22,
#  '10': 489,
#  'bahama': 1953,
#  'same': 879,
#  'hop': 1270,
#  'enemi': 1515,
#  'nvm': 1557,
#  'packag': 1980,
#  'url': 1727,
#  'cum': 687,
#  'txtin': 1981,
#  'prabha': 1538,
#  '£2': 753,
#  '//www': 851,
#  'campu': 1485,
#  'bath': 459,
#  'howev': 1147,
#  'and': 90,
#  'budget': 1461,
#  'u': 1,
#  'balanc': 801,
#  'meetin': 1569,
#  'return': 640,
#  'sk38xh': 1271,
#  'dnt': 809,
#  'pobox': 658,
#  'lie': 1269,
#  'optout': 1570,
#  'simpl': 560,
#  'role': 1197,
#  'list': 1074,
#  'belli': 1571,
#  'fix': 734,
#  'set': 441,
#  'yo': 302,
#  'bro': 1427,
#  'sn': 1625,
#  'abi': 1800,
#  'cheap': 967,
#  '$': 1237,
#  '83355': 1613,
#  'pobox36504w45wq': 1678,
#  'type': 623,
#  'unredeem': 1910,
#  '<forward': 1853,
#  'allah': 1535,
#  '150p/msg': 696,
#  'nt': 534,
#  '25': 1516,
#  '5wb': 1257,
#  'goin': 512,
#  '87239': 1984,
#  'tm': 1679,
#  'sae': 526,
#  'motorola': 802,
#  'oru': 1911,
#  'latr': 1553,
#  'down': 1728,
#  'deal': 817,
#  'yay': 1410,
#  'there': 350,
#  'roger': 1985,
#  'bodi': 1351,
#  '4t': 1729,
#  'work': 59,
#  'form': 1758,
#  'again': 1435,
#  'nah': 924,
#  'ttyl': 1505,
#  'lookin': 1462,
#  'india': 803,
#  'largest': 1912,
#  'strong': 1198,
#  'or': 264,
#  'dint': 1416,
#  'ju': 330,
#  'readi': 262,
#  'leona': 1987,
#  'okay': 421,
#  'airport': 1681,
#  'wet': 1572,
#  'take': 31,
#  'ahmad': 1432,
#  'whether': 1624,
#  'chines': 1607,
#  'parent': 584,
#  'famili': 499,
#  '£150': 1006,
#  'spoken': 1988,
#  'fromm': 1903,
#  'aft': 561,
#  'ym': 1720,
#  'decim': 448,
#  'ansr': 1819,
#  'these': 1682,
#  'leh': 392,
#  'forget': 546,
#  '£400': 1688,
#  'crash': 1989,
#  'gt': 8,
#  'consid': 1391,
#  'yan': 1640,
#  'midnight': 1200,
#  'nxt': 1230,
#  '62468': 1218,
#  'inform': 498,
#  'vijay': 1731,
#  'must': 424,
#  'everybodi': 1629,
#  'express': 1529,
#  'mail': 390,
#  '86021': 1392,
#  '18+': 585,
#  'money': 187,
#  'no1': 1105,
#  'hard': 659,
#  'rest': 910,
#  'addict': 1922,
#  'ignor': 1274,
#  'london': 1463,
#  'person': 171,
#  'wife': 385,
#  'poor': 968,
#  'child': 1915,
#  'suppos': 723,
#  'need': 26,
#  'medic': 1118,
#  'most': 1820,
#  '150': 1041,
#  'relat': 1464,
#  'winner': 646,
#  'funni': 1146,
#  'appli': 335,
#  'chikku': 539,
#  'gone': 672,
#  'sub': 747,
#  'passion': 1821,
#  'ice': 1056,
#  'batteri': 1238,
#  'intro': 1573,
#  'ibiza': 1822,
#  'sourc': 1823,
#  'biz': 1275,
#  'trip': 487,
#  'one': 27,
#  'tariff': 1393,
#  'june': 1817,
#  'april': 1433,
#  'guarante': 226,
#  'immedi': 925,
#  '08000839402': 702,
#  'dark': 1734,
#  'wun': 1201,
#  'captain': 1735,
#  'advanc': 1318,
#  'asleep': 1444,
#  'urself': 1034,
#  'ref': 1916,
#  '100': 634,
#  'prefer': 1202,
#  'aiyar': 1878,
#  'loan': 911,
#  'hear': 349,
#  'derek': 1574,
#  'result': 1035,
#  'amaz': 1394,
#  'life': 128,
#  'buzz': 1203,
#  'ish': 1466,
#  'lik': 1575,
#  'gonna': 197,
#  'handl': 1788,
#  'shall': 362,
#  'wkend': 1949,
#  'wa': 343,
#  'reali': 1095,
#  'my': 68,
#  '4info': 1846,
#  'small': 912,
#  'as': 265,
#  'hill': 1589,
#  'mono': 1736,
#  'babe': 125,
#  'everyth': 393,
#  'don‘t': 1379,
#  'done': 232,
#  'dollar': 1239,
#  'print': 1655,
#  'it': 24,
#  'accid': 1919,
#  'hostel': 1576,
#  'hella': 1577,
#  'wrong': 677,
#  '2nite': 992,
#  'move': 596,
#  'cafe': 1517,
#  'net': 495,
#  'even': 111,
#  'busi': 472,
#  'flower': 1204,
#  'opportun': 1578,
#  'oz': 1825,
#  'order': 449,
#  'yuo': 1737,
#  'missing*': 1993,
#  'dream': 344,
#  'colleagu': 1036,
#  'act': 1683,
#  '2004': 1097,
#  'linerent': 1514,
#  'arrang': 1240,
#  'expens': 1352,
#  'stay': 323,
#  'yogasana': 1579,
#  'com': 165,
#  'rentl': 1550,
#  '10p/min': 993,
#  'store': 784,
#  'confirm': 712,
#  'mrng': 678,
#  'norm150p/ton': 1446,
#  'identifi': 669,
#  '08718727870': 1826,
#  'sept': 1879,
#  'both': 1738,
#  'loyalti': 1319,
#  'bin': 1558,
#  'holla': 1320,
#  'inc': 1112,
#  'sim': 1321,
#  'expect': 896,
#  'dress': 1632,
#  'throat': 1983,
#  'convinc': 1580,
#  'partner': 1353,
#  'site': 1518,
#  'like': 16,
#  'saw': 467,
#  'polyphon': 1684,
#  'sent': 158,
#  'chang': 345,
#  'pull': 1932,
#  'cut': 697,
#  '530': 1568,
#  'tenerif': 1194,
#  'wk': 414,
#  'entitl': 1178,
#  '3': 127,
#  'buck': 1276,
#  'everi': 153,
#  'research': 1994,
#  'practic': 1161,
#  'touch': 532,
#  'onto': 1205,
#  'poli': 461,
#  'challeng': 1891,
#  'born': 1920,
#  'xchat': 1519,
#  'wed': 1000,
#  '11mths+': 1633,
#  'cash': 115,
#  'pick': 113,
#  'guess': 274,
#  'second': 531,
#  'price': 442,
#  'hang': 1468,
#  'island': 1520,
#  'car': 244,
#  'hurt': 346,
#  'goe': 433,
#  'awesom': 562,
#  'intellig': 1815,
#  'teach': 897,
#  'shuhui': 1323,
#  'oh': 87,
#  'team': 1324,
#  'jst': 1395,
#  'per': 199,
#  '18': 446,
#  'voucher': 295,
#  'discuss': 1241,
#  'tuition': 1233,
#  'knew': 754,
#  'reach': 227,
#  'hey': 91,
#  'min': 119,
#  'joke': 628,
#  'arcad': 1402,
#  'town': 395,
#  'me': 195,
#  'yetund': 1887,
#  'man': 242,
#  'goodmorn': 688,
#  'right': 108,
#  'burn': 1685,
#  'appt': 1762,
#  'moan': 1469,
#  'clean': 689,
#  'std': 1075,
#  'never': 251,
#  '2mrw': 1521,
#  'voic': 1009,
#  'thur': 1652,
#  'mistak': 972,
#  'upto': 1774,
#  'wid': 527,
#  'select': 317,
#  'process': 1120,
#  'peopl': 223,
#  'appoint': 1583,
#  'indian': 979,
#  'hello': 217,
#  'beer': 1376,
#  'babi': 358,
#  'boytoy': 660,
#  'lol': 147,
#  'park': 579,
#  'lover': 881,
#  'dude': 475,
#  '08000930705': 661,
#  'k': 49,
#  'public': 1743,
#  'sister': 614,
#  'jen': 1830,
#  'thru': 1134,
#  'bit': 247,
#  'ruin': 1775,
#  'zed': 1470,
#  'weird': 1997,
#  '87077': 1121,
#  'rd': 1686,
#  'window': 1746,
#  '16+': 457,
#  'nigeria': 1098,
#  'maintain': 1901,
#  'children': 973,
#  'get': 5,
#  'guid': 1472,
#  'all': 248,
#  'suit': 1499,
#  'subscrib': 1076,
#  'compani': 606,
#  'review': 1473,
#  'ah': 314,
#  'chase': 1581,
#  'lt': 9,
#  'girlfrnd': 1396,
#  'didnt': 388,
#  'meet': 71,
#  'haf': 496,
#  '10p': 713,
#  'b': 129,
#  'templ': 1732,
#  'quot': 940,
#  'prepar': 1454,
#  'parti': 653,
#  'wot': 439,
#  'anyth': 140,
#  'the': 69,
#  'market': 1747,
#  '£250': 737,
#  'bloke': 1998,
#  'pig': 1996,
#  'dem': 1829,
#  'wow': 818,
#  '3510i': 1642,
#  'din': 1148,
#  'c': 80,
#  'ate': 1474,
#  'quit': 281,
#  'remov': 706,
#  'someth': 154,
#  '4*': 476,
#  'loverboy': 1486,
#  '£1': 336,
#  'detail': 403,
#  '3qxj9': 1999,
#  'travel': 1149,
#  'ticket': 641,
#  'directli': 1381,
#  'regard': 927,
#  'w111wx': 1864,
#  'amt': 1634,
#  'q': 1397,
#  'sheet': 1905,
#  'accept': 1044,
#  'real': 287,
#  'mobileupd8': 648,
#  'close': 434,
#  'may': 218,
#  'account': 260,
#  'let': 101,
#  'total': 1057,
#  'age': 563,
#  'un': 755,
#  'mode': 1010,
#  'complimentari': 852,
#  '8': 411,
#  'don': 373,
#  'except': 1325,
#  'torch': 1326,
#  'shirt': 1150,
#  'when': 209,
#  'villag': 1687,
#  'slept': 1151,
#  'mm': 941,
#  'rite': 574,
#  '11': 899,
#  'convey': 915,
#  'might': 331,
#  'roommat': 1122,
#  'john': 838,
#  '*smiles*': 1832,
#  'visit': 625,
#  'believ': 520,
#  'add': 1077,
#  '0870': 1179,
#  'score': 1278,
#  'murder': 540,
#  '£800': 1078,
#  'ex': 868,
#  'break': 564,
#  'lect': 1011,
#  'toclaim': 1403,
#  'dont': 48,
#  'mite': 1711,
#  'next': 174,
#  'y': 571,
#  'm8': 1437,
#  'film': 810,
#  'complet': 518,
#  'idk': 1883,
#  '£2000': 548,
#  'limit': 1524,
#  'cuz': 1328,
#  'escap': 1749,
#  'news': 572,
#  '08702840625': 1860,
#  'light': 707,
#  'futur': 1124,
#  'pay': 280,
#  'fantast': 928,
#  'somebodi': 877,
#  'anytim': 670,
#  'ldn': 942,
#  '£350': 785,
#  'entri': 447,
#  'think': 35,
#  'still': 40,
#  'login=': 1992,
#  'search': 511,
#  'woman': 1626,
#  'teas': 1475,
#  'envelop': 1355,
#  'onli': 304,
#  'relax': 1242,
#  'websit': 1438,
#  'sinc': 418,
#  '*grins*': 856,
#  'sign': 929,
#  'address': 515,
#  'jazz': 1525,
#  'sol': 1206,
#  'costa': 1207,
#  'rate': 272,
#  'darren': 839,
#  'eat': 249,
#  'http': 573,
#  'allow': 1585,
#  'cs': 277,
#  'differ': 694,
#  'pop': 1280,
#  'left': 363,
#  'hmv': 974,
#  'da': 46,
#  'danc': 1923,
#  '05': 1750,
#  'won': 466,
#  'claim': 86,
#  'sick': 943,
#  'scare': 1691,
#  'fli': 1637,
#  'cinema': 1152,
#  'spend': 724,
#  'x': 201,
#  'plane': 1586,
#  'cw25wx': 1925,
#  'becoz': 1833,
#  'wanna': 305,
#  'ran': 1587,
#  '434': 1659,
#  'lion': 1752,
#  'learn': 1099,
#  'lucozad': 1868,
#  'accident': 1851,
#  '542': 1869,
#  'mrt': 1058,
#  'age16': 1153,
#  'password': 1079,
#  'til': 440,
#  'be': 586,
#  'street': 994,
#  'txtauction': 1358,
#  '|': 953,
#  'enough': 396,
#  'manda': 1991,
#  '30': 643,
#  'someon': 168,
#  'polic': 913,
#  'super': 1494,
#  'outsid': 649,
#  'so': 62,
#  'repli': 37,
#  'adult': 1387,
#  't': 136,
#  'common': 1526,
#  'realli': 124,
#  'doin': 853,
#  'sooner': 1838,
#  'piec': 1588,
#  'weekend': 283,
#  'cuddl': 1390,
#  'treat': 565,
#  'pussi': 1409,
#  'sat': 374,
#  'cat': 1875,
#  'noth': 306,
#  'full': 521,
#  '5we': 1126,
#  'least': 749,
#  'qatar': 1439,
#  'ani': 598,
#  'o2': 1329,
#  'figur': 787,
#  'sen': 1636,
#  '80062': 1710,
#  'invit': 488,
#  'mood': 1100,
#  'pongal': 1721,
#  '=': 914,
#  '%': 1918,
#  'week': 63,
#  'england': 975,
#  'ring': 513,
#  'cold': 1224,
#  'win': 126,
#  'haven': 1527,
#  'gorgeou': 1908,
#  'said': 117,
#  'network': 338,
#  '7': 290,
#  'aiyah': 1359,
#  'if': 54,
#  'doe': 930,
#  'by': 756,
#  'anoth': 309,
#  'month': 252,
#  'gr8': 588,
#  'dun': 212,
#  'reward': 854,
#  'record': 976,
#  'essenti': 1926,
#  'wif': 427,
#  'lead': 1244,
#  'wont': 342,
#  'ship': 1195,
#  'eng': 1712,
#  'lovabl': 883,
#  'ill': 253,
#  'receiv': 243,
#  'semest': 840,
#  'le': 1755,
#  'made': 377,
#  'whenev': 875,
#  'watch': 155,
#  'track': 1478,
#  '3d': 1839,
#  '5th': 1764,
#  'about': 1361,
#  '5': 206,
#  'chariti': 1013,
#  'on': 351,
#  'nope': 681,
#  'gap': 931,
#  'make': 50,
#  'citi': 1692,
#  'urawinn': 1399,
#  'keep': 135,
#  'exam': 642,
#  'with': 415,
#  'want': 20,
#  'mine': 604,
#  'project': 698,
#  'happen': 231,
#  'mad': 1563,
#  'shout': 1898,
#  'omw': 1281,
#  'possibl': 884,
#  'uni': 1638,
#  'wana': 869,
#  'oki': 555,
#  'skype': 1479,
#  'msg*': 1757,
#  'regret': 1528,
#  '£1000': 327,
#  'hl': 1440,
#  'tough': 1282,
#  'feb': 1283,
#  'fullonsm': 1180,
#  'side': 807,
#  'servic': 138,
#  'pleas': 56,
#  'end': 163,
#  'nimya': 1481,
#  'unsubscrib': 566,
#  'naughti': 1210,
#  'click': 1284,
#  '36504': 1211,
#  'askin': 1400,
#  'choic': 1441,
#  'definit': 1059,
#  'bloomberg': 1787,
#  'sp': 1123,
#  'machan': 1842,
#  'hungri': 738,
#  'without': 416,
#  'hook': 1401,
#  'spl': 1556,
#  'anyway': 337,
#  'wyli': 1928,
#  'comput': 725,
#  'rush': 1689,
#  'yiju': 1482,
#  '7pm': 1245,
#  'cool': 266,
#  'wer': 1443,
#  'rather': 1246,
#  'local': 1429,
#  'use': 141,
#  'player': 516,
#  'carlo': 644,
#  'english': 1649,
#  'upgrad': 1844,
#  'area': 808,
#  'other': 782,
#  '8552': 1929,
#  'dedic': 1845,
#  'crazi': 699,
#  'bag': 932,
#  'heart': 219,
#  'boy': 279,
#  'god': 234,
#  'sea': 714,
#  'pete': 885,
#  'dinner': 316,
#  'ar': 1094,
#  'sens': 1154,
#  'btw': 1690,
#  'fast': 651,
#  'star': 1362,
#  'match': 556,
#  'south': 1155,
#  'il': 995,
#  'cbe': 1639,
#  'video': 369,
#  'unless': 1007,
#  '9pm': 1760,
#  'pound': 407,
#  'porn': 1933,
#  'delet': 1484,
#  'congratul': 652,
#  '…': 780,
#  'mid': 1060,
#  'red': 867,
#  '@': 735,
#  'manag': 1096,
#  'beg': 1847,
#  'new': 58,
#  'ta': 1260,
#  'beauti': 482,
#  'empti': 977,
#  'librari': 1156,
#  'friendship': 491,
#  'where': 241,
#  'experi': 1127,
#  'lost': 773,
#  'lift': 1080,
#  'doubl': 477,
#  'bird': 1279,
#  '=d': 1641,
#  'hr': 855,
#  'dload': 1590,
#  'bishan': 1848,
#  'gn': 1213,
#  'honey': 1181,
#  'drive': 270,
#  'sexi': 428,
#  'either': 514,
#  'kiss*': 826,
#  'happi': 77,
#  'warm': 900,
#  'rpli': 898,
#  'bank': 635,
#  'stylish': 1532,
#  'yesterday': 465,
#  'time': 18,
#  'bold': 1214,
#  'told': 213,
#  'excel': 1038,
#  'purchas': 1643,
#  'heavi': 1285,
#  'maxim': 1327,
#  'from': 460,
#  'mayb': 254,
#  'round': 1014,
#  'ur': 6,
#  'lick': 1664,
#  'surf': 1365,
#  'effect': 1850,
#  'here': 1644,
#  'later': 60,
#  'pic': 329,
#  'wherev': 1357,
#  'hour': 224,
#  'bloodi': 1963,
#  'wine': 774,
#  'pretti': 700,
#  'christma': 805,
#  'shd': 1247,
#  'swt': 1101,
#  'speed': 1662,
#  'xma': 419,
#  'cup': 1015,
#  'thursday': 1541,
#  '83600': 1960,
#  'aunti': 1523,
#  'dad': 394,
#  'pictur': 1157,
#  'high': 1248,
#  'question': 315,
#  'ec2a': 1591,
#  'facebook': 1102,
#  'gram': 1852,
#  'perfect': 1964,
#  'maid': 1215,
#  'congrat': 567,
#  '82277': 1331,
#  'hee': 757,
#  'bx420': 1273,
#  'ralli': 1765,
#  'alon': 636,
#  'pix': 1332,
#  'yest': 1286,
#  'pobox84': 1487,
#  'hold': 500,
#  'ntwk': 1913,
#  'start': 145,
#  'anyon': 569,
#  'ive': 1027,
#  'minut': 202,
#  'damn': 1216,
#  'boston': 1601,
#  'urgnt': 1534,
#  'ador': 1935,
#  'tkt': 1763,
#  'askd': 819,
#  '9am': 1693,
#  'cud': 1608,
#  'bought': 1669,
#  'old': 549,
#  '1x150p/wk': 1592,
#  'ride': 1645,
#  'toward': 1317,
#  'gee': 1333,
#  'request': 901,
#  'doc': 1287,
#  'row/w1j6hl': 1767,
#  'mummi': 1779,
#  'hate': 1471,
#  'drink': 435,
#  '12hr': 629,
#  'hug': 1288,
#  'bless': 944,
#  'case': 679,
#  'faster': 1909,
#  'weak': 1289,
#  'isnt': 1363,
#  'lar': 296,
#  'repres': 945,
#  'wap': 981,
#  'tuesday': 1182,
#  '3030': 1104,
#  'fyi': 1488,
#  '*sighs*': 1646,
#  'rcvd': 1235,
#  'singl': 788,
#  'draw': 255,
#  'ge': 1081,
#  'sec': 1217,
#  'rs': 701,
#  'atlanta': 1921,
#  '50': 261,
#  'wednesday': 1158,
#  'santa': 1855,
#  'comuk': 1039,
#  'turn': 841,
#  '||': 811,
#  'yun': 1594,
#  'suck': 1290,
#  '2003': 758,
#  'walk': 382,
#  's': 297,
#  'wen': 450,
#  'though': 425,
#  'lectur': 1555,
#  'max10min': 1420,
#  'log': 662,
#  'year': 144,
#  'ard': 501,
#  'mate': 404,
#  'begin': 1445,
#  'euro2004': 1533,
#  'birthday': 320,
#  'cost': 276,
#  'eatin': 1272,
#  'link': 886,
#  'correct': 739,
#  'impress': 1884,
#  'modul': 1986,
#  'sorri': 39,
#  'ma': 1680,
#  'charg': 321,
#  'soni': 933,
#  '0808': 1770,
#  'page': 870,
#  'hg/suite342/2land': 1183,
#  'fat': 1163,
#  '*kiss*': 1970,
#  'road': 916,
#  'ltd': 655,
#  'sir': 288,
#  'fever': 1971,
#  'na': 771,
#  'were': 1103,
#  'idea': 895,
#  'th': 703,
#  'now': 100,
#  'boost': 1593,
#  'hai': 1220,
#  'unlimit': 726,
#  'hurri': 1082,
#  'greet': 1249,
#  'code': 379,
#  'transfer': 1291,
#  'two': 359,
#  'black': 1159,
#  'wonder': 286,
#  'secret': 663,
#  '£4': 1904,
#  'aha': 1129,
#  'forum': 1857,
#  'alway': 194,
#  '25p': 1184,
#  'offic': 364,
#  'straight': 1364,
#  'darl': 1222,
#  'hot': 502,
#  'prob': 607,
#  'meant': 717,
#  'condit': 1334,
#  'theatr': 1501,
#  'far': 664,
#  'replac': 1695,
#  'smile*': 1867,
#  'cha': 1858,
#  'sex': 775,
#  'internet': 1404,
#  'umma': 1130,
#  'hmm': 719,
#  'centr': 1595,
#  'cheat': 1896,
#  'cal': 1335,
#  'lmao': 1250,
#  'fuck': 237,
#  'center': 1805,
#  'appar': 1880,
#  'suppli': 1859,
#  'n': 42,
#  'hol': 1356,
#  'ru': 1715,
#  'em': 969,
#  'exhaust': 1657,
#  'job': 250,
#  'renew': 1795,
#  'wil': 580,
#  'appreci': 1040,
#  'logo': 1405,
#  'fall': 887,
#  'talk': 182,
#  'valu': 599,
#  'crave': 842,
#  'mom': 522,
#  'daili': 1382,
#  'at': 285,
#  'home': 34,
#  'ppm': 1966,
#  'b4': 727,
#  'deliveri': 507,
#  'tonit': 962,
#  'flirt': 1029,
#  'twice': 1696,
#  '150p/min': 1861,
#  'p': 872,
#  'run': 347,
#  'embarass': 1699,
#  'goto': 1106,
#  'low': 1799,
#  'i': 0,
#  'paid': 1292,
#  'mean': 215,
#  'usf': 888,
#  'colleg': 630,
#  'user': 1061,
#  'seen': 827,
#  'sipix': 1490,
#  'thought': 233,
#  '5000': 1862,
#  'situat': 934,
#  'student': 1185,
#  'dog': 568,
#  'bud': 1892,
#  'got': 21,
#  'clear': 1117,
#  'kettoda': 1726,
#  'avoid': 1536,
#  '3g': 1294,
#  '08718720201': 1295,
#  'wish': 149,
#  'forev': 946,
#  'becaus': 1537,
#  'decemb': 1697,
#  'gay': 1032,
#  'aiyo': 1407,
#  'great': 84,
#  'somewher': 947,
#  'depend': 1008,
#  'stand': 847,
#  'moral': 1016,
#  '4': 11,
#  'origin': 1673,
#  'cake': 1062,
#  'us': 162,
#  'tnc': 1142,
#  'unabl': 1596,
#  'write': 948,
#  'choos': 589,
#  'decis': 1447,
#  'math': 1939,
#  'soon': 181,
#  'tell': 41,
#  'jesu': 1647,
#  ...}

# %%
encoded_data = np.zeros((len(dataset),len(myvocab)))
i=0
for line in dataset:
    for token in line[1]:
        if token in myvocab:
            encoded_data[i,myvocab[token]] = 1
    i+=1

data_sz = len(encoded_data)
training_sz = int(data_sz * 0.8)
test_sz = data_sz - training_sz
training_X = encoded_data[0:training_sz]
test_X = encoded_data[training_sz:data_sz]
training_Y = np.array([x[0] for x in dataset[0:training_sz]]).reshape(training_sz,1)
test_Y = np.array([x[0] for x in dataset[training_sz:data_sz]]).reshape(test_sz,1)

print (data_sz, training_sz, test_sz)
print (training_Y.shape)
# Out:
# 5574 4459 1115
# (4459, 1)

# %%
import math

def sigmoid(x):
    return 1/(1+np.exp(-x))

def sq_loss(x, x_):
    return np.sum(np.square((x-x_)))

def cross_ent_loss(predicted, truth):
    return -np.mean(truth*np.log(predicted) + (1-truth)*np.log(1-predicted))

def predict(Y, Y_):
    Z = (Y > 0.5)
    # print np.count_nonzero(Y_)
    Z = (Z != Y_)
    err = 100.0*np.count_nonzero(Z)/Y.shape[0]
    print ("error: ", np.count_nonzero(Z), "total: ", Y.shape[0], "% error: ", err)
    return err

hl_train = []
hl_test = []

class NeuralNet_sigmoid:
    def __init__(self, inl_dim, hl1_dim, hl2_dim, outl_dim):
        self.inl_dim = inl_dim
        self.hl1_dim = hl1_dim
        self.hl2_dim = hl2_dim
        self.outl_dim = outl_dim
        self.w1 = np.random.normal(size=(inl_dim, hl1_dim), scale=1)
        self.w2 = np.random.normal(size=(hl1_dim, hl2_dim), scale=1)
        self.w3 = np.random.normal(size=(hl2_dim, outl_dim), scale=1)
        self.b1 = np.zeros(hl1_dim)
        self.b2 = np.zeros(hl2_dim)
        self.b3 = np.zeros(outl_dim)
        
    def forward_pass(self, X):
        self.X = X
        t = X.dot(self.w1) + self.b1
        t = sigmoid(t)
        self.y1 = t.copy()
        t = t.dot(self.w2) + self.b2
        t = sigmoid(t)
        self.y2 = t.copy()
        t = t.dot(self.w3) + self.b3
        t = sigmoid(t)
        self.y3 = t.copy()
        return t

    def validate(self, X, Y):
        t = X.dot(self.w1) + self.b1
        t = sigmoid(t)
        t = t.dot(self.w2) + self.b2
        t = sigmoid(t)
        t = t.dot(self.w3) + self.b3
        t = sigmoid(t)
        return predict(t, Y)

    def train(self, X, Y, lr, epochs = 100, batch_sz = 1, reg = 0.0):
        for itr in range(0,epochs):
            
            print ("epoch: ", itr)
            print ("train error:")
            hl_train.append(self.validate(training_X, training_Y))
            print ("test error:")
            hl_test.append(self.validate(test_X, test_Y))
            
            for itr2 in range(0, int(math.ceil(float(X.shape[0])/batch_sz))):
                ds_X = X[int(batch_sz*itr2):int(min(batch_sz*(itr2+1),X.shape[0]))]
                ds_Y = Y[int(batch_sz*itr2):int(min(batch_sz*(itr2+1),Y.shape))]
                self.forward_pass(ds_X)
                l = sq_loss(self.y3, ds_Y)
                #l = cross_ent_loss(self.y3, ds_Y)
                l += reg*(np.sum(np.square(self.w1)) + np.sum(np.square(self.w2)) + np.sum(np.square(self.w3)))
                #print "itr: ", itr, " loss: ", l

                #db3 = (self.y3 - ds_Y)/(ds_Y.shape[0])
                db3 = ((self.y3 - ds_Y)*2)*(self.y3 - np.square(self.y3))
                dw3 = self.y2.T.dot(db3)
                db2 = db3.dot(self.w3.T)*(self.y2 - np.square(self.y2))
                dw2 = self.y1.T.dot(db2)
                db1 = db2.dot(self.w2.T)*(self.y1 - np.square(self.y1))
                dw1 = self.X.T.dot(db1)

                self.w1 -= lr * (dw1 + 2*reg*self.w1)
                self.w2 -= lr * (dw2 + 2*reg*self.w2)
                self.w3 -= lr * (dw3 + 2*reg*self.w3)
                self.b1 -= lr * db1.sum(axis = 0)
                self.b2 -= lr * db2.sum(axis = 0)
                self.b3 -= lr * db3.sum(axis = 0)
            
            
nn = NeuralNet_sigmoid(max_vector_sz, 100, 50, 1)
nn.train(training_X, training_Y, 0.1, 50, 1)
# Out:
# epoch:  0
# train error:
# error:  634 total:  4459 % error:  14.218434626597892
# test error:
# error:  146 total:  1115 % error:  13.094170403587444
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-6cebe2348250> in <module>()
#      91
#      92 nn = NeuralNet_sigmoid(max_vector_sz, 100, 50, 1)
# ---> 93 nn.train(training_X, training_Y, 0.1, 50, 1)
#
# <ipython-input-32-6cebe2348250> in train(self, X, Y, lr, epochs, batch_sz, reg)
#      67             for itr2 in range(0, int(math.ceil(float(X.shape[0])/batch_sz))):
#      68                 ds_X = X[int(batch_sz*itr2):int(min(batch_sz*(itr2+1),X.shape[0]))]
# ---> 69                 ds_Y = Y[int(batch_sz*itr2):int(min(batch_sz*(itr2+1),Y.shape))]
#      70                 self.forward_pass(ds_X)
#      71                 l = sq_loss(self.y3, ds_Y)
#
# TypeError: unorderable types: tuple() < int()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

h1, = plt.plot([x for x in range(0, len(hl_train))], hl_train, label="Train")
h2, = plt.plot([x for x in range(0, len(hl_test))], hl_test, label="Test")
plt.xlabel("Epochs")
plt.ylabel("Error %")
plt.legend(handles=[h1,h2])

# %%
def predict(Y, Y_):
    Z = (Y > 0.5)
    Z = (Z != Y_)
    print ("error: ", np.count_nonzero(Z), "total: ", Y.shape[0], "% error: ", 100.0*np.count_nonzero(Z)/Y.shape[0])

predict(nn.forward_pass(test_X), test_Y)

# %%
import math

def sq_loss(x, x_):
    return np.sum(np.square((x-x_)))

def cross_ent_loss(predicted, truth):
    return -np.mean(truth*np.log(predicted) + (1-truth)*np.log(1-predicted))

def predict(Y, Y_):
    Z = np.array([(1 if x >= 0 else -1) for x in Y]).reshape(Y.shape[0],1)
    Z = (Z != Y_)
    err = 100.0*np.count_nonzero(Z)/Y.shape[0]
    print ("error: ", np.count_nonzero(Z), "total: ", Y.shape[0], "% error: ", err)
    return err

hl_train_2 = []
hl_test_2 = []

class NeuralNet_tanh:
    def __init__(self, inl_dim, hl1_dim, hl2_dim, outl_dim):
        self.inl_dim = inl_dim
        self.hl1_dim = hl1_dim
        self.hl2_dim = hl2_dim
        self.outl_dim = outl_dim
        self.w1 = np.random.normal(size=(inl_dim, hl1_dim), scale=1)
        self.w2 = np.random.normal(size=(hl1_dim, hl2_dim), scale=1)
        self.w3 = np.random.normal(size=(hl2_dim, outl_dim), scale=1)
        self.b1 = np.zeros(hl1_dim)
        self.b2 = np.zeros(hl2_dim)
        self.b3 = np.zeros(outl_dim)
        
    def forward_pass(self, X):
        self.X = X
        t = X.dot(self.w1) + self.b1
        t = np.tanh(t)
        self.y1 = t.copy()
        t = t.dot(self.w2) + self.b2
        t = np.tanh(t)
        self.y2 = t.copy()
        t = t.dot(self.w3) + self.b3
        t = np.tanh(t)
        self.y3 = t.copy()
        return t

    def validate(self, X, Y):
        t = X.dot(self.w1) + self.b1
        t = np.tanh(t)
        t = t.dot(self.w2) + self.b2
        t = np.tanh(t)
        t = t.dot(self.w3) + self.b3
        t = np.tanh(t)
        return predict(t, Y)

    def train(self, X, Y, lr, epochs = 100, batch_sz = 1, reg = 0.0):
        for itr in range(0,epochs):
            
            print ("epoch: ", itr)
            hl_train_2.append(self.validate(training_X, np.array([(-1 if x == 0 else 1) for x in training_Y]).reshape(training_X.shape[0],1)))
            hl_test_2.append(self.validate(test_X, np.array([(-1 if x == 0 else 1) for x in test_Y]).reshape(test_X.shape[0],1)))
            
            for itr2 in range(0, int(math.ceil(float(X.shape[0])/batch_sz))):
                ds_X = X[batch_sz*itr2:min(batch_sz*(itr2+1),X.shape[0])]
                ds_Y = Y[batch_sz*itr2:min(batch_sz*(itr2+1),Y.shape)]
                self.forward_pass(ds_X)
                l = sq_loss(self.y3, ds_Y)
                #l = cross_ent_loss(self.y3, ds_Y)
                l += reg*(np.sum(np.square(self.w1)) + np.sum(np.square(self.w2)) + np.sum(np.square(self.w3)))

                #db3 = (self.y3 - ds_Y)/(ds_Y.shape[0])
                db3 = ((self.y3 - ds_Y)*2)*(1 - np.square(self.y3))
                dw3 = self.y2.T.dot(db3)
                db2 = db3.dot(self.w3.T)*(1 - np.square(self.y2))
                dw2 = self.y1.T.dot(db2)
                db1 = db2.dot(self.w2.T)*(1 - np.square(self.y1))
                dw1 = self.X.T.dot(db1)

                self.w1 -= lr * (dw1 + 2*reg*self.w1)
                self.w2 -= lr * (dw2 + 2*reg*self.w2)
                self.w3 -= lr * (dw3 + 2*reg*self.w3)
                self.b1 -= lr * db1.sum(axis = 0)
                self.b2 -= lr * db2.sum(axis = 0)
                self.b3 -= lr * db3.sum(axis = 0)
#                 print "itr: ", itr, " loss: ", l
            
            
nn2 = NeuralNet_tanh(max_vector_sz, 100, 50, 1)
nn2.train(training_X, np.array([(-1 if x == 0 else 1) for x in training_Y]).reshape(training_Y.shape[0],1), 0.1, 50, 1)

# %%
h1, = plt.plot([x for x in range(0, len(hl_train_2))], hl_train_2, label="Train")
h2, = plt.plot([x for x in range(0, len(hl_test_2))], hl_test_2, label="Test")
plt.xlabel("Epochs")
plt.ylabel("Error %")
plt.legend(handles=[h1,h2])

# %%
import math

def sigmoid(x):
    return 1/(1+np.exp(-x))

def sq_loss(x, x_):
    return np.sum(np.square((x-x_)))

def cross_ent_loss(predicted, truth):
    return -np.mean(truth*np.log(predicted) + (1-truth)*np.log(1-predicted))

def softmax(x):
    x = np.exp(x)
    x /= np.sum(x, axis = 1, keepdims=True)
    return x

def predict(Y, Y_):
    Z = np.array([1 if x[1] >= x[0] else 0 for x in Y]).reshape(Y.shape[0],1)
    # print np.count_nonzero(Y_)
    Z = (Z != Y_)
    err = 100.0*np.count_nonzero(Z)/Y.shape[0]
    print ("error: ", np.count_nonzero(Z), "total: ", Y.shape[0], "% error: ", err)
    return err

hl_train_3 = []
hl_test_3 = []

class NeuralNet_sigmoid:
    def __init__(self, inl_dim, hl1_dim, hl2_dim, outl_dim):
        self.inl_dim = inl_dim
        self.hl1_dim = hl1_dim
        self.hl2_dim = hl2_dim
        self.outl_dim = outl_dim
        self.w1 = np.random.normal(size=(inl_dim, hl1_dim), scale=1)
        self.w2 = np.random.normal(size=(hl1_dim, hl2_dim), scale=1)
        self.w3 = np.random.normal(size=(hl2_dim, outl_dim), scale=1)
        self.b1 = np.zeros(hl1_dim)
        self.b2 = np.zeros(hl2_dim)
        self.b3 = np.zeros(outl_dim)
        
    def forward_pass(self, X):
        self.X = X
        t = X.dot(self.w1) + self.b1
        t = sigmoid(t)
        self.y1 = t.copy()
        t = t.dot(self.w2) + self.b2
        t = sigmoid(t)
        self.y2 = t.copy()
        t = t.dot(self.w3) + self.b3
        t = softmax(t)
        self.y3 = t.copy()
        return t

    def validate(self, X, Y):
        t = X.dot(self.w1) + self.b1
        t = sigmoid(t)
        t = t.dot(self.w2) + self.b2
        t = sigmoid(t)
        t = t.dot(self.w3) + self.b3
        t = softmax(t)
        return predict(t, Y)

    def train(self, X, Y, lr, epochs = 100, batch_sz = 1, reg = 0.0):
        for itr in range(0,epochs):
            
            print ("epoch: ", itr)
            hl_train_3.append(self.validate(training_X, training_Y))
            hl_test_3.append(self.validate(test_X, test_Y))
            
            for itr2 in range(0, int(math.ceil(float(X.shape[0])/batch_sz))):
                ds_X = X[batch_sz*itr2:min(batch_sz*(itr2+1),X.shape[0])]
                ds_Y = Y[batch_sz*itr2:min(batch_sz*(itr2+1),Y.shape)]
                self.forward_pass(ds_X)
                l = sq_loss(self.y3, ds_Y)
                #l = cross_ent_loss(self.y3, ds_Y)
                l += reg*(np.sum(np.square(self.w1)) + np.sum(np.square(self.w2)) + np.sum(np.square(self.w3)))
#                 print "itr: ", itr, " loss: ", l

                #db3 = (self.y3 - ds_Y)/(ds_Y.shape[0])
                dy3 = (self.y3 - ds_Y)*2
                temp = np.prod(self.y3, axis = 1, keepdims=True)
                db3 = dy3 * temp
                db3[:,1] *= -1
                db3 = np.sum(db3, axis=1, keepdims=True)
                db3 = np.repeat(db3, 2, axis = 1)
                db3[:,1] *= -1
                
                dw3 = self.y2.T.dot(db3)
                db2 = db3.dot(self.w3.T)*(self.y2 - np.square(self.y2))
                dw2 = self.y1.T.dot(db2)
                db1 = db2.dot(self.w2.T)*(self.y1 - np.square(self.y1))
                dw1 = self.X.T.dot(db1)

                self.w1 -= lr * (dw1 + 2*reg*self.w1)
                self.w2 -= lr * (dw2 + 2*reg*self.w2)
                self.w3 -= lr * (dw3 + 2*reg*self.w3)
                self.b1 -= lr * db1.sum(axis = 0)
                self.b2 -= lr * db2.sum(axis = 0)
                self.b3 -= lr * db3.sum(axis = 0)            
            
nn3 = NeuralNet_sigmoid(max_vector_sz, 100, 50, 2)
nn3.train(training_X, np.array([np.array([0,1]) if x == 1 else np.array([1,0]) for x in training_Y]), 0.1, 50, 1)

# %%
hl1, = plt.plot([x for x in range(0, len(hl_train_3))], hl_train_3, label="Train")
hl2, = plt.plot([x for x in range(0, len(hl_test_3))], hl_test_3, label="Test")
plt.xlabel("Epochs")
plt.ylabel("Error %")
plt.legend(handles=[h1,h2])
